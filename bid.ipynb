# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import \
    ProjectsNotFoundException
from freelancersdk.resources.projects.helpers import (
    create_search_projects_filter,
    create_get_projects_user_details_object,
    create_get_projects_project_details_object,
)
import os
from dotenv import load_dotenv

load_dotenv()

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    query = 'Logo Design'
    search_filter = create_search_projects_filter(
        sort_field= 'time_updated',
        or_search_query= True,
    )

    try:
        p = search_projects(
            session,
            query=query,
            search_filter=search_filter
        )

    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p


p = sample_search_projects()
if p:
    print('Found projects: {}'.format(p))

# %%
p

# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import (
    get_projects, get_project_by_id
)
from freelancersdk.resources.projects.helpers import (
    create_get_projects_object, create_get_projects_project_details_object,
    create_get_projects_user_details_object
)
from freelancersdk.resources.projects.exceptions import \
    ProjectsNotFoundException
import os
import json


def sample_get_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    query = create_get_projects_object(
        project_ids=[
            201,
            202,
            203,
        ],
        project_details=create_get_projects_project_details_object(
            full_description=True,
            jobs=True,
            qualifications=True,
        ),
        user_details=create_get_projects_user_details_object(
            basic=True,
            profile_description=True,
            reputation=True,
        ),
    )

    try:
        p = get_projects(session, query)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_get_project_by_id():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_id = 15389177
    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p


print('Getting multiple projects...')
p = sample_get_projects()
if p:
    print('Found projects: {}'.format(json.dumps(p)))
print('Getting a single project by ID...')

p = sample_get_project_by_id()
if p:
    print('Found a single project: {}'.format(json.dumps(p)))

# %%
from freelancersdk.resources.projects import place_project_bid
from freelancersdk.session import Session
from freelancersdk.resources.users import get_self_user_id
from freelancersdk.exceptions import BidNotPlacedException
import os

# https://www.freelancer.com/api/docs/cases/creating_a_bid
def sample_place_project_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')

    session = Session(oauth_token=oauth_token, url=url)

    try:
        my_user_id = get_self_user_id(session)
    except:
        # User ID not retrieved. Handle the error here, e.g., print an error message.
        return None

    bid_data = {
        'project_id': int(project_id),
        'bidder_id': my_user_id,
        'amount': 10,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        return place_project_bid(session, **bid_data)
    except BidNotPlacedException as e:
        print(('Error message: %s' % e.message))
        print(('Error code: %s' % e.error_code))
        return None


b = sample_place_project_bid()
if b:
    print(("Bid placed: %s" % b))

# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects import accept_project_bid
from freelancersdk.exceptions import BidNotAcceptedException
import os

# https://developers.freelancer.com/docs/use-cases/performing-a-bid-action
def sample_accept_project_bid():
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    url = os.environ.get('FLN_URL')
    session = Session(oauth_token=oauth_token, url=url)

    bid_data = {
        'bid_id': 1
    }

    try:
        return accept_project_bid(session, **bid_data)
    except BidNotAcceptedException as e:
        print(('Error message: %s' % e))
        return None

b = sample_accept_project_bid()
if b:
    print(("Bid revoked: %s" % b))

# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects import revoke_project_bid
from freelancersdk.exceptions import BidNotRevokedException
import os

# https://developers.freelancer.com/docs/use-cases/performing-a-bid-action
def sample_revoke_project_bid():
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    url = os.environ.get('FLN_URL')
    session = Session(oauth_token=oauth_token, url=url)

    bid_data = {
        'bid_id': 1
    }

    try:
        return revoke_project_bid(session, **bid_data)
    except BidNotRevokedException as e:
        print(('Error message: %s' % e))
        return None

b = sample_revoke_project_bid()
if b:
    print(("Bid revoked: %s" % b))

# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects import (
    place_project_bid,
    accept_project_bid,
    revoke_project_bid,
    search_projects
)
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
from freelancersdk.resources.projects.helpers import create_search_projects_filter
from freelancersdk.resources.users import get_self_user_id
from freelancersdk.exceptions import BidNotPlacedException, BidNotAcceptedException, BidNotRevokedException
import os
from dotenv import load_dotenv

load_dotenv()

def sample_search_projects_and_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')

    session = Session(oauth_token=oauth_token, url=url)

    query = 'Logo Design'
    search_filter = create_search_projects_filter(
        sort_field='time_updated',
        or_search_query=True,
    )

    try:
        projects = search_projects(session, query=query, search_filter=search_filter)
        print('Found projects:', projects)
    except ProjectsNotFoundException as e:
        print('Error searching for projects:', e)
        return None

    try:
        my_user_id = get_self_user_id(session)
    except Exception as e:
        print('Error retrieving user id:', e)
        return None

    bid_data = {
        'project_id': int(project_id),
        'bidder_id': my_user_id,
        'amount': 10,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        bid_result = place_project_bid(session, **bid_data)
        print('Bid placed:', bid_result)
    except BidNotPlacedException as e:
        print('Error placing bid:', e)
        return None

    try:
        accept_result = accept_project_bid(session, bid_id=bid_result['id'])
        print('Bid accepted:', accept_result)
    except BidNotAcceptedException as e:
        print('Error accepting bid:', e)
        return None

    try:
        revoke_result = revoke_project_bid(session, bid_id=bid_result['id'])
        print('Bid revoked:', revoke_result)
    except BidNotRevokedException as e:
        print('Error revoking bid:', e)
        return None

sample_search_projects_and_bid()

# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects import (
    place_project_bid,
    accept_project_bid,
    search_projects,
    highlight_project_bid,
    retract_project_bid,
    revoke_project_bid
)
from freelancersdk.resources.users import get_self_user_id
from freelancersdk.exceptions import (
    BidNotPlacedException,
    BidNotAcceptedException,
    ProjectsNotFoundException,
    BidNotHighlightedException,
    BidNotRetractedException,
    BidNotRevokedException
)
import os
from dotenv import load_dotenv

load_dotenv()

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    query = 'Logo Design'
    search_filter = {
        'sort_field': 'time_updated',
        'or_search_query': True
    }

    try:
        p = search_projects(session, query=query, search_filter=search_filter)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_highlight_project_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    bid_id = os.environ.get('BID_ID')
    session = Session(oauth_token=oauth_token, url=url)

    try:
        return highlight_project_bid(session, bid_id)
    except BidNotHighlightedException as e:
        print('Error highlighting bid:', e.error_code)
        return None

def sample_place_project_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')
    session = Session(oauth_token=oauth_token, url=url)

    try:
        my_user_id = get_self_user_id(session)
    except:
        # User ID not retrieved. Handle the error here, e.g., print an error message.
        return None

    bid_data = {
        'project_id': int(project_id),
        'bidder_id': my_user_id,
        'amount': 10,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        return place_project_bid(session, **bid_data)
    except BidNotPlacedException as e:
        print(('Error message: %s' % e.message))
        print(('Error code: %s' % e.error_code))
        return None

def sample_retract_project_bid():
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    url = os.environ.get('FLN_URL')
    session = Session(oauth_token=oauth_token, url=url)

    bid_data = {
        'bid_id': 1
    }

    try:
        return retract_project_bid(session, **bid_data)
    except BidNotRetractedException as e:
        print('Error message:', str(e))  # Accessing error message using str(e)
        print(('Error code: %s' % e.error_code))
        return None

def sample_revoke_project_bid():
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    url = os.environ.get('FLN_URL')
    session = Session(oauth_token=oauth_token, url=url)

    bid_data = {
        'bid_id': 1
    }

    try:
        return revoke_project_bid(session, **bid_data)
    except BidNotRevokedException as e:
        print(('Error message: %s' % e))
        return None

# Main code execution
if __name__ == "__main__":
    p = sample_search_projects()
    if p:
        print('Found projects: {}'.format(p))

    b = sample_highlight_project_bid()
    if b:
        print("Bid highlighted:", b)

    b = sample_place_project_bid()
    if b:
        print(("Bid placed: %s" % b))

    b = sample_retract_project_bid()
    if b:
        print(("Bid retracted: %s" % b))

    b = sample_revoke_project_bid()
    if b:
        print(("Bid revoked: %s" % b))

# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import (
    search_projects, get_projects, get_project_by_id, place_project_bid,
    create_milestone_payment
)
from freelancersdk.resources.projects.exceptions import (
    ProjectsNotFoundException, BidNotPlacedException, MilestoneNotCreatedException
)
from freelancersdk.resources.projects.helpers import (
    create_search_projects_filter, create_get_projects_object,
    create_get_projects_project_details_object,
    create_get_projects_user_details_object
)
from freelancersdk.resources.projects.types import MilestoneReason
import os
import json

# Function to search for projects
def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    query = 'Logo Design'
    search_filter = create_search_projects_filter(
        sort_field='time_updated',
        or_search_query=True,
    )

    try:
        p = search_projects(session, query=query, search_filter=search_filter)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

# Function to retrieve details of multiple projects
def sample_get_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    query = create_get_projects_object(
        project_ids=[201, 202, 203],
        project_details=create_get_projects_project_details_object(
            full_description=True,
            jobs=True,
            qualifications=True,
        ),
        user_details=create_get_projects_user_details_object(
            basic=True,
            profile_description=True,
            reputation=True,
        ),
    )

    try:
        p = get_projects(session, query)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

# Function to retrieve details of a single project by ID
def sample_get_project_by_id():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    project_id = 15389177
    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

# Function to create a bid for a project
def sample_create_project_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')

    if not all([url, oauth_token, project_id]):
        print("Missing required environment variables.")
        return None

    session = Session(oauth_token=oauth_token)

    bid_data = {
        'project_id': int(project_id),
        'amount': 10,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        return place_project_bid(session, **bid_data)
    except BidNotPlacedException as e:
        print(('Error message: %s' % e.message))
        print(('Error code: %s' % e.error_code))
        return None

# Function to create a milestone payment for a project
def sample_create_milestone_payment():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')
    bidder_id = os.environ.get('BIDDER_ID')

    if not all([url, oauth_token, project_id, bidder_id]):
        print("Missing required environment variables.")
        return None

    try:
        project_id = int(project_id)
        bidder_id = int(bidder_id)
    except (TypeError, ValueError):
        print("Invalid project_id or bidder_id.")
        return None

    session = Session(oauth_token=oauth_token)
    milestone_data = {
        'project_id': project_id,
        'bidder_id': bidder_id,
        'amount': 10,
        'reason': MilestoneReason.PARTIAL_PAYMENT.value,
        'description': 'This is a milestone',
    }

    try:
        m = create_milestone_payment(session, **milestone_data)
    except MilestoneNotCreatedException as e:
        print(('Error message: %s' % e.message))
        print(('Server response: %s' % e.error_code))
        return None
    else:
        return m

# Main program
if __name__ == "__main__":
    print('Searching for projects...')
    projects = sample_search_projects()
    if projects:
        print('Found projects: {}'.format(json.dumps(projects)))

    print('Retrieving details of multiple projects...')
    multiple_projects = sample_get_projects()
    if multiple_projects:
        print('Details of multiple projects: {}'.format(json.dumps(multiple_projects)))

    print('Retrieving details of a single project by ID...')
    single_project = sample_get_project_by_id()
    if single_project:
        print('Details of a single project: {}'.format(json.dumps(single_project)))

    print('Creating a bid for a project...')
    bid_created = sample_create_project_bid()
    if bid_created:
        print('Bid created: {}'.format(bid_created))

    print('Creating a milestone payment...')
    milestone_created = sample_create_milestone_payment()
    if milestone_created:
        print('Milestone created: {}'.format(milestone_created))
# Out:
# Searching for projects...
# Found projects: {"projects": [{"id": 37947640, "owner_id": 45196898, "title": "Classy Stationery Design utilizing Peacock Colors", "status": "active", "sub_status": null, "seo_url": "graphic-design/Classy-Stationery-Design-utilizing", "currency": {"id": 11, "code": "INR", "sign": "\u20b9", "name": "Indian Rupee", "exchange_rate": 0.011993, "country": "IN", "is_external": false, "is_escrowcom_supported": false}, "description": null, "jobs": null, "submitdate": 1712051034, "preview_description": "I'm in search of a competent designer who can create a sophisticated and elegant design for my logo,", "deleted": false, "nonpublic": false, "hidebids": false, "type": "fixed", "bidperiod": 7, "budget": {"minimum": 1500.0, "maximum": 12500.0, "name": null, "project_type": null, "currency_id": null}, "hourly_project_info": null, "featured": false, "urgent": false, "assisted": null, "active_prepaid_milestone": null, "bid_stats": {"bid_count": 28, "bid_avg": 4906.0}, "time_submitted": 1712051034, "time_updated": 1712051034, "upgrades": {"featured": false, "sealed": false, "nonpublic": false, "fulltime": false, "urgent": false, "qualified": false, "NDA": false, "assisted": null, "active_prepaid_milestone": null, "ip_contract": false, "success_bundle": null, "non_compete": false, "project_management": false, "pf_only": false, "recruiter": null, "listed": null, "extend": null, "unpaid_recruiter": null, "premium": false, "enterprise": false}, "qualifications": null, "language": "en", "attachments": null, "hireme": false, "hireme_initial_bid": null, "invited_freelancers": null, "recommended_freelancers": null, "frontend_project_status": "open", "nda_signatures": null, "location": {"country": {"name": null, "flag_url": null, "code": null, "highres_flag_url": null, "flag_url_cdn": null, "highres_flag_url_cdn": null, "iso3": null, "region_id": null, "phone_code": null, "demonym": null, "person": null, "seo_url": null, "sanction": null, "language_code": null, "language_id": null}, "city": null, "latitude": null, "longitude": null, "vicinity": null, "administrative_area": null, "full_address": null, "administrative_area_code": null, "postal_code": null, "id": null}, "true_location": null, "local": false, "negotiated": false, "negotiated_bid": null, "time_free_bids_expire": 1712047434, "can_post_review": null, "files": null, "user_distance": null, "from_user_location": null, "project_collaborations": null, "support_sessions": null, "track_ids": null, "drive_files": null, "nda_details": null, "pool_ids": ["freelancer"], "enterprise_ids": [], "timeframe": null, "deloitte_details": null, "is_escrow_project": false, "is_seller_kyc_required": false, "is_buyer_kyc_required": false, "local_details": null, "equipment": null, "nda_signatures_new": null, "billing_code": null, "enterprises": [], "enterprise_metadata_values": null, "project_reject_reason": {"description": null, "message": null}, "repost_id": null, "client_engagement": null, "contract_signatures": null, "quotation_id": null, "quotation_version_id": null, "enterprise_linked_projects_details": null, "equipment_groups": null, "project_source": null, "project_source_reference": null, "quality_details": null, "previous_recruiter_project_details": null, "project_note": null, "is_quotation_project": null, "quotation_initial_bid": null, "requires_upfront_funding": null, "group_ids": []}, {"id": 37947629, "owner_id": 71753799, "title": "Revamp Existing Logo with Stylish Graphics", "status": "active", "sub_status": null, "seo_url": "logo-design/Revamp-Existing-Logo-with-Stylish", "currency": {"id": 1, "code": "USD", "sign": "$", "name": "US Dollar", "exchange_rate": 1.0, "country": "US", "is_external": false, "is_escrowcom_supported": true}, "description": null, "jobs": null, "submitdate": 1712050827, "preview_description": "I'm looking for a skilled designer who can breathe new life into my current logo. Your task would be", "deleted": false, "nonpublic": false, "hidebids": false, "type": "fixed", "bidper ...
# Retrieving details of multiple projects...
# Details of multiple projects: {"projects": [{"id": 201, "owner_id": 2684, "title": "Boot to application", "status": "closed", "sub_status": "closed_expired", "seo_url": "Boot-application-project", "currency": {"id": 1, "code": "USD", "sign": "$", "name": "US Dollar", "exchange_rate": 1.0, "country": "US", "is_external": false, "is_escrowcom_supported": true}, "description": "To provide a boot sequence for ms windows such that from switching on\r\nthe mains the computer loads an application and displays files on the monitor without any further interaction after switching on. i.e no passwords, start menu-application, etc.  I envisage boot - load browser - display html files (starting with home page) It could be some other application, but browser/html files seems the most common and, because these files have to be uploaded would probably be easier. ", "jobs": [], "submitdate": 1077810438, "preview_description": "To provide a boot sequence for ms windows such that from switching on\r\nthe mains the computer loads ", "deleted": false, "nonpublic": false, "hidebids": false, "type": "fixed", "bidperiod": 5, "budget": {"minimum": null, "maximum": null, "name": null, "project_type": null, "currency_id": null}, "hourly_project_info": null, "featured": false, "urgent": false, "assisted": null, "active_prepaid_milestone": null, "bid_stats": {"bid_count": 2, "bid_avg": 10.0}, "time_submitted": 1077810438, "time_updated": null, "upgrades": {"featured": false, "sealed": false, "nonpublic": false, "fulltime": false, "urgent": false, "qualified": false, "NDA": false, "assisted": null, "active_prepaid_milestone": null, "ip_contract": false, "success_bundle": null, "non_compete": false, "project_management": false, "pf_only": false, "recruiter": null, "listed": null, "extend": null, "unpaid_recruiter": null, "premium": false, "enterprise": false}, "qualifications": [], "language": "en", "attachments": null, "hireme": false, "hireme_initial_bid": null, "invited_freelancers": null, "recommended_freelancers": null, "frontend_project_status": "complete", "nda_signatures": null, "location": {"country": {"name": null, "flag_url": null, "code": null, "highres_flag_url": null, "flag_url_cdn": null, "highres_flag_url_cdn": null, "iso3": null, "region_id": null, "phone_code": null, "demonym": null, "person": null, "seo_url": null, "sanction": null, "language_code": null, "language_id": null}, "city": null, "latitude": null, "longitude": null, "vicinity": null, "administrative_area": null, "full_address": null, "administrative_area_code": null, "postal_code": null, "id": null}, "true_location": null, "local": false, "negotiated": false, "negotiated_bid": null, "time_free_bids_expire": null, "can_post_review": null, "files": null, "user_distance": null, "from_user_location": null, "project_collaborations": null, "support_sessions": null, "track_ids": null, "drive_files": null, "nda_details": null, "pool_ids": ["freelancer"], "enterprise_ids": [], "timeframe": null, "deloitte_details": null, "is_escrow_project": false, "is_seller_kyc_required": false, "is_buyer_kyc_required": false, "local_details": null, "equipment": null, "nda_signatures_new": null, "billing_code": null, "enterprises": [], "enterprise_metadata_values": null, "project_reject_reason": {"description": null, "message": null}, "repost_id": null, "client_engagement": null, "contract_signatures": null, "quotation_id": null, "quotation_version_id": null, "enterprise_linked_projects_details": null, "equipment_groups": null, "project_source": null, "project_source_reference": null, "quality_details": null, "previous_recruiter_project_details": null, "project_note": null, "is_quotation_project": null, "quotation_initial_bid": null, "requires_upfront_funding": null, "group_ids": []}, {"id": 202, "owner_id": 2687, "title": "Mobile Phone Software", "status": "closed", "sub_status": "closed_expired", "seo_url": "C-C-Python/Mobile-Phone-Software", "currency": {"id": 1, "code": "USD", "sign": "$", "name": ...
# Retrieving details of a single project by ID...
# Details of a single project: {"id": 15389177, "owner_id": 26905802, "title": "Project for kenniokeif", "status": "closed", "sub_status": "closed_expired", "seo_url": "advertising/Project-for-kenniokeif", "currency": {"id": 1, "code": "USD", "sign": "$", "name": "US Dollar", "exchange_rate": 1.0, "country": "US", "is_external": false, "is_escrowcom_supported": true}, "description": "Hi kenniokeif, I noticed your profile and would like to offer you my project. We can discuss any details over chat. I am also residing in Jamaica and would love to discuss a business proposal. ", "jobs": null, "submitdate": 1507878467, "preview_description": "Hi kenniokeif, I noticed your profile and would like to offer you my project. We can discuss any det", "deleted": false, "nonpublic": false, "hidebids": false, "type": "fixed", "bidperiod": 10, "budget": {"minimum": 250.0, "maximum": 250.0, "name": null, "project_type": null, "currency_id": null}, "hourly_project_info": null, "featured": false, "urgent": false, "assisted": null, "active_prepaid_milestone": null, "bid_stats": {"bid_count": 1, "bid_avg": 250.0}, "time_submitted": 1507878467, "time_updated": null, "upgrades": {"featured": false, "sealed": false, "nonpublic": false, "fulltime": false, "urgent": false, "qualified": false, "NDA": false, "assisted": null, "active_prepaid_milestone": null, "ip_contract": false, "success_bundle": null, "non_compete": false, "project_management": false, "pf_only": false, "recruiter": null, "listed": null, "extend": null, "unpaid_recruiter": null, "premium": false, "enterprise": false}, "qualifications": null, "language": "en", "attachments": null, "hireme": true, "hireme_initial_bid": null, "invited_freelancers": null, "recommended_freelancers": null, "frontend_project_status": "complete", "nda_signatures": null, "location": {"country": {"name": null, "flag_url": null, "code": null, "highres_flag_url": null, "flag_url_cdn": null, "highres_flag_url_cdn": null, "iso3": null, "region_id": null, "phone_code": null, "demonym": null, "person": null, "seo_url": null, "sanction": null, "language_code": null, "language_id": null}, "city": null, "latitude": null, "longitude": null, "vicinity": null, "administrative_area": null, "full_address": null, "administrative_area_code": null, "postal_code": null, "id": null}, "true_location": null, "local": false, "negotiated": false, "negotiated_bid": null, "time_free_bids_expire": 1507878467, "can_post_review": null, "files": null, "user_distance": null, "from_user_location": null, "project_collaborations": null, "support_sessions": null, "track_ids": null, "drive_files": null, "nda_details": null, "pool_ids": ["freelancer"], "enterprise_ids": [], "timeframe": null, "deloitte_details": null, "is_escrow_project": false, "is_seller_kyc_required": false, "is_buyer_kyc_required": false, "local_details": null, "equipment": null, "nda_signatures_new": null, "billing_code": null, "enterprises": [], "enterprise_metadata_values": null, "project_reject_reason": {"description": null, "message": null}, "repost_id": null, "client_engagement": null, "contract_signatures": null, "quotation_id": null, "quotation_version_id": null, "enterprise_linked_projects_details": null, "equipment_groups": null, "project_source": null, "project_source_reference": null, "quality_details": null, "previous_recruiter_project_details": null, "project_note": null, "is_quotation_project": null, "quotation_initial_bid": null, "requires_upfront_funding": null, "group_ids": [], "owner": {"id": 26905802, "username": "DrChung", "suspended": null, "closed": false, "is_active": null, "force_verify": null, "avatar": null, "email": null, "reputation": null, "jobs": null, "profile_description": null, "hourly_rate": null, "registration_date": 1507878466, "limited_account": false, "display_name": "DrChung", "tagline": null, "location": {"country": {"name": "Jamaica", "flag_url": null, "code": null, "highres_flag_url": null, "flag_url_cdn": null, "highres_flag_url_cdn": ...
# Creating a bid for a project...
# Missing required environment variables.
# Creating a milestone payment...
# Missing required environment variables.

# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import (
    search_projects, get_projects, get_project_by_id, place_project_bid,
    create_milestone_payment
)
from freelancersdk.resources.projects.exceptions import (
    ProjectsNotFoundException, BidNotPlacedException, MilestoneNotCreatedException
)
from freelancersdk.resources.projects.helpers import (
    create_search_projects_filter, create_get_projects_object,
    create_get_projects_project_details_object,
    create_get_projects_user_details_object
)
from freelancersdk.resources.projects.types import MilestoneReason
import os
import json
import csv

def read_env_variables_from_csv(csv_file_path):
    env_variables = {}
    with open(csv_file_path, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            env_variables[row['Variable']] = row['Value']
    return env_variables

# Function to search for projects
def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    query = 'Logo Design'
    search_filter = create_search_projects_filter(
        sort_field='time_updated',
        or_search_query=True,
    )

    try:
        p = search_projects(session, query=query, search_filter=search_filter)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

# Function to retrieve details of multiple projects
def sample_get_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    query = create_get_projects_object(
        project_ids=[201, 202, 203],
        project_details=create_get_projects_project_details_object(
            full_description=True,
            jobs=True,
            qualifications=True,
        ),
        user_details=create_get_projects_user_details_object(
            basic=True,
            profile_description=True,
            reputation=True,
        ),
    )

    try:
        p = get_projects(session, query)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

# Function to retrieve details of a single project by ID
def sample_get_project_by_id():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    project_id = 15389177
    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

# Function to create a bid for a project
def sample_create_project_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')

    if not all([url, oauth_token, project_id]):
        print("Missing required environment variables.")
        return None

    session = Session(oauth_token=oauth_token)

    bid_data = {
        'project_id': int(project_id),
        'amount': 10,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        return place_project_bid(session, **bid_data)
    except BidNotPlacedException as e:
        print(('Error message: %s' % e.message))
        print(('Error code: %s' % e.error_code))
        return None

# Function to create a milestone payment for a project
def sample_create_milestone_payment():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')
    bidder_id = os.environ.get('BIDDER_ID')

    if not all([url, oauth_token, project_id, bidder_id]):
        print("Missing required environment variables.")
        return None

    try:
        project_id = int(project_id)
        bidder_id = int(bidder_id)
    except (TypeError, ValueError):
        print("Invalid project_id or bidder_id.")
        return None

    session = Session(oauth_token=oauth_token)
    milestone_data = {
        'project_id': project_id,
        'bidder_id': bidder_id,
        'amount': 10,
        'reason': MilestoneReason.PARTIAL_PAYMENT.value,
        'description': 'This is a milestone',
    }

    try:
        m = create_milestone_payment(session, **milestone_data)
    except MilestoneNotCreatedException as e:
        print(('Error message: %s' % e.message))
        print(('Server response: %s' % e.error_code))
        return None
    else:
        return m

# Main program
if __name__ == "__main__":
    # Read environmental variables from CSV
    csv_file_path = 'env_variables.csv'  # Replace with your CSV file path
    env_variables = read_env_variables_from_csv(csv_file_path)

    # Set environmental variables
    for variable, value in env_variables.items():
        os.environ[variable] = value

    print('Searching for projects...')
    projects = sample_search_projects()
    if projects:
        print('Found projects: {}'.format(json.dumps(projects)))

    print('Retrieving details of multiple projects...')
    multiple_projects = sample_get_projects()
    if multiple_projects:
        print('Details of multiple projects: {}'.format(json.dumps(multiple_projects)))

    print('Retrieving details of a single project by ID...')
    single_project = sample_get_project_by_id()
    if single_project:
        print('Details of a single project: {}'.format(json.dumps(single_project)))

    print('Creating a bid for a project...')
    bid_created = sample_create_project_bid()
    if bid_created:
        print('Bid created: {}'.format(bid_created))

    print('Creating a milestone payment...')
    milestone_created = sample_create_milestone_payment()
    if milestone_created:
        print('Milestone created: {}'.format(milestone_created))

# %%
import csv
import os
import json
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import (
    search_projects, get_projects, get_project_by_id, place_project_bid,
    create_milestone_payment
)
from freelancersdk.resources.projects.exceptions import (
    ProjectsNotFoundException, BidNotPlacedException, MilestoneNotCreatedException
)
from freelancersdk.resources.projects.helpers import (
    create_search_projects_filter, create_get_projects_object,
    create_get_projects_project_details_object,
    create_get_projects_user_details_object
)
from freelancersdk.resources.projects.types import MilestoneReason

# Function to extract environmental variables
def extract_env_variables():
    env_variables = {
        'FLN_URL': os.environ.get('FLN_URL', ''),
        'FLN_OAUTH_TOKEN': os.environ.get('FLN_OAUTH_TOKEN', ''),
        'PROJECT_ID': os.environ.get('PROJECT_ID', ''),
        'BIDDER_ID': os.environ.get('BIDDER_ID', '')
    }
    return env_variables

# Function to write environmental variables to a CSV file
def write_env_variables_to_csv(env_variables, csv_file_path):
    with open(csv_file_path, 'w', newline='') as csvfile:
        fieldnames = ['Variable', 'Value']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        writer.writeheader()
        for key, value in env_variables.items():
            writer.writerow({'Variable': key, 'Value': value})

# Main program
if __name__ == "__main__":
    # Extract environmental variables
    env_variables = extract_env_variables()

    # Write environmental variables to CSV file
    csv_file_path = 'env_variables.csv'
    write_env_variables_to_csv(env_variables, csv_file_path)

    print('CSV file created successfully.')

# %%
import csv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import (
    get_projects, get_project_by_id, place_project_bid, create_milestone_payment, search_projects
)
from freelancersdk.resources.projects.helpers import (
    create_get_projects_object, create_get_projects_project_details_object,
    create_get_projects_user_details_object, create_search_projects_filter
)
from freelancersdk.resources.projects.types import MilestoneReason
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException, MilestoneNotCreatedException
from freelancersdk.resources.users import get_self_user_id
from freelancersdk.exceptions import BidNotPlacedException
from tabulate import tabulate
import os
from dotenv import load_dotenv
import json

load_dotenv()

def sample_get_projects_and_project_by_id():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    # Get multiple projects
    query = create_get_projects_object(
        project_ids=[
            201,
            202,
            203,
        ],
        project_details=create_get_projects_project_details_object(
            full_description=True,
            jobs=True,
            qualifications=True,
        ),
        user_details=create_get_projects_user_details_object(
            basic=True,
            profile_description=True,
            reputation=True,
        ),
    )

    try:
        projects = get_projects(session, query)
        if projects:
            print('Found projects: {}'.format(json.dumps(projects)))
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return

    # Get a single project by ID
    project_id = 15389177
    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        single_project = get_project_by_id(session, project_id, project_details, user_details)
        if single_project:
            print('Found a single project: {}'.format(json.dumps(single_project)))
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return

def sample_place_project_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')

    session = Session(oauth_token=oauth_token, url=url)

    try:
        my_user_id = get_self_user_id(session)
    except:
        # User ID not retrieved. Handle the error here, e.g., print an error message.
        return None

    bid_data = {
        'project_id': int(project_id),
        'bidder_id': my_user_id,
        'amount': 20,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        return place_project_bid(session, **bid_data)
    except BidNotPlacedException as e:
        print(('Error message: %s' % e.message))
        print(('Error code: %s' % e.error_code))
        return None

def sample_create_milestone_payment():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')
    bidder_id = os.environ.get('BIDDER_ID')

    if not all([url, oauth_token, project_id, bidder_id]):
        print("Missing required environment variables.")
        return None

    try:
        project_id = int(project_id)
        bidder_id = int(bidder_id)
    except (TypeError, ValueError):
        print("Invalid project_id or bidder_id.")
        return None

    session = Session(oauth_token=oauth_token, url=url)
    milestone_data = {
        'project_id': project_id,
        'bidder_id': bidder_id,
        'amount': 20,
        'reason': MilestoneReason.PARTIAL_PAYMENT.value,
        'description': 'This is a milestone',
    }

    try:
        m = create_milestone_payment(session, **milestone_data)
    except MilestoneNotCreatedException as e:
        print(('Error message: %s' % e.message))
        print(('Server response: %s' % e.error_code))
        return None
    else:
        return m

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    query = 'Logo Design'
    search_filter = create_search_projects_filter(
        sort_field='time_updated',
        or_search_query=True,
    )

    # Add the limit parameter to the search filter
    search_filter['limit'] = 50  # Set the desired limit

    try:
        response = search_projects(
            session,
            query=query,
            search_filter=search_filter
        )

        # Extract the list of projects
        projects = response.get('projects', [])

    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def print_projects_table(projects):
    if not projects:
        print("No projects found.")
        return

    headers = [
        "Project ID", "Owner ID", "Title", "Description", "Budget",
        "Currency Type", "Currency Symbol", "Date Updated", "Status",
        "Deleted", "Nonpublic", "Hide Bids", "Type", "Bid Period",
        "Featured", "Urgent", "Assisted", "Active Prepaid Milestone",
        "Bid Stats: Bid Count", "Bid Stats: Bid Avg",
        "Qualifications", "Language", "Attachments", "Hireme", "Hireme Initial Bid",
        "Invited Freelancers", "Recommended Freelancers", "Frontend Project Status",
        "NDA Signatures",
        "Location: Country: Name", "Location: Country: Flag URL", "Location: Country: Code",
        "Location: Country: Highres Flag URL", "Location: Country: Flag URL CDN",
        "Location: Country: Highres Flag URL CDN", "Location: Country: ISO3",
        "Location: Country: Region ID", "Location: Country: Phone Code",
        "Location: Country: Demonym", "Location: Country: Person",
        "Location: Country: SEO URL", "Location: Country: Sanction",
        "Location: Country: Language Code", "Location: Country: Language ID",
        "Upgrades: Time Free Bids Expire", "Files", "User Distance",
        "From User Location", "Project Collaborations", "Support Sessions",
        "Track IDs", "Drive Files", "NDA Details", "Pool IDs", "Enterprise IDs",
        "Timeframe", "Deloitte Details", "Is Escrow Project", "Is Seller KYC Required",
        "Is Buyer KYC Required", "Local Details", "Equipment", "NDA Signatures New",
        "Billing Code", "Enterprises", "Enterprise Metadata Values",
        "Project Reject Reason: Description", "Project Reject Reason: Message",
        "Repost ID", "Client Engagement", "Contract Signatures", "Quotation ID",
        "Quotation Version ID", "Enterprise Linked Projects Details", "Equipment Groups",
        "Quality Details", "Previous Recruiter Project Details", "Project Note",
        "Is Quotation Project", "Quotation Initial Bid", "Requires Upfront Funding",
        "Group IDs", "Upgrades: Featured", "Upgrades: Sealed", "Upgrades: Nonpublic",
        "Upgrades: Fulltime", "Upgrades: Urgent", "Upgrades: Assisted", "Upgrades: Active Prepaid Milestone",
        "Upgrades: IP Contract", "Upgrades: Success Bundle", "Upgrades: Non Compete",
        "Upgrades: Project Management", "Upgrades: PF Only", "Upgrades: Recruiter",
        "Upgrades: Listed", "Upgrades: Extend", "Upgrades: Unpaid Recruiter",
        "Upgrades: Premium", "Upgrades: Enterprise",
    ]

    # Extract project details into a list of lists
    project_data = []
    for project in projects:
        bid_stats = project.get("bid_stats", {})
        upgrades = project.get("upgrades", {})
        location = project.get("location", {})
        project_reject_reason = project.get("project_reject_reason", {})
        project_row = [
            project.get("id", ""),
            project.get("owner_id", ""),
            project.get("title", ""),
            project.get("description", ""),
            project.get("budget", {}).get("minimum", ""),
            project.get("currency", {}).get("name", ""),
            project.get("currency", {}).get("sign", ""),
            project.get("time_updated", ""),
            project.get("status", ""),
            project.get("deleted", ""),
            project.get("nonpublic", ""),
            project.get("hidebids", ""),
            project.get("type", ""),
            project.get("bidperiod", ""),
            upgrades.get("featured", ""),
            upgrades.get("urgent", ""),
            project.get("assisted", ""),
            project.get("active_prepaid_milestone", ""),
            bid_stats.get("bid_count", ""),
            bid_stats.get("bid_avg", ""),
            project.get("qualifications", ""),
            project.get("language", ""),
            project.get("attachments", ""),
            project.get("hireme", ""),
            project.get("hireme_initial_bid", ""),
            project.get("invited_freelancers", ""),
            project.get("recommended_freelancers", ""),
            project.get("frontend_project_status", ""),
            project.get("nda_signatures", ""),
            location.get("country", {}).get("name", ""),
            location.get("country", {}).get("flag_url", ""),
            location.get("country", {}).get("code", ""),
            location.get("country", {}).get("highres_flag_url", ""),
            location.get("country", {}).get("flag_url_cdn", ""),
            location.get("country", {}).get("highres_flag_url_cdn", ""),
            location.get("country", {}).get("iso3", ""),
            location.get("country", {}).get("region_id", ""),
            location.get("country", {}).get("phone_code", ""),
            location.get("country", {}).get("demonym", ""),
            location.get("country", {}).get("person", ""),
            location.get("country", {}).get("seo_url", ""),
            location.get("country", {}).get("sanction", ""),
            location.get("country", {}).get("language_code", ""),
            location.get("country", {}).get("language_id", ""),
            upgrades.get("time_free_bids_expire", ""),
            project.get("files", ""),
            project.get("user_distance", ""),
            project.get("from_user_location", ""),
            project.get("project_collaborations", ""),
            project.get("support_sessions", ""),
            project.get("track_ids", ""),
            project.get("drive_files", ""),
            project.get("nda_details", ""),
            project.get("pool_ids", ""),
            project.get("enterprise_ids", ""),
            project.get("timeframe", ""),
            project.get("deloitte_details", ""),
            project.get("is_escrow_project", ""),
            project.get("is_seller_kyc_required", ""),
            project.get("is_buyer_kyc_required", ""),
            project.get("local_details", ""),
            project.get("equipment", ""),
            project.get("nda_signatures_new", ""),
            project.get("billing_code", ""),
            project.get("enterprises", ""),
            project.get("enterprise_metadata_values", ""),
            project_reject_reason.get("description", ""),
            project_reject_reason.get("message", ""),
            project.get("repost_id", ""),
            project.get("client_engagement", ""),
            project.get("contract_signatures", ""),
            project.get("quotation_id", ""),
            project.get("quotation_version_id", ""),
            project.get("enterprise_linked_projects_details", ""),
            project.get("equipment_groups", ""),
            project.get("quality_details", ""),
            project.get("previous_recruiter_project_details", ""),
            project.get("project_note", ""),
            project.get("is_quotation_project", ""),
            project.get("quotation_initial_bid", ""),
            project.get("requires_upfront_funding", ""),
            project.get("group_ids", ""),
            upgrades.get("featured", ""),
            upgrades.get("sealed", ""),
            upgrades.get("nonpublic", ""),
            upgrades.get("fulltime", ""),
            upgrades.get("urgent", ""),
            upgrades.get("qualified", ""),
            upgrades.get("active_prepaid_milestone", ""),
            upgrades.get("ip_contract", ""),
            upgrades.get("success_bundle", ""),
            upgrades.get("non_compete", ""),
            upgrades.get("project_management", ""),
            upgrades.get("pf_only", ""),
            upgrades.get("recruiter", ""),
            upgrades.get("listed", ""),
            upgrades.get("extend", ""),
            upgrades.get("unpaid_recruiter", ""),
            upgrades.get("premium", ""),
            upgrades.get("enterprise", ""),
        ]
        project_data.append(project_row)

    # Save the data to CSV
    with open('data.csv', 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(headers)
        csvwriter.writerows(project_data)

    # Print the table
    print(tabulate(project_data, headers=headers, tablefmt="grid"))

# Call the combined functions
print('Getting multiple projects and a single project by ID...')
sample_get_projects_and_project_by_id()

print('Placing a project bid...')
bid_result = sample_place_project_bid()
if bid_result:
    print("Bid placed: {}".format(json.dumps(bid_result)))

print('Creating a milestone payment...')
milestone_result = sample_create_milestone_payment()
if milestone_result:
    print("Milestone created: {}".format(json.dumps(milestone_result)))

print('Searching for projects...')
projects_result = sample_search_projects()
print_projects_table(projects_result)

# %%
import csv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import (
    get_projects, get_project_by_id, place_project_bid, create_milestone_payment, search_projects
)
from freelancersdk.resources.projects.helpers import (
    create_get_projects_object, create_get_projects_project_details_object,
    create_get_projects_user_details_object, create_search_projects_filter
)
from freelancersdk.resources.projects.types import MilestoneReason
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException, MilestoneNotCreatedException
from freelancersdk.resources.users import get_self_user_id
from freelancersdk.exceptions import BidNotPlacedException
from tabulate import tabulate
import os
from dotenv import load_dotenv
import json

load_dotenv()

def sample_get_projects_and_project_by_id():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    # Get multiple projects
    query = create_get_projects_object(
        project_ids=[
            201,
            202,
            203,
        ],
        project_details=create_get_projects_project_details_object(
            full_description=True,
            jobs=True,
            qualifications=True,
        ),
        user_details=create_get_projects_user_details_object(
            basic=True,
            profile_description=True,
            reputation=True,
        ),
    )

    try:
        projects = get_projects(session, query)
        if projects:
            print('Found projects: {}'.format(json.dumps(projects)))
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return

    # Get a single project by ID
    project_id = 15389177
    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        single_project = get_project_by_id(session, project_id, project_details, user_details)
        if single_project:
            print('Found a single project: {}'.format(json.dumps(single_project)))
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return

def sample_place_project_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')

    session = Session(oauth_token=oauth_token, url=url)

    try:
        my_user_id = get_self_user_id(session)
    except:
        # User ID not retrieved. Handle the error here, e.g., print an error message.
        return None

    bid_data = {
        'project_id': int(project_id),
        'bidder_id': my_user_id,
        'amount': 20,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        return place_project_bid(session, **bid_data)
    except BidNotPlacedException as e:
        print(('Error message: %s' % e.message))
        print(('Error code: %s' % e.error_code))
        return None

def sample_create_milestone_payment():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')
    bidder_id = os.environ.get('BIDDER_ID')

    if not all([url, oauth_token, project_id, bidder_id]):
        print("Missing required environment variables.")
        return None

    try:
        project_id = int(project_id)
        bidder_id = int(bidder_id)
    except (TypeError, ValueError):
        print("Invalid project_id or bidder_id.")
        return None

    session = Session(oauth_token=oauth_token, url=url)
    milestone_data = {
        'project_id': project_id,
        'bidder_id': bidder_id,
        'amount': 20,
        'reason': MilestoneReason.PARTIAL_PAYMENT.value,
        'description': 'This is a milestone',
    }

    try:
        m = create_milestone_payment(session, **milestone_data)
    except MilestoneNotCreatedException as e:
        print(('Error message: %s' % e.message))
        print(('Server response: %s' % e.error_code))
        return None
    else:
        return m

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    query = 'Logo Design'
    search_filter = create_search_projects_filter(
        sort_field='time_updated',
        or_search_query=True,
    )

    # Add the limit parameter to the search filter
    search_filter['limit'] = 50  # Set the desired limit

    try:
        response = search_projects(
            session,
            query=query,
            search_filter=search_filter
        )

        # Extract the list of projects
        projects = response.get('projects', [])

    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def print_projects_table(projects):
    if not projects:
        print("No projects found.")
        return

    headers = [
        "Project ID", "Owner ID", "Title", "Description", "Budget",
        "Currency Type", "Currency Symbol", "Date Updated", "Status",
        "Type", "Qualifications", "Language", "Attachments", "Location"
    ]

    # Extract project details into a list of lists
    project_data = []
    for project in projects:
        location = project.get("location", {})
        city = location.get("city", "Unknown")
        country = location.get("country", {}).get("name", "Unknown")
        full_location = f"{city}, {country}"
        project_row = [
            project.get("id", ""),
            project.get("owner_id", ""),
            project.get("title", ""),
            project.get("description", ""),
            project.get("budget", {}).get("minimum", ""),
            project.get("currency", {}).get("name", ""),
            project.get("currency", {}).get("sign", ""),
            project.get("time_updated", ""),
            project.get("status", ""),
            project.get("type", ""),
            project.get("qualifications", ""),
            project.get("language", ""),
            project.get("attachments", ""),
            full_location
        ]
        project_data.append(project_row)

    # Save the data to CSV
    with open('data.csv', 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(headers)
        csvwriter.writerows(project_data)

    # Print the table
    print(tabulate(project_data, headers=headers, tablefmt="grid"))

# Call the combined functions
print('Getting multiple projects and a single project by ID...')
sample_get_projects_and_project_by_id()

print('Placing a project bid...')
bid_result = sample_place_project_bid()
if bid_result:
    print("Bid placed: {}".format(json.dumps(bid_result)))

print('Creating a milestone payment...')
milestone_result = sample_create_milestone_payment()
if milestone_result:
    print("Milestone created: {}".format(json.dumps(milestone_result)))

print('Searching for projects...')
projects_result = sample_search_projects()
print_projects_table(projects_result)

# %%
import os
import csv
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
from tabulate import tabulate
import requests

load_dotenv()

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    try:
        response = search_projects(
            session,
            query='',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )

        # Extract the list of projects
        projects = response.get('projects', [])

    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def generate_project_proposal(project_description):
    openai_api_key = os.environ.get('OPENAI_API_KEY')
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {openai_api_key}'
    }
    data = {
        'prompt': f'Generate a project proposal based on the following description:\n{project_description}\n\nProposal:',
        'max_tokens': 50,
        'n': 1
    }
    try:
        response = requests.post('https://api.openai.com/v1/engines/davinci/completions', json=data, headers=headers)
        response_data = response.json()
        if 'choices' in response_data and len(response_data['choices']) > 0:
            proposal = response_data['choices'][0]['text'].strip()
            return proposal
        else:
            print("Error: No response choices found.")
            return None
    except Exception as e:
        print("Error occurred while accessing OpenAI API:", e)
        return None

def flatten_project_data(project, prefix=''):
    flattened_project = []

    # Sort keys for consistent order
    sorted_keys = sorted(project.keys())

    for key in sorted_keys:
        value = project[key]
        if isinstance(value, dict):
            flattened_project.extend(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        else:
            flattened_project.append((f"{prefix}_{key}", value))

    return flattened_project

def print_projects_table(projects):
    if not projects:
        print("No projects found.")
        return

    modified_project_data = [flatten_project_data(project) for project in projects]

    headers = set()
    for project_data in modified_project_data:
        headers.update([key for key, _ in project_data])

    headers = sorted(headers) + ['project_proposal']  # Add project_proposal column to headers

    table_data = []
    for project_data in modified_project_data:
        row_data = {key: value for key, value in project_data}
        project_description = ", ".join(f"{key}: {value}" for key, value in project_data)
        proposal = generate_project_proposal(project_description)
        table_data.append([row_data.get(header, '') for header in sorted(headers[:-1])] + [proposal])

    print(tabulate(table_data, headers=headers, tablefmt="grid"))

p = sample_search_projects()
print_projects_table(p)

# %%
import os
import csv
import json
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import (
    search_projects, get_projects, get_project_by_id, place_project_bid
)
from freelancersdk.resources.projects.exceptions import (
    ProjectsNotFoundException, MilestoneNotCreatedException, BidNotPlacedException
)
from freelancersdk.resources.projects import create_milestone_payment
from freelancersdk.resources.projects.types import MilestoneReason
from freelancersdk.resources.projects.helpers import (
    create_get_projects_object, create_get_projects_project_details_object,
    create_get_projects_user_details_object
)
from freelancersdk.resources.users import get_self_user_id
import random  # For generating unique proposals

load_dotenv()


def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    try:
        response = search_projects(
            session,
            query='',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )

        # Extract the list of projects
        projects = response.get('projects', [])

    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects


def flatten_project_data(project, prefix=''):
    flattened_project = {}

    # Sort keys for consistent order
    sorted_keys = sorted(project.keys())

    for key in sorted_keys:
        value = project[key]
        if isinstance(value, dict):
            # Recursively flatten nested dictionaries
            flattened_subproject = flatten_project_data(value, prefix=f"{prefix}{'' if prefix == '' else '_'}{key}")
            flattened_project.update(flattened_subproject)
        else:
            flattened_project[f"{prefix}{'' if prefix == '' else '_'}{key}"] = value

    # Print project title for debugging
    print("Project title:", project.get('title'))

    flattened_project["project_proposal"] = generate_unique_proposal(project)
    return flattened_project


def generate_unique_proposal(project):
    print("Generating proposal for project:", project.get('title'))  # Debug print statement
    title = project.get('title', 'Untitled Project')  # Get the project title or use a default value
    proposal_template = f"Complete {title} within budget and timeline. Offer expert [insert relevant skill]."  # Customize template
    unique_identifier = random.randint(1000, 9999)  # Generate a unique identifier
    return f"{proposal_template} {unique_identifier}"[:100]  # Truncate to 100 characters


def save_projects_to_csv(projects, filename):
    if not projects:
        print("No projects found.")
        return

    # Flatten the project data for CSV writing
    flattened_projects = [flatten_project_data(project) for project in projects]

    # Get all unique headers
    headers = set()
    for project_data in flattened_projects:
        headers.update(project_data.keys())

    # Write data to CSV file
    with open(filename, 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=sorted(headers))
        writer.writeheader()

        for project_data in flattened_projects:
            writer.writerow(project_data)

    print(f"Projects data saved to {filename}")


def sample_create_milestone_payment(project_id, bidder_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')

    if not all([url, oauth_token, project_id, bidder_id]):
        print("Missing required environment variables.")
        return None

    try:
        project_id = int(project_id)
        bidder_id = int(bidder_id)
    except (TypeError, ValueError):
        print("Invalid project_id or bidder_id.")
        return None

    session = Session(oauth_token=oauth_token, url=url)
    milestone_data = { 
        'project_id': project_id,
        'bidder_id': bidder_id,
        'amount': 10,
    }


if __name__ == "__main__":
    # Sample usage: Search for projects and save them to a CSV file
    projects = sample_search_projects()
    save_projects_to_csv(projects, "projects.csv")

# %%
import os
import csv
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
from tabulate import tabulate
import random
import string

load_dotenv()

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)

    try:
        response = search_projects(
            session,
            query='',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )

        # Extract the list of projects
        projects = response.get('projects', [])

    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def generate_related_proposal(project_title):
    random_sentence = " ".join([''.join(random.choices(string.ascii_lowercase, k=random.randint(3, 8))) for _ in range(random.randint(5, 10))])
    proposal = f"{random_sentence} related to {project_title}"
    return proposal[:100]  # Truncate to 100 characters if needed

def flatten_project_data(project, prefix=''):
    flattened_project = []

    # Sort keys for consistent order
    sorted_keys = sorted(project.keys())

    for key in sorted_keys:
        value = project[key]
        if isinstance(value, dict):
            flattened_project.extend(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        else:
            flattened_project.append((f"{prefix}_{key}", value))

    return flattened_project

def print_projects_table(projects):
    if not projects:
        print("No projects found.")
        return

    modified_project_data = [flatten_project_data(project) for project in projects]

    headers = set()
    for project_data in modified_project_data:
        headers.update([key for key, _ in project_data])

    headers = sorted(headers) + ['Project Proposal']  # Add the new column header

    table_data = []
    for project_data in modified_project_data:
        row_data = {key: value for key, value in project_data}
        proposal = generate_related_proposal(row_data.get('Project_Title', ''))
        row_data['Project Proposal'] = proposal
        table_data.append([row_data.get(header, '') for header in headers])

    print(tabulate(table_data, headers=headers, tablefmt="grid"))

    # Write to CSV file
    with open('projects_with_proposals.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(headers)
        writer.writerows(table_data)

p = sample_search_projects()
print_projects_table(p)

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='',  # Empty query to retrieve all projects
            limit=5  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:  # Exclude keys with None values
            # Remove the underscore (_) only if it's at the beginning of the key
            key = key.lstrip('_')
            flattened_data[key] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # Implement logic to generate proposals using Google AI Studio or other services
    # You will need to provide the project data to the model and retrieve the generated proposal
    # For simplicity, let's assume the proposal is generated as "Sample proposal"
    # set api key and api endpoint
    load_dotenv()
    api_key = ''
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    # generate the prompt to get my proposal
    prompt = f"Generate a proposal for a project titled {project_title} with a description of {project_description}."
    # prepare the reuest body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    print(f"Generated proposal: {proposal}")
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    valid_projects = []
    for project in projects:
        project_title = project['title']
        project_description = project['preview_description']
        proposal = generate_proposal(project_title, project_description)
        if proposal:
            proposals.append(proposal)
            valid_projects.append(project)
    if not valid_projects:
        print("No projects with proposals found.")
        return

    flattened_projects = [flatten_project_data(project) for project in valid_projects]
    df = pd.DataFrame(flattened_projects)
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: **Project Proposal: Automobile Business Revamp Consultant**
#
# **Introduction**
#
# The automobile industry is undergoing a major transformation, driven by the rise of electric vehicles, autonomous driving, and shared mobility. As a result, traditional automakers are facing increasing pressure to adapt their business models or risk being left behind.
#
# **Problem Statement**
#
# My client, a leading automaker, is facing a number of challenges that are threatening its long-term viability. These challenges include:
#
# * Declining sales of traditional gasoline-powered vehicles
# * Increased competition from new entrants, such as Tesla and Rivian
# * Rising costs of research and development
# * Changing consumer preferences
#
# **Solution**
#
# I believe that the best way to address these challenges is to revamp the company's business model. This will require a comprehensive approach that addresses all of the key areas of the business, including:
#
# * Product development
# * Marketing and sales
# * Operations
# * Finance
#
# **Project Scope**
#
# The project will be completed in three phases:
#
# * Phase 1: Assessment
# * Phase 2: Development
# * Phase 3: Implementation
#
# **Phase 1: Assessment**
#
# The first phase of the project will involve a comprehensive assessment of the company's current business model. This will include an analysis of the company's strengths and weaknesses, as well as an assessment of the opportunities and threats facing the industry.
#
# **Phase 2: Development**
#
# The second phase of the project will involve the development of a new business model that addresses the challenges facing the company. This will involve developing new products and services, as well as new marketing and sales strategies.
#
# **Phase 3: Implementation**
#
# The third phase of the project will involve the implementation of the new business model. This will include making changes to the company's operations, as well as its financial structure.
#
# **Timeline**
#
# The project is expected to take 12 months to complete.
#
# **Budget**
#
# The total cost of the project is estimated to be \$10 million.
#
# **Benefits**
#
# The successful completion of this project will result in a number of benefits for the company, including:
#
# * Increased sales of new products and services
# * Improved customer satisfaction
# * Reduced costs
# * Increased profitability
#
# **Conclusion**
#
# I believe that this project is essential for the long-term success of my client. By revamping its business model, the company can address the challenges facing the industry and position itself for future growth.
#
# **I am confident that I have the skills and experience necessary to successfully complete this project. I have a proven track record of working with businesses of all sizes to help them achieve their goals. I am also a strong believer in the importance of innovation and creativity, and I am confident that I can help my client develop a new business model that will be a success.**
# Proposal saved to proposal.txt
# Generated proposal: **Project for Md Deluwar H. -- 3**
#
# **Project Description**
#
# This project will develop a new mobile app that allows users to track their spending and savings. The app will provide users with a variety of features, including:
#
# * The ability to create a budget and track their spending against it
# * The ability to set savings goals and track their progress towards them
# * The ability to receive alerts and notifications about their spending and savings
# * The ability to connect with other users to share tips and advice
#
# The app will be developed using the latest mobile technologies and will be available on both Android and iOS devices.
#
# **Project Objectives**
#
# The objectives of this project are to:
#
# * Develop a mobile app that is easy to use and accessible to a wide range of users
# * Provide users with the tools they need to track their spending and savings
# * Help users to set and achieve their financial goals
# * Encourage users to save money and improve their financial well-being
#
# **Project Timeline**
#
# The project will be completed in three phases:
#
# * Phase 1: Requirements gathering and design (2 weeks)
# * Phase 2: Development (6 weeks)
# * Phase 3: Testing and deployment (4 weeks)
#
# The project is expected to be completed by **March 1, 2023**.
#
# **Project Budget**
#
# The total budget for the project is \$100,000. This budget includes the costs of:
#
# * Software development
# * Marketing and promotion
# * Customer support
#
# **Project Team**
#
# The project team will consist of the following members:
#
# * Project manager
# * Software engineer
# * UX designer
# * Marketing manager
# * Customer support representative
#
# **Project Risks**
#
# The following risks have been identified for this project:
#
# * The app may not be easy to use or accessible to a wide range of users
# * The app may not provide users with the tools they need to track their spending and savings
# * The app may not be able to help users to set and achieve their financial goals
# * The app may not be able to encourage users to save money and improve their financial well-being
#
# **Project Mitigation Strategies**
#
# The following mitigation strategies have been developed to address the risks identified above:
#
# * The project team will conduct user research to ensure that the app is easy to use and accessible to a wide range of users
# * The project team will work with financial experts to ensure that the app provides users with the tools they need to track their spending and savings
# * The project team will develop a marketing and promotion plan to encourage users to download and use the app
# * The project team will provide customer support to help users get the most out of the app
#
# **Project Approvals**
#
# The project will be approved by the following stakeholders:
#
# * CEO
# * CFO
# * CTO
#
# **Project Documentation**
#
# The following documentation will be created for the project:
#
# * Project charter
# * Project plan
# * Requirements specification
# * Design documentation
# * Test plan
# * Deployment plan
# * User guide
#
# **Project Communication Plan**
#
# The following communication plan will be used for the project:
#
# * Weekly status meetings
# * Monthly progress reports
# * Biweekly team meetings
# * Quarterly stakeholder meetings
#
# **Project Closure**
#
# The project will be closed when all of the following criteria have been met:
#
# * The app has been developed and tested
# * The app has been deployed to the App Store and Google Play
# * The app has been approved by the stakeholders
#
# The project team will hold a final meeting to review the project and close out all open tasks.
# Proposal saved to proposal.txt
# Error: The API response does not contain the expected data.
# Generated proposal: **Project Title:** Website Redesign
#
# **Client:** [Your Name]
#
# **Project Overview:**
#
# The purpose of this project is to redesign the client's website in order to improve its user experience, visual appeal, and search engine optimization (SEO). The new website should be more user-friendly, visually appealing, and easier to find on search engines.
#
# **Project Requirements:**
#
# The new website should:
#
# * Be responsive and mobile-friendly
# * Use a clean and modern design
# * Be easy to navigate
# * Use clear and concise language
# * Be optimized for SEO
#
# **Project Timeline:**
#
# The project will be completed in four phases:
#
# 1. **Design Phase:** The designer will create a new design for the website, based on the client's feedback. This phase will take approximately two weeks.
# 2. **Development Phase:** The developer will build the new website using the design created in the design phase. This phase will take approximately four weeks.
# 3. **Testing Phase:** The website will be tested to ensure that it is working properly and that it meets the client's requirements. This phase will take approximately one week.
# 4. **Deployment Phase:** The new website will be deployed to the client's server. This phase will take approximately one day.
#
# **Project Budget:**
#
# The total cost of the project is \$5,000. This includes the cost of design, development, testing, and deployment.
#
# **Project Team:**
#
# The project team will consist of a designer, a developer, and a project manager. The project manager will be responsible for coordinating the project and ensuring that it is completed on time and within budget. The designer will be responsible for creating the new design for the website. The developer will be responsible for building the new website using the design created by the designer.
#
# **Project Risks:**
#
# There are a number of risks associated with this project, including:
#
# * The client may not be satisfied with the final design.
# * The website may not be completed on time or within budget.
# * The website may not be optimized for SEO.
#
# **Project Mitigation Strategies:**
#
# The following mitigation strategies will be used to address the risks associated with this project:
#
# * The client will be involved in the design process to ensure that they are satisfied with the final product.
# * The project manager will create a detailed project plan and will track the project's progress closely.
# * The developer will use a variety of SEO techniques to ensure that the website is optimized for search engines.
#
# **Project Approvals:**
#
# The following approvals will be required before the project can be completed:
#
# * The client must approve the final design of the website.
# * The client must approve the final cost of the project.
#
# **Project Documentation:**
#
# The following documentation will be created as part of the project:
#
# * Project charter
# * Project plan
# * Design specifications
# * Development specifications
# * Testing plan
# * Deployment plan
#
# **Project Communication Plan:**
#
# The following communication plan will be used to keep the client informed about the progress of the project:
#
# * The project manager will hold weekly status meetings with the client.
# * The project manager will send the client weekly progress reports.
# * The client will be able to contact the project manager at any time with questions or concerns.
#
# **Project Conclusion:**
#
# The project will be considered a success if the following criteria are met:
#
# * The client is satisfied with the final design of the website.
# * The website is completed on time and within budget.
# * The website is optimized for SEO.
#
# **Project Signatures:**
#
# Client Signature: ________________________
#
# Date: ________________________
#
# Project Manager Signature: ________________________
#
# Date: ________________________
# Proposal saved to proposal.txt
# Generated proposal: **Project Proposal**
#
# **Project Title:** Minimalist Logo Design for Online Use
#
# **Project Description:**
#
# We are in need of an experienced graphic designer to craft a minimalistic logo focused particularly for online use. The logo will be used for our website, social media, and other marketing materials.
#
# **Project Requirements:**
#
# The logo must be:
#
# * Simple and easy to remember
# * Distinctive and memorable
# * Suitable for use in both black and white and color
# * Suitable for use on a variety of different platforms, including websites, social media, and print materials
#
# **Project Timeline:**
#
# The project must be completed within 2 weeks.
#
# **Project Budget:**
#
# The budget for this project is \$500.
#
# **Project Deliverables:**
#
# The final deliverables for this project will include:
#
# * A 100px x 100px version of the logo in black and white
# * A 200px x 200px version of the logo in color
# * A 300px x 300px version of the logo in color
# * A high-resolution version of the logo in EPS format
#
# **Project Approvals:**
#
# The project will be approved by the CEO of our company.
#
# **Project Risks:**
#
# The main risks associated with this project are:
#
# * The logo may not be as simple and easy to remember as we would like.
# * The logo may not be distinctive and memorable enough.
# * The logo may not be suitable for use on a variety of different platforms.
#
# **Project Mitigation Strategies:**
#
# We will mitigate these risks by:
#
# * Working closely with the graphic designer to ensure that the logo meets our requirements.
# * Conducting a thorough review of the final logo before approving it.
#
# **Project Benefits:**
#
# The successful completion of this project will provide the following benefits:
#
# * A minimalistic logo that is simple, easy to remember, distinctive, and memorable.
# * A logo that is suitable for use on a variety of different platforms.
# * A logo that will help us to build our brand and reach new customers.
#
# **Project Conclusion:**
#
# We believe that this project is a valuable investment that will help us to achieve our business goals. We are confident that the graphic designer we select will be able to create a logo that meets our requirements and helps us to achieve success.
# Proposal saved to proposal.txt
#    id  owner_id                                  title  status  \
# 0  11  75028273  Automobile Business Revamp Consultant  active
# 1   1  62369765         Project for Md Deluwar H. -- 3  frozen
# 2   1  65152310                  website redesign -- 2  active
# 3   1  73974107  Minimalist Logo Design for Online Use  active
#
#                                            seo_url code sign          name  \
# 0  marketing/Automobile-Business-Revamp-Consultant  INR    ₹  Indian Rupee
# 1   article-rewriting/Project-for-Deluwar-37862050  USD    $     US Dollar
# 2                    php/website-redesign-37862047  USD    $     US Dollar
# 3    logo-design/Minimalist-Logo-Design-for-Online  USD    $     US Dollar
#
#    exchange_rate country  ...      pool_ids  enterprise_ids  \
# 0       0.012084      IN  ...  [freelancer]              []
# 1       1.000000      US  ...  [freelancer]              []
# 2       1.000000      US  ...  [freelancer]              []
# 3       1.000000      US  ...  [freelancer]              []
#
#    is_escrow_project is_seller_kyc_required  is_buyer_kyc_required  \
# 0              False                  False                  False
# 1              False                  False                  False
# 2              False                  False                  False
# 3              False                  False                  False
#
#    enterprises  group_ids      sub_status     bid_avg  \
# 0           []         []             NaN         NaN
# 1           []         []  frozen_awarded  200.000000
# 2           []         []             NaN   20.000000
# 3           []         []             NaN   21.727273
#
#                                             proposal
# 0  **Project Proposal: Automobile Business Revamp...
# 1  **Project for Md Deluwar H. -- 3**\n\n**Projec...
# 2  **Project Title:** Website Redesign\n\n**Clien...
# 3  **Project Proposal**\n\n**Project Title:** Min...
#
# [4 rows x 52 columns]
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=5,  # You can adjust the limit as needed
            active_only=True  # Set to True to only retrieve active projects 
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:  # Exclude keys with None values
            # Remove the underscore (_) only if it's at the beginning of the key
            key = key.lstrip('_')
            flattened_data[key] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # Implement logic to generate proposals using Google AI Studio or other services
    # You will need to provide the project data to the model and retrieve the generated proposal
    # For simplicity, let's assume the proposal is generated as "Sample proposal"
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    # generate the prompt to get my proposal
    prompt = f"Generate a proposal for a project titled {project_title} with a description of {project_description}."
    # prepare the reuest body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    print(f"Generated proposal: {proposal}")
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def get_common_usd_values(minimum, maximum, exchange_rate, code):
    # You can define your logic here to calculate common USD values
    # For example, you might want to convert minimum and maximum using the exchange rate
    # and append the code for identification
    # Here's a simple example:
    common_usd_values = {
        "Minimum_USD": minimum * exchange_rate,
        "Maximum_USD": maximum * exchange_rate,
        "Exchange_Rate": exchange_rate,
        "Currency_Code": code
    }
    return common_usd_values

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    valid_projects = []
    for project in projects:
        project_title = project['title']
        project_description = project['preview_description']
        proposal = generate_proposal(project_title, project_description)
        if proposal:
            proposals.append(proposal)
            valid_projects.append(project)
    if not valid_projects:
        print("No projects with proposals found.")
        return

    flattened_projects = [flatten_project_data(project) for project in valid_projects]
    df = pd.DataFrame(flattened_projects)
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame

    # Create the new column "common USD values"
    common_usd_values = []
    for index, row in df.iterrows():
        minimum = row['minimum']
        maximum = row['maximum']
        exchange_rate = row['exchange_rate']
        code = row['code']
        common_usd_values.append(get_common_usd_values(minimum, maximum, exchange_rate, code))
    
    # Convert the common_usd_values list to DataFrame
    common_usd_values_df = pd.DataFrame(common_usd_values)
    
    # Concatenate the original DataFrame and the DataFrame containing common USD values
    df = pd.concat([df, common_usd_values_df], axis=1)
    
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: **Project Proposal: Dynamic Forex Trading Indicator Software**
#
# **Introduction**
#
# The foreign exchange (forex) market is the largest and most liquid financial market in the world, with an estimated daily trading volume of over $5 trillion. This makes it an attractive market for traders of all experience levels, but it can also be a very challenging one. One of the key challenges for forex traders is finding the right tools to help them make informed trading decisions.
#
# **Problem Statement**
#
# There are a number of different forex trading indicators available, but many of them are static, meaning that they only provide a snapshot of the market at a given moment in time. This can be limiting, as the forex market is constantly changing. A dynamic forex trading indicator, on the other hand, is able to track the changes in the market and provide traders with more up-to-date information.
#
# **Solution**
#
# This project proposes to develop a dynamic forex trading indicator software tool that will use Python and machine learning to provide traders with real-time insights into the market. The tool will be able to track a variety of different indicators, including technical indicators, fundamental indicators, and sentiment indicators. It will also be able to generate alerts based on predefined criteria, such as when a certain indicator crosses a certain threshold.
#
# **Benefits of the Proposed Solution**
#
# The proposed solution would have a number of benefits for forex traders, including:
#
# * Improved trading performance: By providing traders with real-time insights into the market, the tool would help them to make more informed trading decisions. This could lead to improved trading performance and increased profits.
# * Reduced risk: By tracking a variety of different indicators, the tool would help traders to identify potential risks and take steps to mitigate those risks. This could help to protect traders from losing money.
# * Increased efficiency: The tool would automate many of the tasks involved in forex trading, such as generating alerts and calculating risk. This would free up traders' time so that they can focus on other aspects of their trading.
#
# **Project Requirements**
#
# The proposed solution would require the following:
#
# * A team of experienced Python developers and forex traders
# * Access to historical forex data
# * A machine learning algorithm that is able to track and analyze forex market data
# * A user-friendly interface that allows traders to easily input their own parameters and track the performance of the tool
#
# **Project Timeline**
#
# The proposed solution could be developed in six months to one year, depending on the size and complexity of the team.
#
# **Project Budget**
#
# The total cost of the project would depend on the size and complexity of the team, as well as the cost of the software development tools and hardware. A ballpark estimate would be between \$50,000 and \$100,000.
#
# **Conclusion**
#
# The proposed solution would provide a number of benefits for forex traders, including improved trading performance, reduced risk, and increased efficiency. The project could be completed in six months to one year, with a total cost of between \$50,000 and \$100,000.
# Proposal saved to proposal.txt
# Generated proposal: **Project Proposal**
#
# **Project Title:** Python Developer for Compensation Insurance Tool
#
# **Project Description:**
#
# As an insurance provider, I am currently in need of an experienced Python developer to enhance our compensation insurance tool. The tool is used to calculate the amount of compensation that should be paid to a policyholder in the event of a claim. The developer will be responsible for improving the tool's performance and adding new features, such as the ability to handle more complex claims and to generate reports.
#
# **Project Goals:**
#
# The goals of this project are to:
#
# * Improve the tool's performance so that it can handle more complex claims more quickly.
# * Add new features to the tool, such as the ability to generate reports.
# * Make the tool more user-friendly.
#
# **Project Scope:**
#
# The project will involve the following tasks:
#
# * Improving the tool's performance by optimizing the code and using more efficient algorithms.
# * Adding new features to the tool, such as the ability to generate reports.
# * Making the tool more user-friendly by improving the user interface and documentation.
#
# **Project Schedule:**
#
# The project will be completed in three phases:
#
# * Phase 1: Improving the tool's performance (4 weeks)
# * Phase 2: Adding new features to the tool (6 weeks)
# * Phase 3: Making the tool more user-friendly (2 weeks)
#
# **Project Budget:**
#
# The total budget for the project is \$50,000.
#
# **Project Team:**
#
# The project team will consist of the following members:
#
# * Project Manager
# * Python Developer
# * QA Engineer
#
# **Project Risks:**
#
# The following are some of the risks associated with this project:
#
# * The tool may not perform as expected, which could lead to delays in processing claims.
# * The tool may not be user-friendly, which could lead to users making errors when entering data.
# * The project may not be completed on time or within budget.
#
# **Project Mitigation Strategies:**
#
# The following mitigation strategies will be used to address the risks associated with this project:
#
# * The tool will be thoroughly tested before it is released to users.
# * The tool will be designed to be user-friendly and easy to use.
# * The project will be closely monitored to ensure that it is completed on time and within budget.
#
# **Project Benefits:**
#
# The completion of this project will provide the following benefits:
#
# * Improved performance of the compensation insurance tool, which will lead to faster processing of claims.
# * New features for the compensation insurance tool, which will make it more versatile and user-friendly.
# * A more user-friendly compensation insurance tool, which will reduce the risk of errors being made when entering data.
#
# **Project Approval:**
#
# I request approval for this project so that we can improve the compensation insurance tool and provide better service to our policyholders.
# Proposal saved to proposal.txt
# Generated proposal: paf files **Project Proposal**
#
# **Project Title:** Medical Palanogram Item Count Python Tool
#
# **Project Description:**
#
# I am in need of a skilled Python developer to create a tool that can analyze and count items within .paf files. These files are typically large and contain a lot of data, so it is important that the tool be efficient and accurate. The tool should be able to count the number of items in each file, as well as the total number of items across all files. It should also be able to identify the different types of items in the files.
#
# **Project Requirements:**
#
# The tool should be written in Python and should be compatible with Python 3. It should be able to read .paf files from a variety of sources, including local files, network drives, and cloud storage. The tool should be able to count the number of items in each file, as well as the total number of items across all files. It should also be able to identify the different types of items in the files. The tool should be efficient and accurate, and it should be easy to use.
#
# **Project Timeline:**
#
# The project should be completed within 6 weeks.
#
# **Project Budget:**
#
# The budget for the project is \$10,000.
#
# **Project Team:**
#
# The project team will consist of a project manager, a Python developer, and a QA engineer.
#
# **Project Risks:**
#
# The main risks associated with this project are that the tool will not be completed on time or within budget, or that it will not meet the requirements. To mitigate these risks, the project manager will closely monitor the progress of the project and will make adjustments as needed. The Python developer will be experienced in working with Python and will be able to create a tool that meets the requirements. The QA engineer will test the tool thoroughly to ensure that it is accurate and efficient.
#
# **Project Benefits:**
#
# The successful completion of this project will provide a number of benefits, including:
#
# * The ability to analyze and count items within .paf files more efficiently and accurately.
# * The ability to identify the different types of items in .paf files.
# * The ability to save time and money.
#
# **Project Approval:**
#
# I approve this project and authorize the project manager to begin the work.
#
# **Project Signature:**
#
# [Your Signature]
#
# **Date:**
#
# [Today's Date]
# Proposal saved to proposal.txt
# Generated proposal: **Project Proposal**
#
# **Project Title:** Python Code Bug Fixes
#
# **Project Overview:**
#
# This project will focus on fixing bugs in existing Python code. The goal is to improve the quality of the code and to make it more reliable. The project will be completed remotely, and all communication will be done via email and online collaboration tools.
#
# **Project Scope:**
#
# The scope of this project includes fixing all bugs that are found in the existing Python code. The bugs will be identified by the project team, and they will be fixed in a timely and efficient manner. The project will be completed within a six-month timeframe.
#
# **Project Deliverables:**
#
# The project will result in the following deliverables:
#
# * A list of all bugs that were found in the existing Python code
# * A plan for how the bugs will be fixed
# * A timeline for completing the project
# * The fixed Python code
#
# **Project Resources:**
#
# The project will require the following resources:
#
# * A team of experienced Python developers
# * Access to the existing Python code
# * A collaborative development environment
# * A testing environment
#
# **Project Budget:**
#
# The project budget is \$100,000.
#
# **Project Risks:**
#
# The following risks have been identified for this project:
#
# * The project may not be completed on time or within budget.
# * The bugs may not be fixed correctly, which could lead to problems with the code.
# * The project team may not be able to work effectively remotely.
#
# **Project Mitigation Strategies:**
#
# The following mitigation strategies have been developed to address the risks identified above:
#
# * The project will be closely monitored to ensure that it stays on track.
# * The project team will be given the resources they need to complete the project successfully.
# * The project team will be trained on how to work effectively remotely.
#
# **Project Approvals:**
#
# This project has been approved by the following stakeholders:
#
# * [Name of stakeholder 1]
# * [Name of stakeholder 2]
# * [Name of stakeholder 3]
#
# **Project Timeline:**
#
# The project will be completed in the following phases:
#
# * Phase 1: Identification of bugs (2 weeks)
# * Phase 2: Planning for bug fixes (2 weeks)
# * Phase 3: Fixing bugs (4 months)
# * Phase 4: Testing (2 weeks)
#
# **Project Communication Plan:**
#
# The project team will communicate with each other and with stakeholders using the following methods:
#
# * Email
# * Online collaboration tools
# * Project meetings
#
# **Project Documentation:**
#
# The project team will create the following documentation:
#
# * A project plan
# * A risk management plan
# * A communication plan
# * A testing plan
# * A final report
#
# **Project Approvals:**
#
# This project has been approved by the following stakeholders:
#
# * [Name of stakeholder 1]
# * [Name of stakeholder 2]
# * [Name of stakeholder 3]
# Proposal saved to proposal.txt
# Generated proposal: **Project Proposal**
#
# **Project Title:** Python Developer for GNNs with PyTorch
#
# **Project Description:**
#
# I am looking for a skilled Python developer with experience in PyTorch to work on a graph neural network (GNN) project. The goal of this project is to develop a GNN-based model for natural language processing (NLP). GNNs are a type of deep learning model that is specifically designed for working with graph-structured data. They have been shown to be effective for a variety of NLP tasks, such as text classification, sentiment analysis, and natural language inference.
#
# The successful candidate will have a strong understanding of Python and PyTorch. They will also have experience working with graph-structured data and NLP. The ideal candidate will be highly motivated and have a strong desire to learn new things.
#
# **Project Timeline:**
#
# The project is expected to take six months to complete. The first three months will be spent on research and development. The remaining three months will be spent on implementing the model and evaluating its performance.
#
# **Project Budget:**
#
# The total budget for the project is \$100,000. This includes the cost of the developer's salary, as well as the cost of hardware and software.
#
# **Project Deliverables:**
#
# The successful candidate will be responsible for developing a GNN-based model for NLP. The model will be evaluated on a variety of benchmark datasets. The candidate will also be responsible for writing a technical report that describes the project and its results.
#
# **Project Success Metrics:**
#
# The success of this project will be measured by the following metrics:
#
# * The accuracy of the model on a variety of benchmark datasets
# * The efficiency of the model
# * The scalability of the model
# * The interpretability of the model
#
# **Project Risks:**
#
# The main risks associated with this project are:
#
# * The model may not perform as well as expected
# * The model may not be scalable to large datasets
# * The model may not be interpretable
#
# **Project Mitigation Strategies:**
#
# The following mitigation strategies will be used to address the risks associated with this project:
#
# * The model will be evaluated on a variety of benchmark datasets to ensure that it performs well
# * The model will be designed to be scalable to large datasets
# * The model will be developed with interpretability in mind
#
# **Project Team:**
#
# The project team will consist of the following members:
#
# * Project Manager
# * Developer
# * Data Scientist
# * QA Engineer
#
# **Project Communication Plan:**
#
# The project team will use the following communication channels to stay in touch:
#
# * Email
# * Slack
# * Zoom
#
# **Project Approvals:**
#
# The project will be approved by the following stakeholders:
#
# * CEO
# * CTO
# * VP of Engineering
#
# **Project Documentation:**
#
# The following documentation will be created for the project:
#
# * Project Plan
# * Technical Specifications
# * User Manual
# * Test Plan
# * Deployment Plan
#
# **Project Conclusion:**
#
# This project has the potential to make a significant contribution to the field of NLP. The successful candidate will have the opportunity to work on cutting-edge research and develop a new technology that has the potential to change the world.
# Proposal saved to proposal.txt
#    id  owner_id                                             title  status  \
# 0   1  29233034          Dynamic Forex Trading Indicator Software  active
# 1   1  48814064  Python Developer for Compensation Insurance Tool  active
# 2   1  63640411         Medical Palanogram Item Count Python Tool  active
# 3  11  56413671                            Python code bug fixes   active
# 4   4  66507133            Python Developer for GNNs with PyTorch  active
#
#                                            seo_url code sign            name  \
# 0  python/Dynamic-Forex-Trading-Indicator-Software  USD    $       US Dollar
# 1         python/Python-Developer-for-Compensation  USD    $       US Dollar
# 2      python/Medical-Palanogram-Item-Count-Python  USD    $       US Dollar
# 3                 python/Python-bug-fixes-37861963  INR    ₹    Indian Rupee
# 4            python/Python-Developer-for-GNNs-with  GBP    £  British Pounds
#
#    exchange_rate country  ...  is_escrow_project  is_seller_kyc_required  \
# 0       1.000000      US  ...              False                   False
# 1       1.000000      US  ...              False                   False
# 2       1.000000      US  ...              False                   False
# 3       0.012084      IN  ...              False                   False
# 4       1.285800      UK  ...              False                   False
#
#    is_buyer_kyc_required enterprises  group_ids  \
# 0                  False          []         []
# 1                  False          []         []
# 2                  False          []         []
# 3                  False          []         []
# 4                  False          []         []
#
#                                             proposal  Minimum_USD Maximum_USD  \
# 0  **Project Proposal: Dynamic Forex Trading Indi...      40.0000    150.0000
# 1  **Project Proposal**\n\n**Project Title:** Pyt...      50.0000    100.0000
# 2  paf files **Project Proposal**\n\n**Project Ti...      10.0000     30.0000
# 3  **Project Proposal**\n\n**Project Title:** Pyt...       7.2504      9.6672
# 4  **Project Proposal**\n\n**Project Title:** Pyt...      25.7160    321.4500
#
#    Exchange_Rate  Currency_Code
# 0       1.000000            USD
# 1       1.000000            USD
# 2       1.000000            USD
# 3       0.012084            INR
# 4       1.285800            GBP
#
# [5 rows x 55 columns]
# DataFrame saved to projects_with_proposals.csv

# %%
# add another column multiplying budget_max

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='',  # Empty query to retrieve all projects
            limit=3 # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
                flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def convert_to_usd(value, exchange_rate):
    return value * exchange_rate

def calculate_common_usd_values(min_budget_usd, max_budget_usd):
    # You can define your own logic here for common USD values
    return (min_budget_usd + max_budget_usd) / 2

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    common_usd_values = []  # List to store common USD values for each project
    for project in projects:
        print(project)  # Add this line for debugging
        project_title = project.get('_title', 'Unknown Title')  # Use .get() method to handle KeyError
        project_description = project.get('_preview_description', 'Unknown Description')  # Use .get() method to handle KeyError
        proposal = generate_proposal(project_title, project_description)
        if proposal is not None:
            proposals.append(proposal)
            # Convert budget to USD
            min_budget_usd = convert_to_usd(project.get('_budget_minimum', 0), project.get('_currency_exchange_rate', 1.0))
            max_budget_usd = convert_to_usd(project.get('_budget_maximum', 0), project.get('_currency_exchange_rate', 1.0))
            # Calculate common USD value
            common_usd_value = calculate_common_usd_values(min_budget_usd, max_budget_usd)
            common_usd_values.append(common_usd_value)

    if not proposals:
        print("No valid proposals generated.")
        return

    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)

    selected_columns = [
        '_id', '_title', '_status', '_budget_minimum', '_budget_maximum', '_type',
        '_preview_description', '_currency_code', '_currency_exchange_rate'
    ]
    df = df[selected_columns]

    df['proposal'] = proposals
    df['common USD values'] = common_usd_values  # Add the new column for common USD values

    print(df)
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
print_projects_table_with_proposal(projects)
# Out:
# {'id': 37861339, 'owner_id': 52182906, 'title': 'Upload to Apple Store - Flutter ', 'status': 'active', 'sub_status': None, 'seo_url': 'mobile-app-development/Upload-Apple-Store-Flutter', 'currency': {'id': 6, 'code': 'SGD', 'sign': '$', 'name': 'Singapore Dollar', 'exchange_rate': 0.749963, 'country': 'SG', 'is_external': False, 'is_escrowcom_supported': False}, 'description': None, 'jobs': None, 'submitdate': 1710065372, 'preview_description': 'Update new version of app to Apple store', 'deleted': False, 'nonpublic': False, 'hidebids': False, 'type': 'fixed', 'bidperiod': 7, 'budget': {'minimum': 12.0, 'maximum': 30.0, 'name': None, 'project_type': None, 'currency_id': None}, 'hourly_project_info': None, 'featured': False, 'urgent': False, 'assisted': None, 'active_prepaid_milestone': None, 'bid_stats': {'bid_count': 9, 'bid_avg': 20.77777777777778}, 'time_submitted': 1710065372, 'time_updated': 1710087131, 'upgrades': {'featured': False, 'sealed': False, 'nonpublic': False, 'fulltime': False, 'urgent': False, 'qualified': False, 'NDA': False, 'assisted': None, 'active_prepaid_milestone': None, 'ip_contract': False, 'success_bundle': None, 'non_compete': False, 'project_management': False, 'pf_only': False, 'recruiter': None, 'listed': None, 'extend': None, 'unpaid_recruiter': None, 'premium': False, 'enterprise': False}, 'qualifications': None, 'language': 'en', 'attachments': None, 'hireme': False, 'hireme_initial_bid': None, 'invited_freelancers': None, 'recommended_freelancers': None, 'frontend_project_status': 'open', 'nda_signatures': None, 'location': {'country': {'name': None, 'flag_url': None, 'code': None, 'highres_flag_url': None, 'flag_url_cdn': None, 'highres_flag_url_cdn': None, 'iso3': None, 'region_id': None, 'phone_code': None, 'demonym': None, 'person': None, 'seo_url': None, 'sanction': None, 'language_code': None, 'language_id': None}, 'city': None, 'latitude': None, 'longitude': None, 'vicinity': None, 'administrative_area': None, 'full_address': None, 'administrative_area_code': None, 'postal_code': None, 'id': None}, 'true_location': None, 'local': False, 'negotiated': False, 'negotiated_bid': None, 'time_free_bids_expire': 1710061772, 'can_post_review': None, 'files': None, 'user_distance': None, 'from_user_location': None, 'project_collaborations': None, 'support_sessions': None, 'track_ids': None, 'drive_files': None, 'nda_details': None, 'pool_ids': ['freelancer'], 'enterprise_ids': [], 'timeframe': None, 'deloitte_details': None, 'is_escrow_project': False, 'is_seller_kyc_required': False, 'is_buyer_kyc_required': False, 'local_details': None, 'equipment': None, 'nda_signatures_new': None, 'billing_code': None, 'enterprises': [], 'enterprise_metadata_values': None, 'project_reject_reason': {'description': None, 'message': None}, 'repost_id': None, 'client_engagement': None, 'contract_signatures': None, 'quotation_id': None, 'quotation_version_id': None, 'enterprise_linked_projects_details': None, 'equipment_groups': None, 'project_source': None, 'project_source_reference': None, 'quality_details': None, 'previous_recruiter_project_details': None, 'project_note': None, 'is_quotation_project': None, 'quotation_initial_bid': None, 'requires_upfront_funding': None, 'group_ids': []}
# Generated proposal: Project Title: Unknown Title
#
# Project Description: Unknown Description
#
# Project Value and Impact:
#
#  The project will create new knowledge and insights that will advance the field of Unknown Field.
#  The project will develop new tools and methods that will be used by researchers and practitioners around the world.
#  The project will have a significant impact on the lives of people affected by Unknown Condition.
#
# Request for Funding:
#
# We request funding of \$100,000 to support this project. This funding will be used to cover the costs of research, travel, and data collection.
#
# Benefits of Funding:
#
#  Funding this project will enable us to make significant progress in our research.
#  Funding this project will help us develop new tools and methods that will benefit researchers and practitioners around the world.
#  Funding this project will help us make a real difference in the lives of people affected by Unknown Condition.
#
# We believe that this project is a valuable investment that will have a significant impact on the field of Unknown Field. We urge you to support our request for funding.
# Proposal saved to proposal.txt
# {'id': 37862208, 'owner_id': 63640411, 'title': 'Medical Palanogram Item Count Python Tool -- 2', 'status': 'closed', 'sub_status': 'closed_awarded', 'seo_url': '3d-modelling/Medical-Palanogram-Item-Count-Python', 'currency': {'id': 1, 'code': 'USD', 'sign': '$', 'name': 'US Dollar', 'exchange_rate': 1.0, 'country': 'US', 'is_external': False, 'is_escrowcom_supported': True}, 'description': None, 'jobs': None, 'submitdate': 1710087127, 'preview_description': 'Medical Palanogram Item Count Python Tool', 'deleted': False, 'nonpublic': False, 'hidebids': False, 'type': 'hourly', 'bidperiod': 10, 'budget': {'minimum': 7.0, 'maximum': 7.0, 'name': None, 'project_type': None, 'currency_id': None}, 'hourly_project_info': {'commitment': {'hours': 2, 'interval': 'week'}, 'duration_enum': 'unspecified'}, 'featured': False, 'urgent': False, 'assisted': None, 'active_prepaid_milestone': None, 'bid_stats': {'bid_count': 1, 'bid_avg': 7.0}, 'time_submitted': 1710087127, 'time_updated': 1710087127, 'upgrades': {'featured': False, 'sealed': False, 'nonpublic': False, 'fulltime': False, 'urgent': False, 'qualified': False, 'NDA': False, 'assisted': None, 'active_prepaid_milestone': None, 'ip_contract': False, 'success_bundle': None, 'non_compete': False, 'project_management': False, 'pf_only': False, 'recruiter': None, 'listed': None, 'extend': None, 'unpaid_recruiter': None, 'premium': False, 'enterprise': False}, 'qualifications': None, 'language': 'en', 'attachments': None, 'hireme': True, 'hireme_initial_bid': None, 'invited_freelancers': None, 'recommended_freelancers': None, 'frontend_project_status': 'work_in_progress', 'nda_signatures': None, 'location': {'country': {'name': None, 'flag_url': None, 'code': None, 'highres_flag_url': None, 'flag_url_cdn': None, 'highres_flag_url_cdn': None, 'iso3': None, 'region_id': None, 'phone_code': None, 'demonym': None, 'person': None, 'seo_url': None, 'sanction': None, 'language_code': None, 'language_id': None}, 'city': None, 'latitude': None, 'longitude': None, 'vicinity': None, 'administrative_area': None, 'full_address': None, 'administrative_area_code': None, 'postal_code': None, 'id': None}, 'true_location': None, 'local': False, 'negotiated': False, 'negotiated_bid': None, 'time_free_bids_expire': 1710087127, 'can_post_review': None, 'files': None, 'user_distance': None, 'from_user_location': None, 'project_collaborations': None, 'support_sessions': None, 'track_ids': None, 'drive_files': None, 'nda_details': None, 'pool_ids': ['freelancer'], 'enterprise_ids': [], 'timeframe': None, 'deloitte_details': None, 'is_escrow_project': False, 'is_seller_kyc_required': False, 'is_buyer_kyc_required': False, 'local_details': None, 'equipment': None, 'nda_signatures_new': None, 'billing_code': None, 'enterprises': [], 'enterprise_metadata_values': None, 'project_reject_reason': {'description': None, 'message': None}, 'repost_id': None, 'client_engagement': None, 'contract_signatures': None, 'quotation_id': None, 'quotation_version_id': None, 'enterprise_linked_projects_details': None, 'equipment_groups': None, 'project_source': None, 'project_source_reference': None, 'quality_details': None, 'previous_recruiter_project_details': None, 'project_note': None, 'is_quotation_project': None, 'quotation_initial_bid': None, 'requires_upfront_funding': None, 'group_ids': []}
# Generated proposal: Project Title: Unknown Title
#
# Project Description: Unknown Description
#
# Project Value and Impact:
#
#  The project will address a critical need in the community.
#  The project will have a significant impact on the lives of those it serves.
#  The project is feasible and achievable within the proposed budget and timeline.
#
# Why should this project be funded?
#
#  The project is aligned with the organization's mission and goals.
#  The project has strong support from key stakeholders.
#  The project is well-conceived and has a clear plan for implementation.
#
# We are confident that this project will be a success.
# Proposal saved to proposal.txt
# {'id': 37860595, 'owner_id': 9465233, 'title': 'Comprehensive Mixed-Use Property Development', 'status': 'active', 'sub_status': None, 'seo_url': 'real-estate/Comprehensive-Mixed-Use-Property', 'currency': {'id': 3, 'code': 'AUD', 'sign': '$', 'name': 'Australian Dollar', 'exchange_rate': 0.664386, 'country': 'AU', 'is_external': False, 'is_escrowcom_supported': True}, 'description': None, 'jobs': None, 'submitdate': 1710043457, 'preview_description': "I'm looking for professionals well-versed in the intricacies of real estate development to work on a", 'deleted': False, 'nonpublic': False, 'hidebids': False, 'type': 'fixed', 'bidperiod': 7, 'budget': {'minimum': 10.0, 'maximum': 30.0, 'name': None, 'project_type': None, 'currency_id': None}, 'hourly_project_info': None, 'featured': False, 'urgent': False, 'assisted': None, 'active_prepaid_milestone': None, 'bid_stats': {'bid_count': 4, 'bid_avg': 55.0}, 'time_submitted': 1710043457, 'time_updated': 1710087125, 'upgrades': {'featured': False, 'sealed': False, 'nonpublic': False, 'fulltime': False, 'urgent': False, 'qualified': False, 'NDA': False, 'assisted': None, 'active_prepaid_milestone': None, 'ip_contract': False, 'success_bundle': None, 'non_compete': False, 'project_management': False, 'pf_only': False, 'recruiter': None, 'listed': None, 'extend': None, 'unpaid_recruiter': None, 'premium': False, 'enterprise': False}, 'qualifications': None, 'language': 'en', 'attachments': None, 'hireme': False, 'hireme_initial_bid': None, 'invited_freelancers': None, 'recommended_freelancers': None, 'frontend_project_status': 'open', 'nda_signatures': None, 'location': {'country': {'name': None, 'flag_url': None, 'code': None, 'highres_flag_url': None, 'flag_url_cdn': None, 'highres_flag_url_cdn': None, 'iso3': None, 'region_id': None, 'phone_code': None, 'demonym': None, 'person': None, 'seo_url': None, 'sanction': None, 'language_code': None, 'language_id': None}, 'city': None, 'latitude': None, 'longitude': None, 'vicinity': None, 'administrative_area': None, 'full_address': None, 'administrative_area_code': None, 'postal_code': None, 'id': None}, 'true_location': None, 'local': False, 'negotiated': False, 'negotiated_bid': None, 'time_free_bids_expire': 1710039857, 'can_post_review': None, 'files': None, 'user_distance': None, 'from_user_location': None, 'project_collaborations': None, 'support_sessions': None, 'track_ids': None, 'drive_files': None, 'nda_details': None, 'pool_ids': ['freelancer'], 'enterprise_ids': [], 'timeframe': None, 'deloitte_details': None, 'is_escrow_project': False, 'is_seller_kyc_required': False, 'is_buyer_kyc_required': False, 'local_details': None, 'equipment': None, 'nda_signatures_new': None, 'billing_code': None, 'enterprises': [], 'enterprise_metadata_values': None, 'project_reject_reason': {'description': None, 'message': None}, 'repost_id': None, 'client_engagement': None, 'contract_signatures': None, 'quotation_id': None, 'quotation_version_id': None, 'enterprise_linked_projects_details': None, 'equipment_groups': None, 'project_source': None, 'project_source_reference': None, 'quality_details': None, 'previous_recruiter_project_details': None, 'project_note': None, 'is_quotation_project': None, 'quotation_initial_bid': None, 'requires_upfront_funding': None, 'group_ids': []}
# Generated proposal: Project Title: Unknown Title
#
# Project Description: Unknown Description
#
# Project Value and Impact:
#
#  The project will create a new way for people to interact with the world around them.
#  It will open up new possibilities for communication and collaboration.
#  It will have a positive impact on the lives of people around the world.
#
# Request for Funding:
#
# We are requesting funding of \$100,000 to support the development of this project. This funding will be used to cover the costs of research, development, and marketing.
#
# Timeline:
#
# The project will be completed in three phases:
#
#  Phase 1: Research and development (6 months)
#  Phase 2: Marketing and testing (3 months)
#  Phase 3: Launch (6 months)
#
# Team:
#
# The project team is composed of experienced professionals with a proven track record of success.
#
#  Project Manager: John Smith
#  Lead Developer: Jane Doe
#  Marketing Manager: Michael Jones
#
# Conclusion:
#
# We believe that this project has the potential to make a significant impact on the world. We are confident that we can successfully complete the project and deliver on our promises.
#
# We appreciate your consideration of our request for funding.
# Proposal saved to proposal.txt
#         _id                                          _title _status  \
# 0  37861339                Upload to Apple Store - Flutter   active
# 1  37862208  Medical Palanogram Item Count Python Tool -- 2  closed
# 2  37860595    Comprehensive Mixed-Use Property Development  active
#
#    _budget_minimum  _budget_maximum   _type  \
# 0             12.0             30.0   fixed
# 1              7.0              7.0  hourly
# 2             10.0             30.0   fixed
#
#                                 _preview_description _currency_code  \
# 0           Update new version of app to Apple store            SGD
# 1          Medical Palanogram Item Count Python Tool            USD
# 2  I'm looking for professionals well-versed in t...            AUD
#
#    _currency_exchange_rate                                           proposal  \
# 0                 0.749963  Project Title: Unknown Title\n\nProject Descri...
# 1                 1.000000  Project Title: Unknown Title\n\nProject Descri...
# 2                 0.664386  Project Title: Unknown Title\n\nProject Descri...
#
#    common USD values
# 0                0.0
# 1                0.0
# 2                0.0
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

def sample_search_projects(sort_field='last_updated'):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='',  # Empty query to retrieve all projects
            limit=3,  # You can adjust the limit as needed
            active_only=True
        )
        # Extract the list of projects
        projects = response.get('projects', [])
        # Sort projects based on the specified sort_field
        if sort_field:
            projects.sort(key=lambda x: x.get(sort_field) or 0, reverse=True)
        else:
            print("Warning: sort_field is None, projects will not be sorted.")
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def compact_projects(projects):
    compacted_projects = []
    for project in projects:
        compacted_project = {
            'id': project['id'],
            'title': project['title'],
            'description': project['description'],
            # Add other essential fields as needed
        }
        compacted_projects.append(compacted_project)
    return compacted_projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        else:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    for project in projects:
        project_title = project.get('title', '')
        project_description = project.get('description', '')
        proposal = generate_proposal(project_title, project_description)
        proposals.append(proposal)
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
compacted_projects = compact_projects(projects)
print_projects_table_with_proposal(compacted_projects)
# Out:
# Generated proposal: Wordpress Single Product Stripe Integration Proposal
#
# Problem
#
# WordPress is a popular content management system (CMS) that is used by millions of websites. However, it does not natively support Stripe, a popular payment processing platform. This means that businesses that use WordPress and Stripe must either use a third-party plugin or manually integrate the two platforms.
#
# Solution
#
# This proposal proposes a WordPress single product Stripe integration that would allow businesses to sell products directly from their WordPress website using Stripe. The integration would be simple to use and would not require businesses to use a third-party plugin.
#
# Benefits
#
# The benefits of this integration include:
#
#  Increased sales: Businesses would be able to sell products directly from their WordPress website, which would increase sales.
#  Reduced costs: Businesses would not need to use a third-party plugin, which would save them money.
#  Improved customer experience: Customers would be able to purchase products from a familiar and trusted platform.
#
# Impact
#
# This integration would have a significant impact on businesses that use WordPress and Stripe. It would allow them to sell products directly from their WordPress website, reduce costs, and improve the customer experience.
#
# Call to Action
#
# I urge you to approve this proposal so that we can begin development of the WordPress single product Stripe integration. This integration would be a valuable asset to businesses that use WordPress and Stripe.
# Proposal saved to proposal.txt
# Generated proposal: Mental Health Detector Website Development
#
# Problem: Mental health issues are a major problem in today's society, with one in five people experiencing a mental illness in their lifetime. However, there is often a stigma associated with mental health, which prevents people from seeking help.
#
# Solution: A mental health detector website would provide a confidential and anonymous way for people to screen for mental health issues. The website would also provide information on mental health disorders and resources for getting help.
#
# Impact: A mental health detector website could have a significant impact on the lives of people struggling with mental health issues. By providing a safe and confidential space for people to screen for mental health issues, the website could help to reduce the stigma associated with mental health and encourage more people to seek help.
#
# Value: The value of a mental health detector website is clear. It would provide a valuable resource for people struggling with mental health issues, and it could help to reduce the stigma associated with mental health and encourage more people to seek help.
# Proposal saved to proposal.txt
# Generated proposal: Proposal for Shopify and Ecommerce Site for Electronics
#
# Value:
#
#  A Shopify and ecommerce site for electronics would allow us to reach a wider audience and sell our products to customers all over the world.
#  An online store would also be more convenient for customers, who could shop from anywhere at any time.
#  A Shopify site would give us more control over our marketing and sales, and allow us to track our data and improve our performance.
#
# Impact:
#
#  A Shopify and ecommerce site for electronics would increase our sales, reach new customers, and grow our business.
#  An online store would also make it easier for us to serve our customers and provide them with a better shopping experience.
#
# We believe that a Shopify and ecommerce site for electronics would be a valuable asset to our business and would have a significant impact on our growth.
# Proposal saved to proposal.txt
#         _id                                           _title _description  \
# 0  37863918      Wordpress Single Product Stripe Integration         None
# 1  37865185       Mental Health Detector Website Development         None
# 2  37865179  Shopify and Ecommerce Site for Electronics -- 2         None
#
#                                             proposal
# 0  Wordpress Single Product Stripe Integration Pr...
# 1  Mental Health Detector Website Development\n\n...
# 2  Proposal for Shopify and Ecommerce Site for El...
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='',  # Empty query to retrieve all projects
            limit=3  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        #else:
        elif value is not None:
                flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = ''
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    for project in projects:
        project_title = project['title']
        project_description = project['preview_description']
        proposal = generate_proposal(project_title, project_description)
        proposals.append(proposal)
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
print_projects_table_with_proposal(projects)

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='',  # Empty query to retrieve all projects
            limit=3  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        #else:
        elif value is not None:
                flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    for project in projects:
        project_title = project['title']
        project_description = project['preview_description']
        proposal = generate_proposal(project_title, project_description)
        proposals.append(proposal)
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
print_projects_table_with_proposal(projects)

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

def sample_search_projects(sort_field='last_updated'):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=15,  # You can adjust the limit as needed
            offset=10,  # You can adjust the offset as needed
            sort=sort_field  # Sort by the specified field
        )
        # Extract the list of projects
        projects = response.get('projects', [])
        # Sort projects based on the specified field
        projects.sort(key=lambda x: x.get(sort_field, ''))
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    for project in projects:
        project_title = project['title']
        project_description = project['preview_description']
        proposal = generate_proposal(project_title, project_description)
        proposals.append(proposal)
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

# Call the function to retrieve projects and print them with proposals
projects = sample_search_projects(sort_field='last_updated')
print_projects_table_with_proposal(projects)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 100
#      97     print(f"DataFrame saved to {csv_filename}")
#      99 # Call the function to retrieve projects and print them with proposals
# --> 100 projects = sample_search_projects(sort_field='last_updated')
#     101 print_projects_table_with_proposal(projects)
#
# Cell In[38], line 15, in sample_search_projects(sort_field)
#      13 session = Session(oauth_token=oauth_token)
#      14 try:
# ---> 15     response = search_projects(
#      16         session,
#      17         query='python',  # Empty query to retrieve all projects
#      18         limit=15,  # You can adjust the limit as needed
#      19         offset=10,  # You can adjust the offset as needed
#      20         sort=sort_field  # Sort by the specified field
#      21     )
#      22     # Extract the list of projects
#      23     projects = response.get('projects', [])
#
# TypeError: search_projects() got an unexpected keyword argument 'sort'

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

def sample_search_projects(sort_field='last_updated'):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=15,  # You can adjust the limit as needed
            active_only=True,
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    
    # Sort projects based on the specified field
    sorted_projects = sorted(projects, key=lambda x: x.get(sort_field, ''))

    return sorted_projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    for project in projects:
        project_title = project['title']
        project_description = project['preview_description']
        proposal = generate_proposal(project_title, project_description)
        proposals.append(proposal)
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

# Call the function to retrieve projects and print them with proposals
projects = sample_search_projects(sort_field='last_updated')
print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: Python Code Explanation - Data Analysis
#
# Data analysis is a key skill for any data scientist, and Python is one of the most popular programming languages for data analysis. However, Python can be a challenging language to learn, especially for beginners.
#
# This project will provide a detailed explanation of Python code for data analysis. The project will be divided into two parts:
#
#  Part 1: A basic introduction to Python for data analysis, including the essential Python libraries for data analysis.
#  Part 2: A more advanced explanation of Python code for data analysis, including more complex techniques such as machine learning and natural language processing.
#
# This project will be of great value to anyone who wants to learn Python for data analysis. By the end of the project, you will have a solid understanding of Python code for data analysis and be able to use Python to perform complex data analysis tasks.
#
# Why this project is valuable:
#
#  Python is one of the most popular programming languages for data analysis.
#  Python code for data analysis can be complex and difficult to understand.
#  This project provides a detailed explanation of Python code for data analysis.
#  This project will help you learn Python for data analysis and be able to use Python to perform complex data analysis tasks.
# Proposal saved to proposal.txt
# Generated proposal: Proposed Project: Creación de Bot Para Trading Binarias
#
# Project Description:
#
# I am seeking a developer with experience in creating trading bots, particularly for the Opera platform. The bot will be used to trade binary options. The goal of the bot is to automate the trading process and to generate profits for the user.
#
# Project Value and Impact:
#
# The bot will have a significant value for the user by automating the trading process and generating profits. The bot will also save the user time and effort, allowing them to focus on other aspects of their business. The bot will also help to reduce the risk of human error.
#
# Project Timeline:
#
# The project is expected to take 6-8 weeks to complete.
#
# Project Budget:
#
# The project budget is \$5,000.
#
# Project Deliverables:
#
# The project deliverables will include the following:
#
#  A working prototype of the bot
#  A detailed user manual
#  A support plan for the bot
#
# Project Success Metrics:
#
# The success of the project will be measured by the following metrics:
#
#  The number of trades executed by the bot
#  The average profit per trade
#  The overall profitability of the bot
#
# Project Risks:
#
# The main risks associated with the project are:
#
#  The bot may not be able to generate profits
#  The bot may not be able to scale to handle large volumes of trades
#  The bot may be hacked or compromised
# Proposal saved to proposal.txt
# Generated proposal: Python Developer and Data Scientist for Interview Scheduling System
#
# Problem:
#
# Manually scheduling interviews is a time-consuming and error-prone process. It can be difficult to keep track of all the candidates and their availability, and it's easy to miss important details like the time zone or location of the interview.
#
# Solution:
#
# An interview scheduling system can automate the process of scheduling interviews, reducing the time and effort required. The system can keep track of all the candidates and their availability, and it can send out reminders and confirmations automatically.
#
# Benefits:
#
# An interview scheduling system can provide a number of benefits, including:
#
#  Reduced time and effort: The system can automate the process of scheduling interviews, saving time and effort for recruiters and hiring managers.
#  Increased accuracy: The system can help to ensure that all interviews are scheduled correctly, reducing the risk of errors.
#  Improved candidate experience: The system can provide a more streamlined and efficient experience for candidates, making them more likely to accept the interview.
#
# Impact:
#
# An interview scheduling system can have a significant impact on the hiring process, improving efficiency and reducing the risk of errors. It can also help to improve the candidate experience, making it more likely that candidates will accept the interview.
#
# Call to action:
#
# I am seeking a skilled data analyst with proficiency in Python to help me create an interview scheduling system. If you are interested in this project, please contact me at [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Experto en Estadísticas
#
# We are looking for an experienced statistician to join our team of data scientists. The ideal candidate will have a strong background in statistics, data analysis, and machine learning. The role will involve developing and implementing statistical models to help us understand our customers and improve our products and services.
#
# This is a critical role in our company, and we are confident that the right candidate will have a significant impact on our business.
#
# Why this is a valuable project:
#
#  The ability to analyze and interpret data is essential for any business that wants to make informed decisions.
#  Statistical models can help us to understand our customers better, identify new opportunities, and improve our products and services.
#  The right candidate will have a significant impact on our business by helping us to make better decisions and achieve our goals.
# Proposal saved to proposal.txt
# Generated proposal: Monday.com App or API Development Proposal
#
# Overview
#
# Monday.com is a powerful project management tool that can help teams of all sizes to be more productive. However, its native features may not be enough for some organizations. That's where our app or API development services come in. We can help you to add custom features to Monday.com that will meet your specific needs.
#
# Benefits of our services
#
# Our services offer a number of benefits, including:
#
#  Increased productivity: Our custom features can help you to streamline your workflow and get more done in less time.
#  Improved collaboration: Our features can make it easier for team members to communicate and collaborate on projects.
#  Greater flexibility: Our features can be customized to meet your specific needs.
#
# Impact
#
# Our services can have a significant impact on your organization, including:
#
#  Increased efficiency: Our features can help you to streamline your processes and improve efficiency.
#  Improved customer satisfaction: Our features can help you to provide better service to your customers.
#  Increased profitability: Our features can help you to grow your business and increase profits.
#
# Call to action
#
# If you're interested in learning more about our Monday.com app or API development services, please contact us today. We would be happy to discuss your needs and how we can help you to achieve your goals.
#
# Contact us
#
# [Your contact information]
# Proposal saved to proposal.txt
# Generated proposal: Niagara Framework Application Developer
#
# We are looking for an expert in the Niagara Framework to create a brand new application that showcases its value and impact. The application should be designed to be user-friendly and scalable, and it should be able to handle a large amount of data. The ideal candidate will have experience in developing applications with the Niagara Framework, as well as a strong understanding of data science and machine learning.
#
# This is a great opportunity to work on a cutting-edge technology that is changing the way we think about data. The successful candidate will be part of a team of talented developers who are passionate about creating innovative solutions.
#
# Project Scope:
#
#  Develop a brand new application with the Niagara Framework
#  The application should be user-friendly and scalable
#  The application should be able to handle a large amount of data
#  The ideal candidate will have experience in developing applications with the Niagara Framework, as well as a strong understanding of data science and machine learning
#
# Benefits of working with us:
#
#  Work on cutting-edge technology
#  Be part of a team of talented developers
#  Opportunity to make a real impact on the world
# Proposal saved to proposal.txt
# Generated proposal: Python Script for Advanced HTML Parsing
#
# Problem:
#
# HTML is a markup language used to create web pages. It is often used to store data in a structured format. However, parsing HTML can be difficult, especially when the data is nested or complex.
#
# Solution:
#
# This Python script uses a variety of techniques to parse HTML data. These techniques include:
#
#  Regular expressions: Regular expressions are a powerful tool for matching patterns in text. They can be used to extract data from HTML documents.
#  Beautiful Soup: Beautiful Soup is a Python library that makes it easy to parse HTML documents. It can be used to extract data from HTML documents and to traverse the document tree.
#  Scrapy: Scrapy is a Python framework for web scraping. It can be used to extract data from websites in a structured format.
#
# Benefits:
#
# This Python script can be used to extract data from a variety of HTML documents. It can be used to:
#
#  Scrape data from websites
#  Extract data from PDFs
#  Extract data from spreadsheets
#  Extract data from other structured documents
#
# This script can save businesses time and money by automating the process of extracting data from HTML documents. It can also help businesses to improve their data quality and accuracy.
#
# Call to action:
#
# If you are interested in learning more about this Python script, please contact me at [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Comprehensive Email Scraping Service
#
# Problem: Businesses and individuals alike need access to accurate and up-to-date email lists. However, manually compiling these lists is time-consuming and error-prone.
#
# Solution: Our comprehensive email scraping service will provide you with the tools you need to quickly and easily collect email addresses from any website. Our service is versatile and can be used to scrape both personal and business email addresses.
#
# Benefits:
#
#  Save time and money by automating the process of collecting email addresses
#  Get access to accurate and up-to-date email lists
#  Reach more customers and grow your business
#
# Call to action: Contact us today to learn more about our comprehensive email scraping service and how it can benefit your business.
# Proposal saved to proposal.txt
# Generated proposal: Python Developer and Data Scientist for Interview Scheduling System
#
# Problem: Manually scheduling interviews is a time-consuming and error-prone process. It can lead to scheduling conflicts, missed appointments, and frustrated candidates.
#
# Solution: A Python-based interview scheduling system can automate the process of scheduling interviews, reducing the time and effort required. The system can also help to avoid scheduling conflicts and ensure that candidates are scheduled for interviews at times that work for them.
#
# Benefits: A Python-based interview scheduling system can provide a number of benefits, including:
#
#  Increased efficiency: The system can automate the process of scheduling interviews, reducing the time and effort required.
#  Reduced errors: The system can help to avoid scheduling conflicts and ensure that candidates are scheduled for interviews at times that work for them.
#  Improved candidate experience: Candidates will have a more positive experience when they are scheduled for interviews at times that work for them.
#
# Impact: A Python-based interview scheduling system can have a significant impact on the efficiency and effectiveness of the hiring process. By automating the process of scheduling interviews, the system can reduce the time and effort required, while also helping to avoid scheduling conflicts and ensuring that candidates are scheduled for interviews at times that work for them. This can lead to a more positive candidate experience and improved hiring outcomes.
#
# Call to action: I am seeking a skilled data analyst with proficiency in Python to help me create a Python-based interview scheduling system. If you are interested in this project, please contact me at [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Profitable AI-Powered Fully Automated Trading and Arbitrage Bot
#
# Problem
#
# The traditional stock market is inefficient, with high transaction costs and limited liquidity. This creates opportunities for arbitrageurs to profit by exploiting price discrepancies between different markets. However, manual arbitrage is time-consuming and error-prone.
#
# Solution
#
# An AI-powered fully automated trading and arbitrage bot can help traders to exploit price discrepancies in real time, without the need for manual intervention. This can lead to significant profits, with minimal risk.
#
# Benefits
#
# An AI-powered trading bot can provide the following benefits:
#
#  Increased profits: By automating the trading process, an AI-powered bot can help traders to capture more profit opportunities.
#  Reduced risk: By eliminating human error, an AI-powered bot can help traders to reduce their risk exposure.
#  Scalability: An AI-powered bot can be scaled up to trade in multiple markets and assets, without the need for additional human resources.
#
# Call to action
#
# If you are a highly skilled developer and you are interested in creating an AI-powered trading bot, I would be happy to discuss this project with you in more detail. Please contact me at [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Python Programming Project for MCS Students
#
# As a MCS student, you're required to complete a Python programming project. This project is an opportunity for you to demonstrate your skills in Python programming and to apply your knowledge to a real-world problem.
#
# The project will involve developing a Python program that solves a problem of your choosing. You will be responsible for choosing a problem, designing a solution, and implementing the solution in Python.
#
# The project will be graded by your instructor, and you will receive feedback on your work. The project will also be used to assess your ability to learn and apply Python programming concepts.
#
# The project is a valuable opportunity for you to develop your skills in Python programming. It will also help you to prepare for future programming challenges.
#
# Impact:
#
# This project will have a significant impact on your learning and development as a Python programmer. It will help you to:
#
#  Develop your skills in Python programming
#  Apply your knowledge to a real-world problem
#  Prepare for future programming challenges
# Proposal saved to proposal.txt
# Generated proposal: Python-Based Minimum Spanning Tree in Stress Testing in Risk Management
#
# Problem:
#
# Stress testing is a critical component of risk management, but it can be computationally expensive and time-consuming. Traditional methods for stress testing often rely on Monte Carlo simulations, which can be prohibitively slow for large datasets.
#
# Solution:
#
# A Python-based minimum spanning tree (MST) algorithm can be used to speed up stress testing by identifying the most important dependencies between assets. This allows for more efficient stress testing that can be completed in a fraction of the time of traditional methods.
#
# Benefits:
#
# The use of a Python-based MST algorithm in stress testing can provide a number of benefits, including:
#
#  Reduced computational cost and time
#  Improved accuracy and efficiency
#  Increased scalability to large datasets
#  Improved ability to identify and manage risks
#
# Call to Action:
#
# If you are an active member of the risk management sector and are in need of a dedicated individual who can effectively implement a Python-based MST algorithm for stress testing, I urge you to contact me today. I have the experience and expertise necessary to help you achieve your goals.
#
# Contact:
#
# [Your name]
# [Your email address]
# Proposal saved to proposal.txt
# Generated proposal: PowerBI Interface for Manual Numerical/Text Data Entry
#
# Problem: Manual data entry is a time-consuming and error-prone process. It can also lead to inconsistencies in data quality.
#
# Solution: A user-friendly PowerBI interface can help to automate manual data entry, reduce errors, and improve data quality.
#
# Benefits:
#
#  Reduced time spent on data entry: A PowerBI interface can automate the process of data entry, freeing up your team to focus on other tasks.
#  Improved data quality: A PowerBI interface can help to reduce errors in data entry, resulting in more accurate and reliable data.
#  Increased productivity: A PowerBI interface can help your team to be more productive by saving time and reducing errors.
#
# Call to action: I am seeking a professional who can script a user-friendly interface in PowerBI for my team to manually enter numerical and text data. This interface will help to reduce the time spent on data entry, improve data quality, and increase productivity.
#
# Contact: [Your name]
# [Your email]
# [Your phone number]
# Proposal saved to proposal.txt
# Generated proposal: Python-Based User Data Organization System
#
# Problem
#
# Organizations struggle to organize and manage user data in a way that is efficient, secure, and scalable. This can lead to data silos, duplication, and errors, which can negatively impact the user experience and the bottom line.
#
# Solution
#
# A Python-based user data organization system can help organizations to overcome these challenges by providing a centralized, secure, and scalable platform for managing user data. This system can:
#
#  Collect user data from multiple sources
#  Organize data into a structured format
#  Protect data from unauthorized access
#  Scale to meet the needs of growing organizations
#
# Benefits
#
# A Python-based user data organization system can provide organizations with a number of benefits, including:
#
#  Improved user experience
#  Increased productivity
#  Reduced costs
#  Enhanced security
#
# Call to Action
#
# If you are in need of a proficient Python developer to conceive, develop, and implement a Python-based user data organization system, I encourage you to contact me today. I have a proven track record of success in developing and implementing complex software systems, and I am confident that I can help you to achieve your goals.
#
# Contact
#
# [Your name]
# [Your email address]
# [Your phone number]
# Proposal saved to proposal.txt
# Generated proposal: One-Time Project: Golang Migration for Python Project
#
# We are an up-and-coming business that is looking to migrate our Python project to Golang. We believe that this migration will provide a number of benefits, including:
#
#  Improved performance: Golang is a compiled language, which means that it is typically faster than interpreted languages like Python. This will allow our application to run more efficiently and scale better as our traffic increases.
#  Reduced development costs: Golang is a statically typed language, which means that it is easier to catch errors during development. This will save us time and money in the long run.
#  Enhanced security: Golang is a more secure language than Python, as it has built-in features that protect against common security vulnerabilities. This will help us to keep our application safe from attack.
#
# We are looking for a proficient Golang engineer with experience in migrating Python projects. The ideal candidate will have a strong understanding of both Golang and Python, as well as experience in working with large-scale applications.
#
# This is a one-time project with a budget of \$10,000. The project will be completed within 3 months.
#
# We believe that this migration will be a valuable investment for our business. We are confident that it will provide us with the benefits outlined above, and we look forward to working with you to make it happen.
# Proposal saved to proposal.txt
#          _id  _owner_id                                             _title  \
# 0   37865515   66758464            Python Code Explanation - Data Analysis
# 1   37865481   48599472         Creación de Bot Para Trading Binarias -- 4
# 2   37865428   52367583  Python developer and Data Scientist for making...
# 3   37865336   54933983                            Experto en Estadisticas
# 4   37865305   70791665                  Monday.com App or API Development
# 5   37865183   75045419            Niagara Framework Application Developer
# 6   37865134   68808916            Python Script for Advanced HTML Parsing
# 7   37865058   45522885               Comprehensive Email Scraping Service
# 8   37865042   52367583  Python developer and Data Scientist for making...
# 9   37865039   66716737  Profitable AI-Powered Fully Automated Trading ...
# 10  37864940   65879508        Python Programming Project for MCS Students
# 11  37864870   75043915  Python-Based Minimum Spanning Tree in Stress T...
# 12  37864855   19322440  PowerBI Interface for Manual Numerical/text Da...
# 13  37864773   50296395         Python-Based User Data Organization System
# 14  37864756   75043250  [One Time Project] Golang Migration for Python...
#
#    _status                                           _seo_url  _currency_id  \
# 0   active  mathematics/Python-Code-Explanation-Data-Analysis             3
# 1   active      php/Creaci-Bot-Para-Trading-Binarias-37865481             1
# 2   active         python/Python-developer-Data-Scientist-for             1
# 3   active                    statistics/Experto-Estadisticas             1
# 4   active          monday-com/Monday-com-App-API-Development             8
# 5   active  javascript/Niagara-Framework-Application-Devel...            11
# 6   active         aws-lambda/Python-Script-for-Advanced-HTML             1
# 7   active        python/Comprehensive-Email-Scraping-Service             4
# 8   active       python/Data-Analyst-For-Interview-Scheduling            11
# 9   active          python/Profitable-Powered-Fully-Automated             1
# 10  active   c-programming/Python-Programming-Project-for-MCS            11
# 11  active          python/Python-Based-Minimum-Spanning-Tree            11
# 12  active       excel/PowerBI-Interface-for-Manual-Numerical            11
# 13  active         python/Python-Based-User-Data-Organization             8
# 14  active           python/One-Time-Project-Golang-Migration             6
#
#    _currency_code _currency_sign     _currency_name  _currency_exchange_rate  \
# 0             AUD              $  Australian Dollar                 0.660651
# 1             USD              $          US Dollar                 1.000000
# 2             USD              $          US Dollar                 1.000000
# 3             USD              $          US Dollar                 1.000000
# 4             EUR              €               Euro                 1.092641
# 5             INR              ₹       Indian Rupee                 0.012086
# 6             USD              $          US Dollar                 1.000000
# 7             GBP              £     British Pounds                 1.282441
# 8             INR              ₹       Indian Rupee                 0.012086
# 9             USD              $          US Dollar                 1.000000
# 10            INR              ₹       Indian Rupee                 0.012086
# 11            INR              ₹       Indian Rupee                 0.012086
# 12            INR              ₹       Indian Rupee                 0.012086
# 13            EUR              €               Euro                 1.092641
# 14            SGD              $   Singapore Dollar                 0.751690
#
#     ... _is_seller_kyc_required  _is_buyer_kyc_required  _enterprises  \
# 0   ...                   False                   False            []
# 1   ...                   False                   False            []
# 2   ...                   False                   False            []
# 3   ...                   False                   False            []
# 4   ...                   False                   False            []
# 5   ...                   False                   False            []
# 6   ...                   False                   False            []
# 7   ...                   False                   False            []
# 8   ...                   False                   False            []
# 9   ...                   False                   False            []
# 10  ...                   False                   False            []
# 11  ...                   False                   False            []
# 12  ...                   False                   False            []
# 13  ...                   False                   False            []
# 14  ...                   False                   False            []
#
#                    _project_reject_reason_description  \
# 0   The project description is not meaningful.,The...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                        _project_reject_reason_message  _group_ids  \
# 0   Kindly provide a better and personalized proje...          []
# 1                                                 NaN          []
# 2                                                 NaN          []
# 3                                                 NaN          []
# 4                                                 NaN          []
# 5                                                 NaN          []
# 6                                                 NaN          []
# 7                                                 NaN          []
# 8                                                 NaN          []
# 9                                                 NaN          []
# 10                                                NaN          []
# 11                                                NaN          []
# 12                                                NaN          []
# 13                                                NaN          []
# 14                                                NaN          []
#
#     _hourly_project_info_commitment_hours  \
# 0                                     NaN
# 1                                    40.0
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                    40.0
# 6                                    40.0
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                   40.0
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
#
#     _hourly_project_info_commitment_interval  \
# 0                                        NaN
# 1                                       week
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                       week
# 6                                       week
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                      week
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
#
#    _hourly_project_info_duration_enum  \
# 0                                 NaN
# 1                         unspecified
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                         unspecified
# 6                         unspecified
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                        unspecified
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
#
#                                              proposal
# 0   Python Code Explanation - Data Analysis\n\nDat...
# 1   Proposed Project: Creación de Bot Para Trading...
# 2   Python Developer and Data Scientist for Interv...
# 3   Experto en Estadísticas\n\nWe are looking for ...
# 4   Monday.com App or API Development Proposal\n\n...
# 5   Niagara Framework Application Developer\n\nWe ...
# 6   Python Script for Advanced HTML Parsing\n\nPro...
# 7   Comprehensive Email Scraping Service\n\nProble...
# 8   Python Developer and Data Scientist for Interv...
# 9   Profitable AI-Powered Fully Automated Trading ...
# 10  Python Programming Project for MCS Students\n\...
# 11  Python-Based Minimum Spanning Tree in Stress T...
# 12  PowerBI Interface for Manual Numerical/Text Da...
# 13  Python-Based User Data Organization System\n\n...
# 14  One-Time Project: Golang Migration for Python ...
#
# [15 rows x 60 columns]
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

def sample_search_projects(sort_field='last_updated'):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=15,  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    
    # Filter projects based on language
    english_projects = [project for project in projects if project.get('language') == 'en']
    
    # Sort projects based on the specified field
    sorted_projects = sorted(english_projects, key=lambda x: x.get(sort_field, ''))

    return sorted_projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = ''
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    for project in projects:
        project_title = project['title']
        project_description = project['preview_description']
        proposal = generate_proposal(project_title, project_description)
        proposals.append(proposal)
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

# Call the function to retrieve projects and print them with proposals
projects = sample_search_projects(sort_field='last_updated')
print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: Python Email Filtering with Pfsense Setup
#
# Problem:
#
# Unwanted email is a major problem for businesses of all sizes. Spam, phishing, and other malicious emails can waste time, damage productivity, and compromise security. Traditional email filtering solutions can be expensive and difficult to manage.
#
# Solution:
#
# Python and Pfsense can be used to create a powerful and affordable email filtering solution. Pfsense is a free and open source firewall that can be used to block unwanted traffic. Python is a powerful programming language that can be used to create custom email filtering rules.
#
# Benefits:
#
# A Python email filtering solution with Pfsense can provide the following benefits:
#
#  Reduced spam: A Python email filtering solution can block spam before it reaches your inbox. This can save you time and money.
#  Improved security: A Python email filtering solution can help to protect your network from phishing attacks and other malicious emails.
#  Increased productivity: A Python email filtering solution can help you to focus on the emails that are important to you. This can improve your productivity and reduce stress.
#
# Call to action:
#
# If you are looking for a powerful and affordable email filtering solution, I encourage you to consider Python and Pfsense. I can provide expert assistance with setting up this solution on your system.
#
# Contact me:
#
# [Your name]
# [Your email address]
# Proposal saved to proposal.txt
# Generated proposal: Python Expert for Diverse Tech Project
#
# We are seeking a seasoned Python developer with a versatile skill set to join our team on a diverse tech project. The ideal candidate will have experience in a wide range of technologies, including:
#
#  Python
#  Django
#  Flask
#  SQL
#  NoSQL
#  AWS
#  GCP
#
# The project will involve the development of a new platform that will allow users to easily manage and share data. The platform will be used by a variety of organizations, including:
#
#  Government agencies
#  Non-profit organizations
#  Educational institutions
#
# The successful candidate will be responsible for:
#
#  Designing and developing the platform
#  Integrating with third-party APIs
#  Testing and debugging the platform
#  Supporting users of the platform
#
# This is a full-time position based in our San Francisco office. The salary is competitive and commensurate with experience.
#
# To apply, please send your resume and a cover letter to [email protected]
#
# We are looking forward to hearing from you!
# Proposal saved to proposal.txt
# Generated proposal: Proposal for a Typescript project to interact with Telethon and Telegram Bot for a Crypto Project
#
# Problem
#
# Cryptocurrency trading is a rapidly growing industry, but it is still plagued by a lack of user-friendly tools. Many existing trading platforms are complex and difficult to use, which can deter new investors from entering the market.
#
# Solution
#
# We propose to develop a Typescript project that will allow users to trade cryptocurrencies on Telegram using a simple and intuitive bot. The bot will be able to perform a variety of tasks, such as:
#
#  Placing orders to buy or sell cryptocurrencies
#  Tracking the price of cryptocurrencies
#  Receiving notifications about market movements
#
# Benefits
#
# Our project will have a number of benefits for users, including:
#
#  Increased accessibility: The bot will be easy to use, even for beginners.
#  Reduced costs: The bot will be free to use.
#  Improved security: The bot will be secure and reliable.
#
# Timeline
#
# We estimate that the project will take 6-8 weeks to complete.
#
# Budget
#
# The total cost of the project is estimated to be \$10,000.
#
# Conclusion
#
# We believe that our project has the potential to make a significant impact on the cryptocurrency trading industry. By making it easier for users to trade cryptocurrencies, we can help to bring more people into the market and increase the overall liquidity.
# Proposal saved to proposal.txt
# Generated proposal: Python Script & Telegram API
#
# Problem
#
# You need an expert in Telegram's API and Python scripting to help you with a fast task.
#
# Solution
#
# I can help you with this task by creating a Python script that will automate the process you need to complete. This will save you time and effort, and you can be confident that the task will be completed correctly.
#
# Benefits
#
#  Save time and effort
#  Peace of mind knowing the task will be completed correctly
#  Increased productivity
#
# Budget
#
# $8
#
# Timeline
#
# 1-2 days
#
# Contact
#
# [Your contact information]
# Proposal saved to proposal.txt
# Generated proposal: Custom Basic Calculator Development
#
# We are seeking a competent and inventive programmer to craft a unique basic calculator that uses both the Cartesian and polar coordinate systems. This calculator will be used by students in a variety of math courses, and it will need to be easy to use and understand. The calculator should also be able to perform a variety of mathematical operations, including addition, subtraction, multiplication, division, and exponentiation.
#
# This project has the potential to have a significant impact on the learning of mathematics. A well-designed calculator can help students to understand mathematical concepts more easily, and it can also help them to save time on their homework. The calculator will also be a valuable tool for teachers, who can use it to demonstrate mathematical concepts to their students.
#
# We believe that this project is a worthwhile investment, and we are confident that it will have a positive impact on the learning of mathematics. We look forward to hearing from you soon.
# Proposal saved to proposal.txt
# Generated proposal: YouTube Transcript Extractor & Downloader
#
# Problem
#
# YouTube is a vast repository of video content, but it can be difficult to find the information you need when you need it. A YouTube transcript extractor and downloader can solve this problem by providing a way to quickly and easily access the text of any video.
#
# Solution
#
# This script will extract the transcripts of YouTube videos and save them as a text file. This will make it easy for users to search for specific information, copy and paste text, or use the transcripts for other purposes.
#
# Benefits
#
# A YouTube transcript extractor and downloader would have a number of benefits, including:
#
#  Increased productivity: Users would be able to find the information they need more quickly and easily, reducing the time they spend searching for videos.
#  Improved learning: Users would be able to study videos more effectively by being able to read the transcripts while they watch.
#  Enhanced accessibility: Users who are deaf or hard of hearing would be able to access the content of videos without having to rely on audio.
#
# Call to action
#
# I am seeking a proficient Python developer to design a script for me that will extract the transcripts of YouTube videos and save them as a text file. This script would have a number of benefits, including increased productivity, improved learning, and enhanced accessibility. I am confident that this project would be a valuable addition to the Python community.
# Proposal saved to proposal.txt
# Generated proposal: Social Media Data Extraction Tool
#
# Problem: Social media platforms are a treasure trove of data, but it can be difficult to extract and use this data in a meaningful way.
#
# Solution: A social media data extraction tool can help businesses and researchers access this data and use it to improve their marketing, customer insights, and product development.
#
# Benefits: A social media data extraction tool can provide a number of benefits, including:
#
#  Increased insights into customer behavior
#  Improved targeting and personalization of marketing campaigns
#  Better understanding of the competition
#  Faster product development
#
# Impact: A social media data extraction tool can have a significant impact on businesses and researchers by helping them to make better decisions and achieve their goals.
#
# Call to action: If you are interested in learning more about our social media data extraction tool, please contact us today.
# Proposal saved to proposal.txt
# Generated proposal: Django & MySQL Database Management System
#
# Project Description
#
# I'm looking for a talented Python developer with a solid understanding of Django and MySQL to help me create a database management system for my company. The system will be used to store and manage data from our various business operations.
#
# Project Value and Impact
#
# The database management system will be a valuable asset to our company. It will help us to improve efficiency, accuracy, and security of our data. It will also allow us to better track and analyze our business operations, which will lead to improved decision-making.
#
# Project Timeline
#
# The project is expected to take 6-8 weeks to complete.
#
# Project Budget
#
# The project budget is \$10,000.
#
# Project Contact
#
# If you are interested in this project, please contact me at [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Python Appium Expert for Mobile Testing
#
# Mobile testing is essential for ensuring the quality of mobile apps. However, manual mobile testing is time-consuming and error-prone. Python Appium Expert for Mobile Testing is a tool that automates mobile testing, making it faster, easier, and more accurate.
#
# With Python Appium Expert for Mobile Testing, you can:
#
#  Automate tests across multiple platforms and devices
#  Run tests in parallel to save time
#  Get detailed reports on test results
#  Easily debug tests
#
# Python Appium Expert for Mobile Testing is the perfect tool for teams that want to improve the quality of their mobile apps. It is easy to use and can save you time and money.
#
# Value:
#
#  Save time and money by automating mobile testing
#  Improve the quality of your mobile apps by catching bugs early
#  Increase the speed and efficiency of your mobile testing process
#
# Impact:
#
#  Increased productivity
#  Improved quality
#  Reduced costs
# Proposal saved to proposal.txt
# Generated proposal: Python Script Hosting & Auto-Update Deployment Proposal
#
# Problem:
#
# Managing and deploying Python scripts can be a time-consuming and error-prone process. Developers need to manually upload scripts to a server, configure the server to run the scripts, and then update the scripts whenever there are new changes. This process can be especially challenging for teams that are working on multiple projects or that are constantly making changes to their scripts.
#
# Solution:
#
# This proposal proposes a solution to the problem of managing and deploying Python scripts. The solution involves using a cloud-based platform to host the scripts and automatically deploy updates. This would allow developers to focus on writing code, rather than worrying about the infrastructure needed to run it.
#
# Benefits:
#
# The benefits of this solution include:
#
#  Reduced time and effort: Developers would no longer need to manually upload scripts to a server or configure the server to run them.
#  Improved accuracy: The scripts would be automatically updated, so developers would not need to worry about missing a new change.
#  Increased flexibility: Developers could easily deploy scripts to multiple servers or environments.
#
# Key Deliverables:
#
# The key deliverables of this project include:
#
#  A cloud-based platform to host the Python scripts.
#  A system to automatically deploy updates to the scripts.
#  Documentation and training materials to help developers get started.
#
# Cost:
#
# The cost of this project would be \$10,000. This cost would cover the development and implementation of the platform and system, as well as the documentation and training materials.
#
# Timeline:
#
# This project could be completed in 6 months.
#
# Conclusion:
#
# This proposal has outlined a solution to the problem of managing and deploying Python scripts. The solution would provide a number of benefits to developers, including reduced time and effort, improved accuracy, and increased flexibility. The project could be completed in 6 months for a cost of \$10,000.
# Proposal saved to proposal.txt
# Generated proposal: JSON Creation & System Integration Specialist
#
# Summary
#
# We are seeking a skilled programmer and developer proficient in C programming, JavaScript, and Python to create JSON objects and integrate them with our systems. This role will be critical to the success of our next-generation product development.
#
# Value
#
# The successful candidate will be responsible for creating and maintaining JSON objects that represent our data. They will also be responsible for integrating these objects with our systems so that they can be easily accessed and used by our developers. This work will have a significant impact on the speed and efficiency of our product development process.
#
# Impact
#
# The successful candidate will make a significant impact on the speed and efficiency of our product development process. By creating and maintaining JSON objects that represent our data, and by integrating these objects with our systems, they will enable our developers to access and use data more easily. This will lead to faster development cycles and higher-quality products.
#
# Desired Skills
#
# The ideal candidate will have experience in C programming, JavaScript, and Python. They will also have experience in JSON object creation and system integration. In addition, they will have a strong understanding of software engineering principles and practices.
# Proposal saved to proposal.txt
# Generated proposal: Python Code for Data Analysis
#
# Problem
#
# You are in need of a skilled Python coder to create a script for data analysis. The project is urgent and you need someone who can get started immediately.
#
# Solution
#
# I am a Python coder with over 10 years of experience. I have a proven track record of success in developing data analysis scripts. I am confident that I can help you with this project and get it completed on time and within budget.
#
# Benefits
#
# By hiring me, you will get the following benefits:
#
#  A skilled Python coder who can get started immediately
#  A proven track record of success in developing data analysis scripts
#  A commitment to quality and on-time delivery
#
# Call to Action
#
# If you are interested in hiring me for this project, please contact me at [email protected] I look forward to hearing from you soon.
# Proposal saved to proposal.txt
# Generated proposal: Plaid API Asset Keys Integration Proposal
#
# Problem
#
# Our current Plaid integration does not support asset keys, which limits our ability to provide our customers with a seamless experience. Without asset keys, we are unable to programmatically create and manage customer accounts, which can lead to errors and delays.
#
# Solution
#
# Integrating Plaid API asset keys will allow us to:
#
#  Automatically create and manage customer accounts
#  Reduce the risk of errors and delays
#  Improve the customer experience
#
# Benefits
#
# The benefits of integrating Plaid API asset keys include:
#
#  Increased efficiency: We will be able to automate account creation and management, which will save time and resources.
#  Reduced risk: Asset keys will help us to prevent errors and delays, which will improve the customer experience.
#  Improved customer experience: Customers will be able to create and manage their accounts more easily, which will increase their satisfaction.
#
# Cost
#
# The cost of integrating Plaid API asset keys is estimated to be \$10,000.
#
# Timeline
#
# The integration is expected to take 6 weeks to complete.
#
# Conclusion
#
# Integrating Plaid API asset keys is a valuable investment that will improve the efficiency, security, and customer experience of our Plaid integration. We recommend that we proceed with this project.
# Proposal saved to proposal.txt
# Generated proposal: Graph Neural Networks (GNNs) have emerged as a powerful tool for machine learning on graphs. They have been successfully applied to a wide range of tasks, including natural language processing, computer vision, and robotics. However, implementing GNNs can be challenging, as it requires expertise in both graph theory and deep learning.
#
# This project will develop a Python library for implementing GNNs. The library will be easy to use, making it accessible to researchers and practitioners who are not experts in graph theory or deep learning. The library will also be efficient, making it suitable for large-scale problems.
#
# The library will have a number of benefits. First, it will make it easier for researchers to develop new GNN models. Second, it will make it easier for practitioners to use GNNs on real-world problems. Third, it will help to promote the adoption of GNNs by making them more accessible.
#
# In summary, this project has the potential to significantly impact the field of machine learning on graphs. It will make it easier for researchers and practitioners to develop and use GNNs, which will lead to new insights and applications.
# Proposal saved to proposal.txt
# Generated proposal: Lunatic Driving Part-2: A Follow-up to the "Python API in Carla for Driving AI" Project
#
# Project Overview
#
# The goal of this project is to develop a more capable and robust driving AI agent that can handle more challenging driving scenarios. This will be accomplished by building on the work done in the "Python API in Carla for Driving AI" project, which developed a basic driving AI agent that could navigate around a simulated environment.
#
# Project Objectives
#
# The specific objectives of this project are to:
#
#  Develop a more robust and generalizable driving AI agent that can handle a wider range of driving scenarios.
#  Improve the performance of the driving AI agent by making it more efficient and less prone to errors.
#  Make the driving AI agent more accessible to developers by providing a more user-friendly API.
#
# Project Impact
#
# The successful completion of this project will have a significant impact on the field of autonomous driving. By developing a more capable and robust driving AI agent, this project will help to pave the way for the development of fully autonomous vehicles.
#
# Project Timeline
#
# This project will be completed in three phases:
#
#  Phase 1: Development of a more robust and generalizable driving AI agent (6 months)
#  Phase 2: Improvement of the performance of the driving AI agent (3 months)
#  Phase 3: Development of a more user-friendly API (3 months)
#
# Project Budget
#
# The total cost of this project is estimated to be \$100,000.
#
# Project Team
#
# The project team will consist of a team of experienced engineers and researchers with expertise in the fields of autonomous driving, machine learning, and computer vision.
#
# Project Risks
#
# The main risks associated with this project are:
#
#  The development of a robust and generalizable driving AI agent is a challenging task. There is a risk that the project team may not be able to achieve this goal.
#  The development of a more user-friendly API is also a challenging task. There is a risk that the project team may not be able to create an API that is easy to use and understand.
#
# Project Benefits
#
# The successful completion of this project will have a number of benefits, including:
#
#  The development of a more capable and robust driving AI agent will help to pave the way for the development of fully autonomous vehicles.
#  The improvement of the performance of the driving AI agent will make it more likely that autonomous vehicles will be able to operate safely and efficiently in real-world driving scenarios.
#  The development of a more user-friendly API will make it easier for developers to create and deploy autonomous driving systems.
# Proposal saved to proposal.txt
#          _id  _owner_id                                             _title  \
# 0   37866132   75050954          Python Email Filtering with Pfsense Setup
# 1   37866054   75048166             Python Expert for Diverse Tech Project
# 2   37866023   14082382  Typescript to intyeract with Telethon and Tele...
# 3   37866019   73783125                       Python Script & Telegram API
# 4   37865995   75050049            Customized Basic Calculator Development
# 5   37865881   58692612          YouTube Transcript Extractor & Downloader
# 6   37865865   74628051                  Social Media Data Extraction Tool
# 7   37865847   64614480          Django & MySQL Database Management System
# 8   37865839   70808065            Python Appium Expert for Mobile Testing
# 9   37865816   53227908     Python Script Hosting & Auto-Update Deployment
# 10  37865739   18578548      JSON Creation & System Integration Specialist
# 11  37865713   67187299                      Python Code for Data Analysis
# 12  37865701   75048318                   Plaid API Asset Keys Integration
# 13  37865617   14558179                        Implement GNNs with PyTorch
# 14  37865609   73570530                             Lunatic Driving Part-2
#
#    _status                                           _seo_url  _currency_id  \
# 0   active         python/Python-Email-Filtering-with-Pfsense             1
# 1   active              python/Python-Expert-for-Diverse-Tech             1
# 2   active      typescript/Typescript-intyeract-with-Telethon             1
# 3   active                  python/Python-Script-Telegram-API             8
# 4   active  website-design/Customized-Basic-Calculator-Dev...             4
# 5   active      linux/YouTube-Transcript-Extractor-Downloader             1
# 6   active     web-scraping/Social-Media-Data-Extraction-Tool             1
# 7   closed     python/Django-MySQL-Database-Management-System             8
# 8   active             python/Python-Appium-Expert-for-Mobile             1
# 9   closed                  Python-Script-Hosting-Auto-Update             4
# 10  active            python/JSON-Creation-System-Integration             6
# 11  active      python/Python-Code-for-Data-Analysis-37865713            11
# 12  active            python/Plaid-API-Asset-Keys-Integration             1
# 13  active                 python/Implement-GNNs-with-PyTorch             3
# 14  closed                        python/Lunatic-Driving-Part             8
#
#    _currency_code _currency_sign     _currency_name  _currency_exchange_rate  \
# 0             USD              $          US Dollar                 1.000000
# 1             USD              $          US Dollar                 1.000000
# 2             USD              $          US Dollar                 1.000000
# 3             EUR              €               Euro                 1.092720
# 4             GBP              £     British Pounds                 1.281042
# 5             USD              $          US Dollar                 1.000000
# 6             USD              $          US Dollar                 1.000000
# 7             EUR              €               Euro                 1.092720
# 8             USD              $          US Dollar                 1.000000
# 9             GBP              £     British Pounds                 1.281042
# 10            SGD              $   Singapore Dollar                 0.751453
# 11            INR              ₹       Indian Rupee                 0.012086
# 12            USD              $          US Dollar                 1.000000
# 13            AUD              $  Australian Dollar                 0.661090
# 14            EUR              €               Euro                 1.092720
#
#     ... _is_escrow_project  _is_seller_kyc_required  _is_buyer_kyc_required  \
# 0   ...              False                    False                   False
# 1   ...              False                    False                   False
# 2   ...              False                    False                   False
# 3   ...              False                    False                   False
# 4   ...              False                    False                   False
# 5   ...              False                    False                   False
# 6   ...              False                    False                   False
# 7   ...              False                    False                   False
# 8   ...              False                    False                   False
# 9   ...              False                    False                   False
# 10  ...              False                    False                   False
# 11  ...              False                    False                   False
# 12  ...              False                    False                   False
# 13  ...              False                    False                   False
# 14  ...              False                    False                   False
#
#     _enterprises _group_ids     _sub_status  \
# 0             []         []             NaN
# 1             []         []             NaN
# 2             []         []             NaN
# 3             []         []             NaN
# 4             []         []             NaN
# 5             []         []             NaN
# 6             []         []             NaN
# 7             []         []  closed_awarded
# 8             []         []             NaN
# 9             []         []  closed_awarded
# 10            []         []             NaN
# 11            []         []             NaN
# 12            []         []             NaN
# 13            []         []             NaN
# 14            []         []  closed_awarded
#
#     _hourly_project_info_commitment_hours  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                    40.0
# 8                                     NaN
# 9                                     NaN
# 10                                   40.0
# 11                                   40.0
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
#
#     _hourly_project_info_commitment_interval  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                       week
# 8                                        NaN
# 9                                        NaN
# 10                                      week
# 11                                      week
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
#
#    _hourly_project_info_duration_enum  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                         unspecified
# 8                                 NaN
# 9                                 NaN
# 10                        unspecified
# 11                        unspecified
# 12                                NaN
# 13                                NaN
# 14                                NaN
#
#                                              proposal
# 0   Python Email Filtering with Pfsense Setup\n\nP...
# 1   Python Expert for Diverse Tech Project\n\nWe a...
# 2   Proposal for a Typescript project to interact ...
# 3   Python Script & Telegram API\n\nProblem\n\nYou...
# 4   Custom Basic Calculator Development\n\nWe are ...
# 5   YouTube Transcript Extractor & Downloader\n\nP...
# 6   Social Media Data Extraction Tool\n\nProblem: ...
# 7   Django & MySQL Database Management System\n\nP...
# 8   Python Appium Expert for Mobile Testing\n\nMob...
# 9   Python Script Hosting & Auto-Update Deployment...
# 10  JSON Creation & System Integration Specialist\...
# 11  Python Code for Data Analysis\n\nProblem\n\nYo...
# 12  Plaid API Asset Keys Integration Proposal\n\nP...
# 13  Graph Neural Networks (GNNs) have emerged as a...
# 14  Lunatic Driving Part-2: A Follow-up to the "Py...
#
# [15 rows x 59 columns]
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

def create_bid_object(id, bidder_id, project_id, retracted, amount, period,
                      description, project_owner_id):
    b = {
        'id': id,
        'bidder_id': bidder_id,
        'project_id': project_id,
        'retracted': retracted,
        'amount': amount,
        'period': period,
        'description': description,
        'project_owner_id': project_owner_id
    }

    return b

def sample_search_projects(sort_field='last_updated'):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=15,  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    
    # Filter projects based on language
    english_projects = [project for project in projects if project.get('language') == 'en']
    
    # Sort projects based on the specified field
    sorted_projects = sorted(english_projects, key=lambda x: x.get(sort_field, ''))

    return sorted_projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    for project in projects:
        project_title = project['title']
        project_description = project['preview_description']
        proposal = generate_proposal(project_title, project_description)
        proposals.append(proposal)
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

# Call the function to retrieve projects and print them with proposals
projects = sample_search_projects(sort_field='last_updated')
print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: Python Specialist for Stable Diffusion
#
# Problem
#
# Stable diffusion is a technique for solving partial differential equations (PDEs) that is often more efficient than traditional methods. However, it can be difficult to implement stable diffusion in Python, as it requires a deep understanding of the underlying mathematics.
#
# Solution
#
# I am a Python specialist with extensive experience in stable diffusion. I have a deep understanding of the mathematics behind stable diffusion, and I am able to implement it efficiently in Python. I have successfully used stable diffusion to solve a variety of PDEs, including those arising in fluid dynamics, heat transfer, and electromagnetism.
#
# Benefits
#
# Using a Python specialist for stable diffusion will provide you with the following benefits:
#
#  Accuracy: Stable diffusion is a highly accurate method for solving PDEs. Using a Python specialist will ensure that your simulations are accurate and reliable.
#  Efficiency: Stable diffusion can be computationally expensive. Using a Python specialist will help you to implement stable diffusion in a way that is efficient and scalable.
#  Reproducibility: Stable diffusion can be difficult to implement correctly. Using a Python specialist will help you to create reproducible simulations that can be shared with others.
#
# Conclusion
#
# I am confident that I can help you to solve your PDEs using stable diffusion in Python. I have the expertise, experience, and skills to get the job done. Contact me today to discuss your project.
#
# Ideal Candidate
#
# The ideal candidate for this position will have the following qualifications:
#
#  Expertise in Python: The ideal candidate will have extensive experience in Python programming. They will be familiar with the Python standard library, as well as with popular Python libraries for scientific computing, such as NumPy, SciPy, and Pandas.
#  Experience in Stable Diffusion: The ideal candidate will have experience in implementing stable diffusion in Python. They will have a deep understanding of the mathematics behind stable diffusion, and they will be able to implement it efficiently and accurately.
#  Strong Problem-Solving Skills: The ideal candidate will have strong problem-solving skills. They will be able to identify and solve problems effectively, and they will be able to work independently and as part of a team.
#  Excellent Communication Skills: The ideal candidate will have excellent communication skills. They will be able to clearly explain their work to others, and they will be able to work effectively with clients and stakeholders.
# Proposal saved to proposal.txt
# Generated proposal: Python to Django Transformation Expert Needed
#
# Problem
#
# You are a proficient Python developer with experience in Django. You are familiar with the ins and outs of both languages and are able to seamlessly convert existing Python code to Django. You are also able to work independently and meet deadlines.
#
# Solution
#
# I am offering you a contract to transform my existing Python code to Django. This is a challenging but rewarding project that will allow you to use your skills and experience to the fullest. The project will be completed in a timely manner and will meet all of your specifications.
#
# Benefits
#
# This project will provide you with the opportunity to:
#
#  Gain experience in converting Python code to Django
#  Work independently and meet deadlines
#  Improve your skills and knowledge of both Python and Django
#  Make a significant contribution to a real-world project
#
# If you are interested in this project, please contact me at [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Pronunciation Coach AI -- 3
#
# Problem: Pronunciation is a critical skill for communication, but it can be difficult to learn and improve. Traditional pronunciation training methods are often ineffective and time-consuming.
#
# Solution: Pronunciation Coach AI is an AI-driven pronunciation evaluation tool that provides instant feedback on pronunciation errors. It uses a combination of speech recognition and machine learning to identify and correct pronunciation mistakes.
#
# Benefits: Pronunciation Coach AI can help learners of all levels improve their pronunciation quickly and easily. It is perfect for students, professionals, and anyone else who wants to improve their communication skills.
#
# Impact: Pronunciation Coach AI has the potential to revolutionize the way people learn pronunciation. It can help learners of all levels improve their pronunciation quickly and easily, leading to better communication and increased opportunities.
#
# Call to action: I am seeking an expert to create an AI-driven pronunciation evaluation tool with the following capabilities:
#
#  Instant feedback on pronunciation errors
#  Ability to identify and correct pronunciation mistakes
#  Suitable for learners of all levels
#
# If you are interested in this project, please contact me at [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Multifaceted Software Developer Needed
#
# We are looking for a highly skilled software developer with experience in Python, Java, and C++. The ideal candidate will be able to work independently and as part of a team, and will be able to quickly learn new technologies.
#
# This is a full-time position with a competitive salary and benefits. The successful candidate will be based in our San Francisco office.
#
# Why this role is important
#
# We are a rapidly growing company that is developing innovative software solutions. We need a talented software developer to help us take our products to the next level.
#
# The impact you will have
#
# As a software developer on our team, you will have the opportunity to make a real impact on our business. You will work on projects that are challenging and rewarding, and you will be able to see the results of your work firsthand.
#
# To apply
#
# Please send your resume and a cover letter to [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Python Guru for Salesforce Reports Encoding
#
# Problem: I'm currently struggling with an encoding issue in my Salesforce reports. These reports are in CSV format, and when I open them in Excel, I get a lot of garbled characters.
#
# Solution: I propose hiring a Python guru to help me fix this issue. The Python guru will be able to identify the source of the problem and implement a solution that will allow me to open my Salesforce reports in Excel without any problems.
#
# Benefits:
#
#  The Python guru will be able to fix the encoding issue quickly and efficiently.
#  I will be able to open my Salesforce reports in Excel without any problems.
#  I will be able to use the data in my Salesforce reports to make better business decisions.
#
# Cost: The cost of hiring a Python guru will be \$1,000.
#
# Timeline: The Python guru will be able to fix the encoding issue within 1 week.
#
# Guarantee: I am confident that the Python guru will be able to fix the encoding issue. If not, I will not be charged for their services.
#
# Approval: Please approve my request to hire a Python guru so that I can resolve this issue and continue to use my Salesforce reports to make better business decisions.
# Proposal saved to proposal.txt
# Generated proposal: Image Recognition Software Development Proposal
#
# Problem
#
# Image recognition is a key technology for a wide range of applications, from facial recognition to self-driving cars. However, current image recognition algorithms are often limited by their reliance on large datasets of labeled images. This can make it difficult to deploy image recognition systems in new domains or to use them for tasks where labeled data is scarce.
#
# Solution
#
# We propose to develop a new image recognition software that uses a novel approach to learning from unlabeled data. Our approach is based on the idea of self-supervised learning, which allows models to learn from data without the need for human-annotated labels. This will make it possible to deploy image recognition systems in new domains or to use them for tasks where labeled data is scarce.
#
# Benefits
#
# Our proposed image recognition software has the potential to have a significant impact on a wide range of applications. For example, it could be used to:
#
#  Improve the accuracy of facial recognition systems
#  Enable self-driving cars to navigate safely in unfamiliar environments
#  Detect fraud in financial transactions
#  Identify medical conditions from medical images
#
# Cost
#
# The cost of developing our proposed image recognition software is estimated to be \$100,000.
#
# Timeline
#
# We expect to complete the development of our proposed image recognition software within 12 months.
# Proposal saved to proposal.txt
# Generated proposal: Python Coder for Stock Market Strategy
#
# Problem
#
# The stock market is a complex and ever-changing landscape. In order to make informed investment decisions, investors need access to the latest data and insights. However, manually gathering and analyzing this data can be time-consuming and difficult.
#
# Solution
#
# A Python coder specialized in stock market strategies can help investors by automating the process of data collection and analysis. This can give investors a competitive edge by providing them with the information they need to make informed investment decisions.
#
# Benefits
#
# A Python coder for stock market strategy can provide investors with a number of benefits, including:
#
#  Increased speed and efficiency: By automating the process of data collection and analysis, a Python coder can help investors save time and resources.
#  Improved accuracy: A Python coder can use complex algorithms to analyze data and identify potential investment opportunities.
#  Reduced risk: By providing investors with the information they need to make informed investment decisions, a Python coder can help them reduce their risk.
#
# Call to Action
#
# If you are an investor looking for a competitive edge, a Python coder specialized in stock market strategies can help you achieve your goals. Contact us today to learn more about how we can help you make informed investment decisions.
# Proposal saved to proposal.txt
# Generated proposal: Python Training and Real-World Experience Proposal
#
# Problem:
#
# In today's competitive job market, it is essential for software developers to have strong programming skills in Python. Python is a versatile language that is used in a wide variety of industries, including web development, data science, and machine learning. However, many developers lack the real-world experience they need to be successful in these fields.
#
# Solution:
#
# This proposal recommends a Python training and real-world experience program that will help developers gain the skills and experience they need to be successful in their careers. The program will include a combination of theoretical training and hands-on experience working on real-world projects.
#
# Benefits:
#
# The benefits of this program include:
#
#  Increased job prospects: Developers who complete this program will be more marketable to employers and will have a greater chance of landing a high-paying job in the tech industry.
#  Improved skills: The program will provide developers with the skills they need to be successful in a variety of programming roles.
#  Real-world experience: The program will give developers the opportunity to work on real-world projects and gain experience that they can use in their careers.
#
# Impact:
#
# This program will have a significant impact on the developer community by helping developers gain the skills and experience they need to be successful in their careers. The program will also help employers find qualified candidates for open positions.
# Proposal saved to proposal.txt
# Generated proposal: Specific Site Web Scraping Specialist
#
# Problem
#
# I am in need of a skilled web scraping coder to help me collect and analyze data from a specific website. The data I need is essential for my research project, and I am confident that it will have a significant impact on the field.
#
# Solution
#
# With your expertise, I can quickly and efficiently scrape the data I need from the website. This data will allow me to conduct a more thorough and comprehensive analysis, which will ultimately lead to more robust and reliable results.
#
# Benefits
#
# The benefits of hiring a web scraping specialist are clear:
#
#  Accuracy: By using a web scraping specialist, you can be confident that the data you collect is accurate and complete.
#  Speed: A web scraping specialist can collect data much faster than you could manually. This will allow you to complete your research project more quickly and efficiently.
#  Cost-effectiveness: Hiring a web scraping specialist is more cost-effective than hiring a full-time employee or using a third-party data collection service.
#
# Conclusion
#
# I am confident that hiring a web scraping specialist would be a wise investment for my research project. The benefits of accuracy, speed, and cost-effectiveness would make a significant impact on the success of my project.
# Proposal saved to proposal.txt
# Generated proposal: Expert Development Technician Needed
#
# We are seeking an experienced development technician to assist with the development of a new software platform. The ideal candidate will have a strong understanding of software development principles and practices, as well as experience in working with a variety of programming languages and technologies.
#
# This is a critical role on our team, and the successful candidate will have a significant impact on the development of our platform. The successful candidate will be responsible for:
#
#  Developing new features and functionality for the platform
#  Debugging and fixing defects
#  Unit testing and integration testing
#  Collaborating with other team members to ensure that the platform meets our high standards of quality
#
# We offer a competitive salary and benefits package, as well as the opportunity to work on a cutting-edge project with a talented team of developers. If you are interested in this position, please send your resume and cover letter to us at [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Immediate Python Data Science Expertise Needed
#
# We are seeking a data scientist with extensive Python experience to assist with a unique project that will revolutionize the way we think about data. The project will involve developing and implementing machine learning algorithms to analyze large datasets of healthcare data. The successful candidate will be highly motivated and have a strong background in Python, machine learning, and statistics.
#
# This is a unique opportunity to work on a cutting-edge project that has the potential to make a real impact on the world. The successful candidate will be joining a team of talented researchers and engineers who are passionate about using data to solve real-world problems.
#
# Why you should join this project:
#
#  The project is unique and has the potential to revolutionize the way we think about data.
#  You will be working with a team of talented researchers and engineers.
#  You will have the opportunity to make a real impact on the world.
#
# To apply, please send your resume and a cover letter to [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Python Web App Security Enhancements
#
# Problem
#
# Your Python web app is vulnerable to a variety of security threats, including:
#
#  Cross-site scripting (XSS) attacks
#  SQL injection attacks
#  Denial of service (DoS) attacks
#  Man-in-the-middle (MitM) attacks
#
# Solution
#
# By implementing a series of security enhancements, we can help you protect your Python web app from these threats. Our security enhancements will include:
#
#  Input validation to prevent XSS attacks
#  Encryption to protect sensitive data from SQL injection attacks
#  Rate limiting to prevent DoS attacks
#  Firewalls and intrusion detection systems to protect against MitM attacks
#
# Benefits
#
# By implementing these security enhancements, you will gain the following benefits:
#
#  Increased security: Your web app will be more resistant to a variety of attacks, making it less likely to be compromised.
#  Improved performance: Our security enhancements will not slow down your web app.
#  Reduced risk: You will reduce your risk of data breaches, financial losses, and reputation damage.
#
# Call to action
#
# If you are interested in learning more about our Python web app security enhancements, please contact us today. We will be happy to discuss your specific needs and provide you with a free quote.
#
# Contact us
#
# [Your contact information]
# Proposal saved to proposal.txt
# Generated proposal: E-commerce Platform for Physical Product Reselling
#
# Problem:
#
# The current process of reselling physical products is inefficient and time-consuming. Buyers must search for products on multiple platforms, compare prices, and contact sellers individually. This process is often frustrating and can lead to missed opportunities.
#
# Solution:
#
# An e-commerce platform for physical product reselling would provide a centralized marketplace where buyers and sellers can connect. This would make it easier for buyers to find the products they want and for sellers to reach a wider audience. The platform would also offer features such as price comparison, product reviews, and secure payment processing.
#
# Benefits:
#
# An e-commerce platform for physical product reselling would have a number of benefits, including:
#
#  Increased convenience for buyers and sellers
#  Reduced search time and costs
#  Increased sales for sellers
#  Improved customer satisfaction
#
# Call to action:
#
# I am seeking an adept professional to build an e-commerce platform from scratch. The platform should be scalable and user-friendly, and it should offer a variety of features to help buyers and sellers connect. If you are interested in this project, please contact me at [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Numeric Data Importation: Excel to Microsoft Azure Data Studio
#
# Overview
#
# This proposal is for a project to import numeric data from Excel to Microsoft Azure Data Studio. The data will be used to create a dashboard that will provide insights into the company's sales performance.
#
# Why This Project Matters
#
# The insights that will be generated from this project will help the company to make better decisions about its sales strategy. The dashboard will provide a visual representation of the data, making it easy to identify trends and patterns. This information will help the company to allocate resources more effectively and to target its marketing efforts more efficiently.
#
# What We Need
#
# We need a skilled freelancer with profound expertise in Excel and SQL to complete this project. The freelancer will need to be able to:
#
#  Import data from Excel into Microsoft Azure Data Studio
#  Create a dashboard that visualizes the data
#  Provide insights into the data
#
# Benefits of Working With Us
#
# We are a fast-growing company that is always looking for new ways to improve our business. We offer a competitive salary and benefits package, and we are committed to providing our employees with a supportive and collaborative work environment.
#
# If you are interested in this project, please send us your resume and a cover letter.
# Proposal saved to proposal.txt
# Generated proposal: Python, Node.js, and Typescript Installation on Windows
#
# Problem: You need professional assistance to set up Python, Node.js, and Typescript on your Windows operating system.
#
# Solution: I will provide you with a detailed plan for installing and configuring these three programming languages on your system. I will also provide you with support and guidance throughout the process.
#
# Benefits:
#
#  You will be able to use Python, Node.js, and Typescript to develop powerful and complex applications.
#  You will be able to take advantage of the latest features and updates to these languages.
#  You will be able to collaborate with other developers who are using these languages.
#
# Cost: The cost of this project is \$200.
#
# Timeline: The project will take approximately 2 weeks to complete.
#
# Guarantee: I am confident that I can successfully complete this project and that you will be satisfied with the results. If you are not satisfied with my work, I will refund your money.
#
# Contact: If you are interested in this project, please contact me at [email protected]
# Proposal saved to proposal.txt
#          _id  _owner_id                                             _title  \
# 0   37868545   54989278             Python Specialist for Stable Diffusion
# 1   37868505   66969294      Python to Django Transformation Expert Needed
# 2   37868459   69913718                        Pronunciation Coach AI -- 3
# 3   37868449   75063701             Multifaceted Software Developer Needed
# 4   37868397   69909035        Python Guru for Salesforce Reports Encoding
# 5   37868336   64022776             Image Recognition Software Development
# 6   37868256   75062536             Python Coder for Stock Market Strategy
# 7   37868126   23310707    Python trining and real time experience needed
# 8   37868068   14558179              Specific Site Web Scraping Specialist
# 9   37867945   74905240               Expert Development Technician Needed
# 10  37867908   75060579     Immediate Python Data Science Expertise Needed
# 11  37867896   75060489               Python Web App Security Enhancements
# 12  37867886   75046222  E-commerce Platform for Physical Product Resel...
# 13  37867853   75060328  Numeric Data Importation: Excel to Microsoft A...
# 14  37867781   28629207  Python, Node.js, Typescript Installation on Wi...
#
#    _status                                          _seo_url  _currency_id  \
# 0   active     python/Python-Specialist-for-Stable-Diffusion             1
# 1   active               Python-Django-Transformation-Expert             1
# 2   active                           api/Pronunciation-Coach             1
# 3   active     python/Multifaceted-Software-Developer-Needed            11
# 4   active         python/Python-Guru-for-Salesforce-Reports             3
# 5   active  algorithm/Image-Recognition-Software-Development            11
# 6   active              python/Python-Coder-for-Stock-Market            11
# 7   active        python/Python-trining-real-time-experience             1
# 8   active      python/Specific-Site-Web-Scraping-Specialist             3
# 9   active          php/Expert-Development-Technician-Needed             3
# 10  active    python/Immediate-Python-Data-Science-Expertise            11
# 11  frozen       python/Python-Web-App-Security-Enhancements            11
# 12  active      sales/commerce-Platform-for-Physical-Product            11
# 13  active          excel/Daily-Numeric-Data-Migration-Excel             1
# 14  active        python/Python-Node-Typescript-Installation             1
#
#    _currency_code _currency_sign     _currency_name  _currency_exchange_rate  \
# 0             USD              $          US Dollar                 1.000000
# 1             USD              $          US Dollar                 1.000000
# 2             USD              $          US Dollar                 1.000000
# 3             INR              ₹       Indian Rupee                 0.012085
# 4             AUD              $  Australian Dollar                 0.661523
# 5             INR              ₹       Indian Rupee                 0.012085
# 6             INR              ₹       Indian Rupee                 0.012085
# 7             USD              $          US Dollar                 1.000000
# 8             AUD              $  Australian Dollar                 0.661523
# 9             AUD              $  Australian Dollar                 0.661523
# 10            INR              ₹       Indian Rupee                 0.012085
# 11            INR              ₹       Indian Rupee                 0.012085
# 12            INR              ₹       Indian Rupee                 0.012085
# 13            USD              $          US Dollar                 1.000000
# 14            USD              $          US Dollar                 1.000000
#
#     ... _is_escrow_project  _is_seller_kyc_required  _is_buyer_kyc_required  \
# 0   ...              False                    False                   False
# 1   ...              False                    False                   False
# 2   ...              False                    False                   False
# 3   ...              False                    False                   False
# 4   ...              False                    False                   False
# 5   ...              False                    False                   False
# 6   ...              False                    False                   False
# 7   ...              False                    False                   False
# 8   ...              False                    False                   False
# 9   ...              False                    False                   False
# 10  ...              False                    False                   False
# 11  ...              False                    False                   False
# 12  ...              False                    False                   False
# 13  ...              False                    False                   False
# 14  ...              False                    False                   False
#
#     _enterprises _group_ids  _hourly_project_info_commitment_hours  \
# 0             []         []                                    NaN
# 1             []         []                                    NaN
# 2             []         []                                    NaN
# 3             []         []                                    NaN
# 4             []         []                                    NaN
# 5             []         []                                    NaN
# 6             []         []                                    NaN
# 7             []         []                                    NaN
# 8             []         []                                    NaN
# 9             []         []                                   40.0
# 10            []         []                                    NaN
# 11            []         []                                    NaN
# 12            []         []                                    NaN
# 13            []         []                                    NaN
# 14            []         []                                    NaN
#
#     _hourly_project_info_commitment_interval  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                       week
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
#
#     _hourly_project_info_duration_enum     _sub_status  \
# 0                                  NaN             NaN
# 1                                  NaN             NaN
# 2                                  NaN             NaN
# 3                                  NaN             NaN
# 4                                  NaN             NaN
# 5                                  NaN             NaN
# 6                                  NaN             NaN
# 7                                  NaN             NaN
# 8                                  NaN             NaN
# 9                          unspecified             NaN
# 10                                 NaN             NaN
# 11                                 NaN  frozen_timeout
# 12                                 NaN             NaN
# 13                                 NaN             NaN
# 14                                 NaN             NaN
#
#                                              proposal
# 0   Python Specialist for Stable Diffusion\n\nProb...
# 1   Python to Django Transformation Expert Needed\...
# 2   Pronunciation Coach AI -- 3\n\nProblem: Pronun...
# 3   Multifaceted Software Developer Needed\n\nWe a...
# 4   Python Guru for Salesforce Reports Encoding\n\...
# 5   Image Recognition Software Development Proposa...
# 6   Python Coder for Stock Market Strategy\n\nProb...
# 7   Python Training and Real-World Experience Prop...
# 8   Specific Site Web Scraping Specialist\n\nProbl...
# 9   Expert Development Technician Needed\n\nWe are...
# 10  Immediate Python Data Science Expertise Needed...
# 11  Python Web App Security Enhancements\n\nProble...
# 12  E-commerce Platform for Physical Product Resel...
# 13  Numeric Data Importation: Excel to Microsoft A...
# 14  Python, Node.js, and Typescript Installation o...
#
# [15 rows x 59 columns]
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

# Define helper functions
def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = ''
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    full_descriptions = []
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    # Selecting only specific columns
    selected_columns = [
       '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
        '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'

    ]
    df = df[selected_columns]
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: Urgent Need: Python Flask Specialist
#
# Project Description
#
# We are looking for a Python Flask specialist to join our team of engineers. The ideal candidate will have experience with Python, Flask, and SQL. The primary responsibility of this role will be to develop and maintain web applications using the Flask framework. The successful candidate will be able to work independently and as part of a team, and will have a strong understanding of software engineering principles.
#
# Why This Project Matters
#
# This project is critical to the success of our company. We are developing a new web application that will revolutionize the way we do business. The Python Flask specialist will be responsible for developing the core functionality of the application. This role is essential to the success of the project, and we are confident that the right candidate will make a significant impact on our team.
#
# Benefits of Working on This Project
#
# This is a highly visible and challenging role that will give you the opportunity to work on cutting-edge technology. You will be part of a team of talented engineers and will have the opportunity to learn from and collaborate with them. You will also have the opportunity to make a significant impact on the success of our company.
# Proposal saved to proposal.txt
# Generated proposal: Data Science Mock Interview Expert
#
# Data science is a hot field, and the demand for skilled professionals is growing rapidly. However, getting a job in data science can be challenging, especially for those who are new to the field. A data science mock interview can help you to prepare for the real thing by providing you with feedback on your skills and knowledge.
#
# A data science mock interview expert with 4-5 years of experience can help you to:
#
#  Identify your strengths and weaknesses
#  Practice answering common interview questions
#  Get feedback on your technical skills
#  Improve your communication skills
#
# A data science mock interview can give you the confidence you need to succeed in your job search.
#
# Value:
#
# A data science mock interview can help you to:
#
#  Increase your chances of getting a job in data science
#  Improve your technical skills
#  Develop your communication skills
#  Gain confidence in your ability to perform well in a job interview
#
# Impact:
#
# A data science mock interview can help you to:
#
#  Land your dream job in data science
#  Accelerate your career growth
#  Make a positive impact on the world
#
# Call to action:
#
# If you are interested in learning more about our data science mock interview program, please contact us today.
# Proposal saved to proposal.txt
# Generated proposal: Project Proposal: Python Specialist for Stable Diffusion
#
# Problem: Stable diffusion is a technique for stabilizing neural networks, making them more robust to noise and outliers. However, implementing stable diffusion in Python can be challenging, as it requires specialized knowledge of the Python programming language and the PyTorch deep learning library.
#
# Solution: This project will create a Python specialist for stable diffusion. The specialist will be a software package that makes it easy for developers to implement stable diffusion in their Python projects. The specialist will be lightweight and easy to use, with a clean and well-documented API.
#
# Benefits: The Python specialist for stable diffusion will have a number of benefits, including:
#
#  Reduced development time: The specialist will make it easier for developers to implement stable diffusion in their Python projects, reducing the time and effort required.
#  Improved robustness: Stable diffusion can make neural networks more robust to noise and outliers, reducing the risk of errors in production.
#  Increased accuracy: Stable diffusion can improve the accuracy of neural networks, leading to better results in downstream tasks.
#
# Impact: The Python specialist for stable diffusion has the potential to have a significant impact on the field of deep learning. By making it easier for developers to implement stable diffusion, the specialist will enable more researchers and practitioners to use this technique, leading to improved robustness and accuracy in neural networks.
#
# Budget: \$10,000
#
# Timeline: 6 months
# Proposal saved to proposal.txt
# Generated proposal: Python to Django Transformation Expert Needed
#
# Problem:
#
# Our company is facing a growing need to migrate our Python applications to Django. This is a complex and time-consuming task, and we need an expert to help us get it done quickly and efficiently.
#
# Solution:
#
# We are looking for a Python to Django transformation expert who can help us migrate our applications to Django. The ideal candidate will have experience with both Python and Django, as well as a strong understanding of software engineering principles.
#
# Benefits:
#
# Successfully completing this project will have a number of benefits for our company, including:
#
#  Improved performance and scalability
#  Reduced development costs
#  Increased security
#  Improved developer productivity
#
# Impact:
#
# Successfully completing this project will allow us to continue to develop and maintain our Python applications while taking advantage of the benefits of Django. This will help us to stay ahead of the competition and deliver better products to our customers.
#
# Call to Action:
#
# If you are a Python to Django transformation expert and you are interested in working with our company, please contact us today.
# Proposal saved to proposal.txt
# Generated proposal: Pronunciation Coach AI -- 3
#
# Problem: Pronunciation is a critical skill for communication, but it can be difficult to learn. Traditional methods of pronunciation training are often ineffective or time-consuming.
#
# Solution: Pronunciation Coach AI -- 3 is an AI-powered pronunciation training tool that uses a combination of speech recognition, machine learning, and natural language processing to provide personalized feedback on pronunciation. Pronunciation Coach AI -- 3 is easy to use and can help learners of all levels improve their pronunciation quickly and effectively.
#
# Benefits:
#
#  Personalized feedback: Pronunciation Coach AI -- 3 provides tailored feedback on pronunciation errors, helping learners identify and correct their mistakes.
#  Adaptive learning: Pronunciation Coach AI -- 3 adapts to the learner's individual needs, providing more challenging exercises as the learner progresses.
#  Convenient: Pronunciation Coach AI -- 3 can be used on any device with an internet connection, making it easy to fit pronunciation training into busy schedules.
#
# Impact:
#
# Pronunciation Coach AI -- 3 has the potential to make a significant impact on the lives of learners of all ages and levels. By providing effective and accessible pronunciation training, Pronunciation Coach AI -- 3 can help learners communicate more effectively and confidently in their everyday lives.
# Proposal saved to proposal.txt
# Generated proposal: Multifaceted Software Developer Needed
#
# Problem
#
# The software industry is constantly evolving, and businesses need developers who can keep up with the latest trends. A multifaceted software developer is someone who has a wide range of skills and experience, making them a valuable asset to any team.
#
# Solution
#
# This project will recruit a multifaceted software developer who will be responsible for developing new software applications, maintaining existing systems, and providing technical support to users. The ideal candidate will have a strong understanding of programming languages, software development methodologies, and web technologies. They will also be able to work independently and as part of a team.
#
# Impact
#
# The successful completion of this project will have a significant impact on the business by providing it with a talented software developer who can help it to stay ahead of the competition. The developer will be able to develop new applications that meet the needs of the business, maintain existing systems, and provide technical support to users. This will allow the business to operate more efficiently and effectively, and it will be able to better serve its customers.
#
# Benefits
#
# The benefits of hiring a multifaceted software developer include:
#
#  Improved efficiency and effectiveness
#  Increased customer satisfaction
#  Competitive advantage
#  Reduced costs
#
# Call to action
#
# If you are interested in hiring a multifaceted software developer, please contact us today. We would be happy to discuss your needs and how we can help you find the best possible candidate.
# Proposal saved to proposal.txt
# Generated proposal: Python Guru for Salesforce Reports Encoding
#
# Problem: Salesforce reports are often encoded in a format that is not human-readable. This makes it difficult for users to understand and analyze the data.
#
# Solution: A Python guru can develop a script to decode Salesforce reports into a human-readable format. This would make it much easier for users to understand and analyze the data, leading to improved decision-making.
#
# Value: The value of this project would be significant. It would allow Salesforce users to:
#
#  Gain a deeper understanding of their data
#  Make more informed decisions
#  Improve the efficiency of their business
#
# Impact: The impact of this project would be far-reaching. It would help businesses of all sizes make better decisions, leading to increased productivity and profitability.
# Proposal saved to proposal.txt
# Generated proposal: Image Recognition Software Development Proposal
#
# Image recognition software has the potential to revolutionize a wide range of industries, from healthcare to retail to security. By automating the process of identifying and classifying objects in images, image recognition software can help businesses save time and money, improve accuracy, and provide better customer experiences.
#
# Here are just a few examples of the potential impact of image recognition software:
#
#  In healthcare, image recognition software can be used to diagnose diseases, identify medical anomalies, and guide surgical procedures.
#  In retail, image recognition software can be used to track inventory, identify fraudulent transactions, and personalize shopping experiences.
#  In security, image recognition software can be used to detect suspicious activity, identify criminals, and protect critical infrastructure.
#
# The potential benefits of image recognition software are clear. By developing this technology, we can help businesses improve their operations, save money, and provide better services to their customers.
#
# Project Timeline
#
#  Phase 1: Research and development (6 months)
#  Phase 2: Prototype development (6 months)
#  Phase 3: Testing and validation (6 months)
#  Phase 4: Commercial launch (6 months)
#
# Total Project Cost
#
# $1 million
#
# Project Team
#
#  Project Manager
#  Software Engineer
#  Machine Learning Engineer
#  Data Scientist
#  UX Designer
#
# Project Risks
#
#  The technology may not be feasible or scalable.
#  The project may not be completed on time or within budget.
#  The project may not meet the needs of the target market.
#
# Project Benefits
#
#  The project will have a significant impact on a wide range of industries.
#  The project will create new jobs and economic opportunities.
#  The project will help to improve the lives of people around the world.
# Proposal saved to proposal.txt
# Generated proposal: Python Coder for Stock Market Strategy
#
# Stock market trading is a complex and competitive field, and it can be difficult for individual investors to make money. However, with the help of a Python coder, investors can develop and implement sophisticated trading strategies that can help them outperform the market.
#
# A Python coder can help investors in a number of ways. First, they can use Python to collect and analyze data on stocks, indices, and other financial instruments. This data can then be used to identify trends and develop trading strategies. Second, Python coders can automate trading strategies, which can save investors time and money. Finally, Python coders can provide investors with insights into the market that they would not be able to obtain on their own.
#
# The value of a Python coder for stock market strategy is clear. With the help of a Python coder, investors can improve their trading performance and potentially make more money.
#
# Impact:
#
# A Python coder for stock market strategy can help investors in a number of ways, including:
#
#  Identifying trends and developing trading strategies
#  Automating trading strategies
#  Providing insights into the market
#
# By leveraging the power of Python, investors can improve their trading performance and potentially make more money.
# Proposal saved to proposal.txt
# Generated proposal: Python Training and Real-World Experience
#
# Problem:
#
# The demand for Python skills is growing rapidly, but many job seekers lack the real-world experience that employers are looking for.
#
# Solution:
#
# This project will provide Python training and real-world experience to help job seekers get the skills they need to land their dream jobs.
#
# Benefits:
#
#  Job seekers will gain the skills they need to compete in today's job market.
#  Employers will have access to a pool of qualified candidates with the skills they need.
#  The project will help to close the skills gap between job seekers and employers.
#
# Impact:
#
# This project will have a significant impact on the job market by helping job seekers get the skills they need and by providing employers with a pool of qualified candidates. It will also help to close the skills gap between job seekers and employers.
# Proposal saved to proposal.txt
#         _id                                             _title  \
# 0  37868623           Urgently Needed: Python Flask Specialist
# 1  37868602  Datascience mock interviews expert(4-5 years o...
# 2  37868545             Python Specialist for Stable Diffusion
# 3  37868505      Python to Django Transformation Expert Needed
# 4  37868459                        Pronunciation Coach AI -- 3
# 5  37868449             Multifaceted Software Developer Needed
# 6  37868397        Python Guru for Salesforce Reports Encoding
# 7  37868336             Image Recognition Software Development
# 8  37868256             Python Coder for Stock Market Strategy
# 9  37868126    Python trining and real time experience needed
#
#    _budget_minimum  _budget_maximum   _type  _bidperiod  _time_submitted  \
# 0             30.0            250.0   fixed           7       1710229702
# 1            100.0            400.0  hourly           7       1710229479
# 2             10.0             30.0   fixed           7       1710228545
# 3             30.0            250.0   fixed           7       1710227892
# 4            250.0            750.0   fixed           7       1710227217
# 5          10000.0          20000.0   fixed           7       1710227055
# 6             10.0             30.0   fixed           7       1710226211
# 7          75000.0         150000.0   fixed           7       1710224831
# 8          12500.0          37500.0   fixed           7       1710223585
# 9             30.0            250.0   fixed           7       1710221135
#
#    _bid_stats_bid_count  _bid_stats_bid_avg _currency_code  \
# 0                     6          143.166667            AUD
# 1                     2         1033.500000            INR
# 2                     5           43.600000            USD
# 3                    35          190.685714            USD
# 4                     8          519.875000            USD
# 5                     7        22142.857143            INR
# 6                     4           17.500000            AUD
# 7                     4       125000.000000            INR
# 8                    10        23574.900000            INR
# 9                    26          149.961538            USD
#
#    _currency_exchange_rate                                           proposal  \
# 0                 0.661890  Urgent Need: Python Flask Specialist\n\nProjec...
# 1                 0.012084  Data Science Mock Interview Expert\n\nData sci...
# 2                 1.000000  Project Proposal: Python Specialist for Stable...
# 3                 1.000000  Python to Django Transformation Expert Needed\...
# 4                 1.000000  Pronunciation Coach AI -- 3\n\nProblem: Pronun...
# 5                 0.012084  Multifaceted Software Developer Needed\n\nProb...
# 6                 0.661890  Python Guru for Salesforce Reports Encoding\n\...
# 7                 0.012084  Image Recognition Software Development Proposa...
# 8                 0.012084  Python Coder for Stock Market Strategy\n\nStoc...
# 9                 1.000000  Python Training and Real-World Experience\n\nP...
#
#                                     full_description
# 0  I'm in immediate need of an experienced Python...
# 1  I am in need of a knowledgeable and experience...
# 2  Currently, I'm in need of an expert who specia...
# 3  I'm on the hunt for a proficient Python and Dj...
# 4  I'm seeking an expert to create an AI-driven p...
# 5  I'm in search of a proficient software develop...
# 6  I'm currently struggling with an encoding issu...
# 7  I'm looking for a skilled software developer p...
# 8  I am seeking a skilled Python coder specialize...
# 9  Looking for python real time experience traini...
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

# Define helper functions
def create_bid_object(project, bidder_id, amount, period, description):
    project_id = project['id']
    project_owner_id = project['owner_id']
    retracted = False  # Assuming the bid is not retracted by default

    # Now, create the bid object using the derived values
    bid_object = {
        'id': project_id,  # Use project_id as the bid id
        'bidder_id': bidder_id,
        'project_id': project_id,
        'retracted': retracted,
        'amount': amount,
        'period': period,
        'description': description,
        'project_owner_id': project_owner_id
    }

    return bid_object

def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'  # Replace 'YOUR_API_KEY' with your actual API key
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    full_descriptions = []
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)
        
        # Create bid object
        bid_object = create_bid_object(
            project,
            bidder_id=456,  # Assuming bidder_id is known
            amount=100,     # Example bid amount
            period='1 week',
            description='Example bid description'
        )
        # Print the created bid object
        print("Created Bid Object:", bid_object)
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    # Selecting only specific columns
    #selected_columns = [
      # '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
       # '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'

  #  ]
  #  df = df[selected_columns]
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

if __name__ == "__main__":
    projects = sample_search_projects()
    print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: Intelligent Product Finder Telegram Chatbot
#
# Problem: Customers find it difficult to find the right products online. They often have to search through multiple websites and compare prices, which is time-consuming and frustrating.
#
# Solution: An intelligent product finder Telegram chatbot that can help customers find the right products by asking them a few questions about their needs. The chatbot would be able to search through multiple online stores and compare prices, and it would also be able to provide product recommendations based on the customer's past purchases.
#
# Benefits:
#
#  Save customers time and money by helping them find the right products faster
#  Improve customer satisfaction by providing a more personalized shopping experience
#  Increase sales by driving traffic to online stores
#
# Impact:
#
# The intelligent product finder Telegram chatbot would have a significant impact on the e-commerce industry by making it easier for customers to find the products they want. It would also help online stores to increase sales and improve customer satisfaction.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37869232, 'bidder_id': 456, 'project_id': 37869232, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 74946177}
# Generated proposal: Python Expert for Training Task Verification
#
#  Problem: Manually verifying training tasks is time-consuming and error-prone.
#  Solution: A Python expert will develop a tool to automate training task verification.
#  Benefits:
#      Reduced time spent on manual verification
#      Increased accuracy of training tasks
#      Improved data quality
#      Faster time to market for new models
#
# Impact: This project will have a significant impact on the efficiency and accuracy of our training process. It will also help us to deliver new models to our customers faster.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37863101, 'bidder_id': 456, 'project_id': 37863101, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 75034540}
# Generated proposal: Python Developer for Sales Data Analytics
#
# Problem
#
# Sales data is essential for businesses to make informed decisions, but it can be difficult to analyze and interpret. This is where a Python developer for sales data analytics can help.
#
# Solution
#
# A Python developer can use their skills to develop and implement data analytics solutions that help businesses make better use of their sales data. This can lead to increased sales, improved customer satisfaction, and reduced costs.
#
# Benefits
#
# A Python developer for sales data analytics can bring a number of benefits to a business, including:
#
#  Increased sales: By providing businesses with insights into their sales data, a Python developer can help them identify opportunities to increase sales.
#  Improved customer satisfaction: By understanding what customers want and need, a Python developer can help businesses develop products and services that meet their needs.
#  Reduced costs: By automating tasks and identifying areas where costs can be reduced, a Python developer can help businesses save money.
#
# Impact
#
# A Python developer for sales data analytics can have a significant impact on a business's bottom line. By helping businesses make better use of their sales data, a Python developer can help them increase sales, improve customer satisfaction, and reduce costs. This can lead to a more profitable and successful business.
#
# Call to action
#
# If you are looking for a Python developer who can help you make the most of your sales data, contact us today. We have the experience and expertise to help you achieve your business goals.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37869040, 'bidder_id': 456, 'project_id': 37869040, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 62521667}
# Generated proposal: Easy21 Game Play via Reinforcement Learning
#
# Reinforcement learning is a powerful technique that can be used to train agents to play games. In this project, we will use reinforcement learning to train an agent to play the game of Easy21. Easy21 is a variant of blackjack where the goal is to get as close to 21 as possible without going over. The agent will be trained using a deep neural network and a policy gradient algorithm.
#
# This project has the potential to have a significant impact on the field of artificial intelligence. By training agents to play games, we can learn more about how to design intelligent systems. We can also use these agents to develop new games and applications.
#
# The proposed project is well-defined and has a clear goal. The project is also feasible and has a high potential for success. I believe that this project would be a valuable addition to the field of artificial intelligence.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37869020, 'bidder_id': 456, 'project_id': 37869020, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 41567737}
# Generated proposal: Python & HTML Guru for Blogsite
#
# Problem: Our blog is not getting the traffic it deserves because it is not search engine optimized (SEO). We need to improve our SEO by adding more relevant content and making it easier for search engines to index our pages.
#
# Solution: Hire a Python & HTML guru to help us improve our SEO. The guru will work with our team to identify the best keywords for our blog, create high-quality content that is relevant to those keywords, and optimize our pages for search engines.
#
# Impact: The impact of hiring a Python & HTML guru will be significant. Our blog will get more traffic from search engines, which will lead to more leads and sales. We will also be able to reach a wider audience with our content and establish ourselves as a thought leader in our industry.
#
# Cost: The cost of hiring a Python & HTML guru will be \$10,000 per month. This includes the guru's salary, benefits, and expenses.
#
# Benefits: The benefits of hiring a Python & HTML guru will far outweigh the cost. We will gain a valuable asset to our team, increase our traffic and leads, and establish ourselves as a thought leader in our industry.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37864400, 'bidder_id': 456, 'project_id': 37864400, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 73459176}
# Generated proposal: Project Proposal: MILP for Solving Optimization Problems
#
# Problem: Many real-world problems can be formulated as optimization problems, but finding an optimal solution can be computationally difficult.
#
# Solution: MILP (Mixed-Integer Linear Programming) is a powerful technique for solving optimization problems. MILP models can be solved efficiently using specialized solvers, and MILP can be used to solve a wide variety of problems, including scheduling, routing, and resource allocation.
#
# Value: MILP can help organizations to improve their efficiency and productivity by solving a variety of optimization problems. For example, MILP can be used to:
#
#  Optimize production schedules to minimize costs and maximize profits
#  Plan transportation routes to minimize travel time and cost
#  Allocate resources to maximize efficiency
#
# Impact: MILP can have a significant impact on organizations by helping them to make better decisions and improve their bottom line. By using MILP, organizations can save money, reduce costs, and increase profits.
#
# Call to Action: If you are facing an optimization problem, consider using MILP to solve it. MILP is a powerful technique that can help you to find the best possible solution to your problem.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37868849, 'bidder_id': 456, 'project_id': 37868849, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 73047049}
# Generated proposal: Urgent Need: Python Flask Specialist
#
# Problem
#
# Our team is developing a new web application that uses Python Flask. We need a specialist with experience in Python Flask to help us complete the project on time and within budget.
#
# Solution
#
# A Python Flask specialist will be able to:
#
#  Design and develop the application's backend
#  Integrate the application with third-party APIs
#  Test and deploy the application
#
# Benefits
#
# The benefits of hiring a Python Flask specialist include:
#
#  Faster development time
#  Improved quality of the application
#  Reduced costs
#
# Impact
#
# Hiring a Python Flask specialist will help us complete the project on time and within budget. The application will be more robust and reliable, and it will be easier to maintain and update. This will have a positive impact on our business and our customers.
#
# Call to Action
#
# If you are a Python Flask specialist, we encourage you to apply for this position. We are offering a competitive salary and benefits. To apply, please send your resume and cover letter to [email protected]
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37868623, 'bidder_id': 456, 'project_id': 37868623, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 14558179}
# Generated proposal: Data Science Mock Interview Expert
#
# Data science is a rapidly growing field, and there is a high demand for skilled data scientists. However, many job seekers lack the experience necessary to land a data science job. A data science mock interview expert can help job seekers prepare for their interviews by providing them with realistic practice questions and feedback. This can give job seekers the confidence they need to succeed in their interviews and land their dream jobs.
#
# Value:
#
# A data science mock interview expert can provide job seekers with the following benefits:
#
#  Realistic practice questions and feedback
#  Increased confidence in their ability to perform well in interviews
#  A better understanding of the data science interview process
#  Increased chances of landing a data science job
#
# Impact:
#
# A data science mock interview expert can help job seekers to:
#
#  Get their dream data science job
#  Advance their careers in the data science field
#  Make a positive impact on the world by using data science to solve real-world problems
#
# Call to action:
#
# If you are a job seeker looking to land a data science job, or if you are a data science professional looking to advance your career, I encourage you to reach out to a data science mock interview expert today.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37868602, 'bidder_id': 456, 'project_id': 37868602, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 70803505}
# Generated proposal: Project Proposal: Python Specialist for Stable Diffusion
#
# Problem: Stable diffusion is a critical technique for many machine learning applications, but it is often difficult to implement efficiently in Python. This can lead to performance bottlenecks and make it difficult to deploy models to production.
#
# Solution: A Python specialist will develop a library of stable diffusion routines that are optimized for performance and ease of use. This will make it possible to use stable diffusion in a wider range of applications and improve the performance of existing models.
#
# Impact: The Python specialist will make stable diffusion more accessible to a wider range of developers, which will lead to new applications and improved performance in existing models. This will benefit the entire machine learning community and help to accelerate the development of new AI technologies.
#
# Value: The Python specialist will create a valuable resource for the machine learning community by making stable diffusion more accessible and easier to use. This will lead to new applications and improved performance in existing models, which will benefit the entire field of AI.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37868545, 'bidder_id': 456, 'project_id': 37868545, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 54989278}
# Generated proposal: Python to Django Transformation Expert Needed
#
# Problem
#
# Our company is facing a growing need to migrate our Python applications to Django. Django is a popular Python framework that provides a robust and scalable platform for building web applications. However, migrating our existing applications to Django is a complex and time-consuming process.
#
# Solution
#
# We need to hire a Python to Django transformation expert who can help us migrate our applications to Django quickly and efficiently. This person will need to have a deep understanding of both Python and Django, as well as experience with migrating applications from one platform to another.
#
# Benefits
#
# Successfully migrating our applications to Django will provide a number of benefits for our company, including:
#
#  Improved scalability: Django is a more scalable platform than Python, which will allow us to handle more traffic and process more data.
#  Increased security: Django is a more secure platform than Python, which will help us protect our data from unauthorized access.
#  Reduced costs: Django is a more cost-effective platform than Python, which will help us save money on our IT infrastructure.
#
# Impact
#
# Successfully migrating our applications to Django will have a significant impact on our company. It will allow us to:
#
#  Handle more traffic and process more data.
#  Protect our data from unauthorized access.
#  Save money on our IT infrastructure.
#
# Conclusion
#
# We are confident that hiring a Python to Django transformation expert will be a valuable investment for our company. This person will help us migrate our applications to Django quickly and efficiently, which will provide a number of benefits for our company, including improved scalability, increased security, and reduced costs.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37868505, 'bidder_id': 456, 'project_id': 37868505, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 66969294}
#         _id  _owner_id                                             _title  \
# 0  37869232   74946177        Intelligent Product Finder Telegram Chatbot
# 1  37863101   75034540       Python Expert for Training Task Verification
# 2  37869040   62521667          Python Developer for Sales Data Analytics
# 3  37869020   41567737        Easy21 Game Play via Reinforcement Learning
# 4  37864400   73459176                    Python & HTML Guru for Blogsite
# 5  37868849   73047049                                               MILP
# 6  37868623   14558179           Urgently Needed: Python Flask Specialist
# 7  37868602   70803505  Datascience mock interviews expert(4-5 years o...
# 8  37868545   54989278             Python Specialist for Stable Diffusion
# 9  37868505   66969294      Python to Django Transformation Expert Needed
#
#   _status                                         _seo_url  _currency_id  \
# 0  active       python/Intelligent-Product-Finder-Telegram             1
# 1  active           python/Python-Expert-for-Training-Task             1
# 2  active           python/Python-Developer-for-Sales-Data            11
# 3  active          python/Easy-Game-Play-via-Reinforcement             1
# 4  active             python/Python-HTML-Guru-for-Blogsite            11
# 5  closed                          matlab-mathematica/MILP             8
# 6  active   python/Urgently-Needed-Python-Flask-Specialist             3
# 7  active  python/Datascience-mock-interviews-expert-years            11
# 8  closed    python/Python-Specialist-for-Stable-Diffusion             1
# 9  active              Python-Django-Transformation-Expert             1
#
#   _currency_code _currency_sign     _currency_name  _currency_exchange_rate  \
# 0            USD              $          US Dollar                 1.000000
# 1            USD              $          US Dollar                 1.000000
# 2            INR              ₹       Indian Rupee                 0.012080
# 3            USD              $          US Dollar                 1.000000
# 4            INR              ₹       Indian Rupee                 0.012080
# 5            EUR              €               Euro                 1.093119
# 6            AUD              $  Australian Dollar                 0.661502
# 7            INR              ₹       Indian Rupee                 0.012080
# 8            USD              $          US Dollar                 1.000000
# 9            USD              $          US Dollar                 1.000000
#
#    ... _is_seller_kyc_required  _is_buyer_kyc_required  _enterprises  \
# 0  ...                   False                   False            []
# 1  ...                   False                   False            []
# 2  ...                   False                   False            []
# 3  ...                   False                   False            []
# 4  ...                   False                   False            []
# 5  ...                   False                   False            []
# 6  ...                   False                   False            []
# 7  ...                   False                   False            []
# 8  ...                   False                   False            []
# 9  ...                   False                   False            []
#
#    _group_ids     _sub_status  _hourly_project_info_commitment_hours  \
# 0          []             NaN                                    NaN
# 1          []             NaN                                    NaN
# 2          []             NaN                                    NaN
# 3          []             NaN                                    NaN
# 4          []             NaN                                    NaN
# 5          []  closed_awarded                                    NaN
# 6          []             NaN                                    NaN
# 7          []             NaN                                   40.0
# 8          []  closed_awarded                                    NaN
# 9          []             NaN                                    NaN
#
#    _hourly_project_info_commitment_interval  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                      week
# 8                                       NaN
# 9                                       NaN
#
#    _hourly_project_info_duration_enum  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                         unspecified
# 8                                 NaN
# 9                                 NaN
#
#                                             proposal  \
# 0  Intelligent Product Finder Telegram Chatbot\n\...
# 1  Python Expert for Training Task Verification\n...
# 2  Python Developer for Sales Data Analytics\n\nP...
# 3  Easy21 Game Play via Reinforcement Learning\n\...
# 4  Python & HTML Guru for Blogsite\n\nProblem: Ou...
# 5  Project Proposal: MILP for Solving Optimizatio...
# 6  Urgent Need: Python Flask Specialist\n\nProble...
# 7  Data Science Mock Interview Expert\n\nData sci...
# 8  Project Proposal: Python Specialist for Stable...
# 9  Python to Django Transformation Expert Needed\...
#
#                                     full_description
# 0  I require a proficient developer conversant in...
# 1  As a professional or hobbyist deeply immersed ...
# 2  I'm in need of a skilled Python developer expe...
# 3  I'm looking for an expert in Artificial Intell...
# 4  I'm seeking a savvy Python and HTML expert who...
# 5  Mixed integer linear programming for VRP in pu...
# 6  I'm in immediate need of an experienced Python...
# 7  I am in need of a knowledgeable and experience...
# 8  Currently, I'm in need of an expert who specia...
# 9  I'm on the hunt for a proficient Python and Dj...
#
# [10 rows x 60 columns]
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

# Define helper functions
def create_bid_object(project, bidder_id, amount, period, description):
    project_id = project['id']
    project_owner_id = project['owner_id']
    retracted = False  # Assuming the bid is not retracted by default

    # Now, create the bid object using the derived values
    bid_object = {
        'id': project_id,  # Use project_id as the bid id
        'bidder_id': bidder_id,
        'project_id': project_id,
        'retracted': retracted,
        'amount': amount,
        'period': period,
        'description': description,
        'project_owner_id': project_owner_id
    }

    return bid_object

def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'  # Replace 'YOUR_API_KEY' with your actual API key
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    full_descriptions = []
    bid_objects = []  # New list to store bid objects
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)
        
        # Create bid object
        bid_object = create_bid_object(
            project,
            bidder_id=456,  # Assuming bidder_id is known
            amount=100,     # Example bid amount
            period='1 week',
            description='Example bid description'
        )
        bid_objects.append(bid_object)  # Append the created bid object
        
        # Print the created bid object
        print("Created Bid Object:", bid_object)
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    # Selecting only specific columns
    selected_columns = [
       '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
        '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'

    ]
    df = df[selected_columns]
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    df['bid_object'] = bid_objects  # Add the created bid objects to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

if __name__ == "__main__":
    projects = sample_search_projects()
    print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: Python-Based Screenshot Expert
#
# Problem: Manually taking screenshots and annotating them is time-consuming and error-prone.
#
# Solution: A Python-based screenshot expert that can automatically take screenshots and annotate them with relevant information. This would save time and improve the accuracy of screenshots, allowing developers to focus on their work rather than on tedious tasks.
#
# Benefits:
#
#  Save time: The screenshot expert can take screenshots and annotate them in a fraction of the time it would take a human to do it.
#  Improve accuracy: The screenshot expert can be trained to annotate screenshots with the correct information, reducing the risk of errors.
#  Focus on work: Developers can spend less time taking screenshots and annotating them, and more time on their actual work.
#
# Impact:
#
# The Python-based screenshot expert would have a significant impact on developers' productivity, allowing them to focus on their work and ship products faster.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37869245, 'bidder_id': 456, 'project_id': 37869245, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 20013642}
# Generated proposal: Intelligent Product Finder Telegram Chatbot
#
# Problem: Online shopping is a convenient way to buy products, but it can be difficult to find the right product at the right price.
#
# Solution: Our Intelligent Product Finder Telegram Chatbot will help you find the best products by searching across multiple online retailers and providing you with real-time pricing information.
#
# Benefits:
#
#  Save time and money by finding the best deals on products
#  Get instant access to product information and reviews
#  Easily compare products from different retailers
#  Receive personalized recommendations based on your interests
#
# Impact:
#
# Our Intelligent Product Finder Telegram Chatbot will make online shopping easier and more enjoyable for consumers, and it will help retailers increase sales.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37869232, 'bidder_id': 456, 'project_id': 37869232, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 74946177}
# Generated proposal: Python Expert for Training Task Verification
#
# Problem:
#
# Machine learning models are becoming increasingly complex, and it is becoming more difficult to ensure that they are working correctly. One of the most important steps in the development of a machine learning model is to verify that it is working as intended. This can be a time-consuming and error-prone process, especially for complex models.
#
# Solution:
#
# We propose to develop a Python expert for training task verification. This expert would be able to automatically verify the correctness of machine learning models, reducing the time and effort required for this process. The expert would be able to:
#
#  Identify potential problems with a model's training data
#  Detect errors in the model's training process
#  Verify that the model is making accurate predictions
#
# Benefits:
#
# The development of a Python expert for training task verification would have a number of benefits, including:
#
#  Reduced time and effort required to verify machine learning models
#  Increased confidence in the accuracy of machine learning models
#  Faster time to market for new machine learning models
#
# Impact:
#
# The development of a Python expert for training task verification would have a significant impact on the development of machine learning models. It would make it easier to ensure that models are working correctly, which would lead to increased confidence in the accuracy of these models. This would in turn lead to faster time to market for new machine learning models, which could have a significant impact on a variety of industries.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37863101, 'bidder_id': 456, 'project_id': 37863101, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 75034540}
# Generated proposal: Project Proposal: Python Developer for Sales Data Analytics
#
# Problem: Sales teams are drowning in data, but they lack the tools to make sense of it. As a result, they're making decisions based on intuition and guesswork, which is leading to lost opportunities and wasted time.
#
# Solution: A Python developer can help sales teams to analyze their data and identify trends and insights that can be used to improve their performance. For example, a Python developer could create a dashboard that shows sales reps the performance of their products and customers in real time. This information could help reps to target their sales efforts more effectively and close more deals.
#
# Value: A Python developer for sales data analytics can help sales teams to:
#
#  Increase sales revenue
#  Reduce costs
#  Improve customer satisfaction
#  Make better decisions
#
# Impact: By implementing a Python data analytics solution, sales teams can:
#
#  Increase sales by 10%
#  Reduce costs by 5%
#  Improve customer satisfaction by 20%
#  Make better decisions that lead to increased profits
#
# Conclusion: A Python developer for sales data analytics is a valuable asset for any sales team. By providing sales teams with the tools they need to analyze their data, a Python developer can help them to improve their performance and achieve their goals.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37869040, 'bidder_id': 456, 'project_id': 37869040, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 62521667}
# Generated proposal: ## Easy21 Game Play via Reinforcement Learning
#
# Value:
#
# Reinforcement learning is a powerful technique that can be used to teach agents to play games. In this project, we will use reinforcement learning to teach an agent to play the game of Easy21. Easy21 is a simplified version of blackjack that is easier to learn and understand than the original game. This project has the potential to make a significant impact on the field of artificial intelligence, as it could lead to the development of more effective and efficient reinforcement learning algorithms.
#
# Impact:
#
# The successful completion of this project could have a significant impact on the field of artificial intelligence. By developing a reinforcement learning algorithm that can be used to teach agents to play Easy21, we will be able to demonstrate the power of this technique and show how it can be used to solve real-world problems. This could lead to the development of more effective and efficient reinforcement learning algorithms, which could in turn be used to solve a wide variety of other problems, such as robotics, natural language processing, and computer vision.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37869020, 'bidder_id': 456, 'project_id': 37869020, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 41567737}
# Generated proposal: MILP: A Proposal
#
# Problem
#
# Many real-world problems can be formulated as optimization problems, but finding an optimal solution is often computationally intractable. Mixed-integer linear programming (MILP) is a powerful tool for solving these problems, but it can be difficult to use effectively.
#
# Solution
#
# This proposal describes a new MILP solver that is designed to be easy to use and efficient. The solver is based on a new algorithm that is both scalable and robust.
#
# Impact
#
# The new MILP solver will have a significant impact on a wide range of applications, including scheduling, routing, and resource allocation. It will enable researchers and practitioners to solve problems that were previously intractable, and it will lead to new insights and discoveries.
#
# Value
#
# The new MILP solver is a valuable tool that will benefit researchers and practitioners in a variety of fields. It is easy to use, efficient, and scalable, making it ideal for solving a wide range of optimization problems.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37868849, 'bidder_id': 456, 'project_id': 37868849, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 73047049}
# Generated proposal: Urgent Need: Python Flask Specialist
#
# We are looking for a Python Flask specialist to join our team. The ideal candidate will have experience with web development, RESTful APIs, and unit testing. This is a full-time position with a competitive salary and benefits.
#
# Why this role is important:
#
#  We are rapidly growing our team and need additional resources to support our development efforts.
#  Python Flask is a popular framework for building web applications, and we need someone who is familiar with it.
#  The successful candidate will have a significant impact on the development of our products.
#
# What you will do:
#
#  Develop and maintain web applications using Python Flask.
#  Design and implement RESTful APIs.
#  Write unit tests and integration tests.
#  Work closely with other developers on the team.
#
# To apply, please send your resume and a cover letter to [email protected]
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37868623, 'bidder_id': 456, 'project_id': 37868623, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 14558179}
# Error: The API response does not contain the expected data.
# Created Bid Object: {'id': 37868602, 'bidder_id': 456, 'project_id': 37868602, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 70803505}
# Generated proposal: Project Proposal: Python Specialist for Stable Diffusion
#
# Problem: Stable diffusion is a critical technique for many machine learning applications, but it is computationally expensive. This can limit the use of stable diffusion in real-world applications.
#
# Solution: We propose to develop a Python specialist for stable diffusion. This specialist will be able to automatically optimize the parameters of stable diffusion for a given dataset, resulting in significant speedups.
#
# Benefits: The Python specialist for stable diffusion will have the following benefits:
#
#  Reduced computational cost: The Python specialist will be able to significantly reduce the computational cost of stable diffusion, making it more feasible to use in real-world applications.
#  Improved performance: The Python specialist will be able to improve the performance of stable diffusion, leading to better results in machine learning tasks.
#  Increased accessibility: The Python specialist will make stable diffusion more accessible to a wider range of users, who may not have the expertise to manually optimize the parameters of stable diffusion.
#
# Overall, we believe that the Python specialist for stable diffusion will have a significant impact on the field of machine learning. It will make stable diffusion more feasible to use in real-world applications, leading to improved performance and increased accessibility.
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37868545, 'bidder_id': 456, 'project_id': 37868545, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 54989278}
# Generated proposal: Python to Django Transformation Expert Needed
#
# Problem:
#
# Our team is facing a growing need to migrate our Python applications to Django. Django is a popular Python framework that provides a robust set of tools for building web applications. However, migrating our applications to Django is a complex and time-consuming process.
#
# Solution:
#
# We need to hire a Python to Django transformation expert who can help us migrate our applications to Django quickly and efficiently. This expert will need to have a deep understanding of both Python and Django, as well as experience with migrating applications from one framework to another.
#
# Benefits:
#
# Successfully migrating our applications to Django will have a number of benefits for our team, including:
#
#  Reduced development time: Django is a mature framework with a well-established ecosystem of libraries and tools. This means that we can develop new features faster and with less effort.
#  Improved scalability: Django is designed to be scalable, so our applications will be able to handle more traffic without experiencing performance problems.
#  Improved security: Django includes a number of security features that can help us protect our applications from attacks.
#
# Impact:
#
# Successfully migrating our applications to Django will have a significant impact on our team, allowing us to develop new features faster, scale our applications more easily, and protect our applications from attacks.
#
# Call to Action:
#
# We are seeking a Python to Django transformation expert who can help us migrate our applications to Django quickly and efficiently. If you are interested in this position, please send your resume and cover letter to [email protected]
# Proposal saved to proposal.txt
# Created Bid Object: {'id': 37868505, 'bidder_id': 456, 'project_id': 37868505, 'retracted': False, 'amount': 100, 'period': '1 week', 'description': 'Example bid description', 'project_owner_id': 66969294}
#         _id                                             _title  \
# 0  37869245                     Python-Based Screenshot Expert
# 1  37869232        Intelligent Product Finder Telegram Chatbot
# 2  37863101       Python Expert for Training Task Verification
# 3  37869040          Python Developer for Sales Data Analytics
# 4  37869020        Easy21 Game Play via Reinforcement Learning
# 5  37868849                                               MILP
# 6  37868623           Urgently Needed: Python Flask Specialist
# 7  37868602  Datascience mock interviews expert(4-5 years o...
# 8  37868545             Python Specialist for Stable Diffusion
# 9  37868505      Python to Django Transformation Expert Needed
#
#    _budget_minimum  _budget_maximum   _type  _bidperiod  _time_submitted  \
# 0             10.0             30.0   fixed           7       1710239944
# 1             30.0            250.0   fixed           7       1710239659
# 2             30.0            250.0   fixed           7       1710237893
# 3            600.0           1500.0   fixed           7       1710236507
# 4             10.0             30.0   fixed           7       1710236064
# 5            150.0            150.0   fixed          10       1710233401
# 6             30.0            250.0   fixed           7       1710229702
# 7            100.0            400.0  hourly           7       1710229479
# 8             10.0             30.0   fixed           7       1710228545
# 9             30.0            250.0   fixed           7       1710227892
#
#    _bid_stats_bid_count  _bid_stats_bid_avg _currency_code  \
# 0                     8           33.125000            USD
# 1                    18          158.750000            USD
# 2                    17          172.500000            USD
# 3                     7         1097.142857            INR
# 4                     9           80.000000            USD
# 5                     1          150.000000            EUR
# 6                     9          145.444444            AUD
# 7                     3          772.333333            INR
# 8                     8           44.125000            USD
# 9                    47          183.468085            USD
#
#    _currency_exchange_rate                                           proposal  \
# 0                 1.000000  Python-Based Screenshot Expert\n\nProblem: Man...
# 1                 1.000000  Intelligent Product Finder Telegram Chatbot\n\...
# 2                 1.000000  Python Expert for Training Task Verification\n...
# 3                 0.012080  Project Proposal: Python Developer for Sales D...
# 4                 1.000000  ## Easy21 Game Play via Reinforcement Learning...
# 5                 1.093325  MILP: A Proposal\n\nProblem\n\nMany real-world...
# 6                 0.661534  Urgent Need: Python Flask Specialist\n\nWe are...
# 7                 0.012080                                               None
# 8                 1.000000  Project Proposal: Python Specialist for Stable...
# 9                 1.000000  Python to Django Transformation Expert Needed\...
#
#                                     full_description  \
# 0  The project aims to automate the process of ca...
# 1  I require a proficient developer conversant in...
# 2  As a professional or hobbyist deeply immersed ...
# 3  I'm in need of a skilled Python developer expe...
# 4  I'm looking for an expert in Artificial Intell...
# 5  Mixed integer linear programming for VRP in pu...
# 6  I'm in immediate need of an experienced Python...
# 7  I am in need of a knowledgeable and experience...
# 8  Currently, I'm in need of an expert who specia...
# 9  I'm on the hunt for a proficient Python and Dj...
#
#                                           bid_object
# 0  {'id': 37869245, 'bidder_id': 456, 'project_id...
# 1  {'id': 37869232, 'bidder_id': 456, 'project_id...
# 2  {'id': 37863101, 'bidder_id': 456, 'project_id...
# 3  {'id': 37869040, 'bidder_id': 456, 'project_id...
# 4  {'id': 37869020, 'bidder_id': 456, 'project_id...
# 5  {'id': 37868849, 'bidder_id': 456, 'project_id...
# 6  {'id': 37868623, 'bidder_id': 456, 'project_id...
# 7  {'id': 37868602, 'bidder_id': 456, 'project_id...
# 8  {'id': 37868545, 'bidder_id': 456, 'project_id...
# 9  {'id': 37868505, 'bidder_id': 456, 'project_id...
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re
import json

# Define helper functions
def create_bid_object(project, bidder_id, amount, period, description):
    project_id = project['id']
    project_owner_id = project['owner_id']
    retracted = False  # Assuming the bid is not retracted by default

    # Now, create the bid object using the derived values
    bid_object = {
        'id': project_id,  # Use project_id as the bid id
        'bidder_id': bidder_id,
        'project_id': project_id,
        'retracted': retracted,
        'amount': amount,
        'period': period,
        'description': description,
        'project_owner_id': project_owner_id
    }

    return bid_object

def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'  # Replace 'YOUR_API_KEY' with your actual API key
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    full_descriptions = []
    bid_objects = []  # New list to store bid objects
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)
        
        # Create bid object
        bid_object = create_bid_object(
            project,
            bidder_id=456,  # Assuming bidder_id is known
            amount=100,     # Example bid amount
            period='1 week',
            description='Example bid description'
        )
        bid_objects.append(json.dumps(bid_object, indent=4))  # Append the created bid object as JSON
        
        # Print the created bid object
        print("Created Bid Object:", json.dumps(bid_object, indent=4))
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    # Selecting only specific columns
    selected_columns = [
       '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
        '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'

    ]
    df = df[selected_columns]
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    df['bid_object'] = bid_objects  # Add the created bid objects to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

if __name__ == "__main__":
    projects = sample_search_projects()
    print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: Python Flask Project Development Proposal
#
# Project Overview
#
# Python Flask is a popular web framework that is known for its simplicity and ease of use. It is a great choice for developers who want to create quick and efficient web applications. This proposal outlines the steps involved in developing a Python Flask project, from the initial planning stages to the final deployment.
#
# Project Goals
#
# The goal of this project is to develop a Python Flask project that demonstrates the framework's capabilities. The project will be a simple web application that allows users to create and manage a to-do list. The application will be hosted on a cloud-based platform and accessible from anywhere in the world.
#
# Project Benefits
#
# The benefits of this project include:
#
#  Improved productivity: The Python Flask framework can help developers create web applications faster and more efficiently.
#  Reduced costs: The Python Flask framework is open source and free to use.
#  Increased scalability: The Python Flask framework is scalable and can be used to create large and complex web applications.
#
# Project Timeline
#
# The project will be completed in four phases:
#
# 1. Planning: The first phase will involve gathering requirements and developing a project plan.
# 2. Development: The second phase will involve developing the application's code.
# 3. Testing: The third phase will involve testing the application to ensure that it meets all requirements.
# 4. Deployment: The final phase will involve deploying the application to a cloud-based platform.
#
# Project Budget
#
# The total cost of the project is estimated to be \$10,000. This includes the cost of software licenses, hardware, and cloud-based hosting.
#
# Project Team
#
# The project team will consist of a project manager, a software engineer, and a QA engineer. The project manager will be responsible for overseeing the project and ensuring that it is completed on time and within budget. The software engineer will be responsible for developing the application's code. The QA engineer will be responsible for testing the application to ensure that it meets all requirements.
#
# Project Risks
#
# The main risks associated with this project include:
#
#  Scope creep: The project scope may change during the development process, which could lead to delays and cost overruns.
#  Technical challenges: The project team may encounter technical challenges that could delay the project or prevent it from being completed successfully.
#  Market changes: The market for web applications may change during the development process, which could make the application less valuable.
#
# Project Mitigation Strategies
#
# The project team will implement the following mitigation strategies to address the risks associated with this project:
#
#  Scope creep will be managed by using a rigorous project management process.
#  Technical challenges will be addressed by using experienced software engineers and QA engineers.
#  Market changes will be monitored closely, and the application will be updated as needed to stay relevant.
#
# Project Approval
#
# We recommend that you approve this project because it has the potential to create significant benefits for your organization. The Python Flask framework is a powerful tool that can help you develop web applications quickly and efficiently. The project team has the experience and expertise to successfully complete the project on time and within budget.
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37869301,
#     "bidder_id": 456,
#     "project_id": 37869301,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 72882119
# }
# Generated proposal: Python-Based Screenshot Expert
#
# Problem
#
# Taking screenshots is a common task, but it can be tedious and time-consuming. Manually cropping and editing screenshots can be even more so.
#
# Solution
#
# A Python-based screenshot expert can automate the process of taking and editing screenshots. This would save users time and effort, and it would also improve the quality of screenshots.
#
# Benefits
#
# A Python-based screenshot expert would have a number of benefits, including:
#
#  Increased productivity: Users would be able to take and edit screenshots more quickly and easily, which would save them time.
#  Improved quality: Screenshots would be more accurate and visually appealing, as they would be taken and edited with precision.
#  Reduced errors: Manually taking and editing screenshots can lead to errors, such as incorrect cropping or editing. A Python-based screenshot expert would help to reduce these errors.
#
# Impact
#
# A Python-based screenshot expert would have a significant impact on users' productivity and the quality of their work. It would also help to reduce errors and improve the overall user experience.
#
# Call to action
#
# We are seeking funding to develop a Python-based screenshot expert. This would be a valuable tool for users of all levels, and it would have a significant impact on their productivity and the quality of their work.
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37869245,
#     "bidder_id": 456,
#     "project_id": 37869245,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 20013642
# }
# Generated proposal: Intelligent Product Finder Telegram Chatbot
#
# Problem: Online shopping is a time-consuming and frustrating experience. Customers often have to search through multiple websites to find the products they're looking for, and they may not be able to find the best prices or the most relevant information.
#
# Solution: Our Intelligent Product Finder Telegram Chatbot will help customers find the products they're looking for quickly and easily. The chatbot will use artificial intelligence to search across multiple online stores and find the best prices and deals. It will also provide customers with relevant information about the products they're considering, such as reviews and ratings.
#
# Impact: Our Intelligent Product Finder Telegram Chatbot will save customers time and money, and it will make online shopping a more enjoyable experience. The chatbot will also help businesses increase sales and grow their customer base.
#
# Value: Our Intelligent Product Finder Telegram Chatbot is a valuable tool for both customers and businesses. It will save customers time and money, and it will help businesses increase sales and grow their customer base.
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37869232,
#     "bidder_id": 456,
#     "project_id": 37869232,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 74946177
# }
# Generated proposal: Project Proposal: Python Expert for Training Task Verification
#
# Problem:
#
# Machine learning models are becoming increasingly complex, and it is becoming more difficult to ensure that they are working correctly. One of the most important steps in the machine learning development process is to verify that the training data is correct. This is often done manually, which is a time-consuming and error-prone process.
#
# Solution:
#
# We propose to develop a Python expert for training task verification. This expert would be able to automatically verify the training data, identify any errors, and suggest ways to improve the data. This would save time and effort, and it would help to ensure that machine learning models are working correctly.
#
# Impact:
#
# The Python expert for training task verification would have a significant impact on the machine learning development process. It would make it easier to verify the training data, which would lead to more accurate and reliable machine learning models. This would benefit businesses of all sizes, as it would allow them to use machine learning to improve their operations.
#
# Budget:
#
# The total cost of the project is estimated to be \$100,000. This includes the cost of hiring a Python expert, the cost of developing the software, and the cost of testing the software.
#
# Timeline:
#
# The project is expected to take six months to complete.
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37863101,
#     "bidder_id": 456,
#     "project_id": 37863101,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 75034540
# }
# Generated proposal: Project Proposal: Python Developer for Sales Data Analytics
#
# Problem: Sales teams are drowning in data, but they lack the tools to make sense of it. As a result, they're missing out on valuable insights that could help them close more deals and grow their business.
#
# Solution: A Python developer can help sales teams build and deploy data analytics models that will help them identify trends, uncover hidden insights, and make better decisions.
#
# Impact: By implementing a data analytics solution, sales teams can:
#
#  Increase sales by up to 20%
#  Reduce costs by up to 15%
#  Improve customer satisfaction by up to 10%
#
# Value: A Python developer for sales data analytics can help your team achieve a significant return on investment (ROI). By implementing a data analytics solution, you can increase sales, reduce costs, and improve customer satisfaction. This will lead to a more profitable and sustainable business.
#
# Call to Action: If you're interested in learning more about how a Python developer can help your sales team, please contact us today.
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37869040,
#     "bidder_id": 456,
#     "project_id": 37869040,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 62521667
# }
# Generated proposal: Easy21 Game Play via Reinforcement Learning
#
# Problem
#
# The game of Easy21 is a variant of blackjack where the goal is to get as close to 21 as possible without going over. The player is dealt two cards and can then choose to hit (receive another card) or stand (keep their current hand). The dealer also receives two cards, one of which is face up and the other face down. The dealer must hit until they reach 17 or higher. The player wins if they have a higher score than the dealer without going over 21. The dealer wins if the player goes over 21 or if the player's score is lower than the dealer's.
#
# Solution
#
# We propose to use reinforcement learning to train an agent to play Easy21. Reinforcement learning is a type of machine learning that allows an agent to learn by interacting with its environment and receiving rewards for its actions. In the case of Easy21, the agent would receive a reward of +1 for winning a hand and a reward of -1 for losing a hand. The agent would also receive a reward of 0 for drawing a hand that is worth exactly 21.
#
# Impact
#
# The successful development of an Easy21 agent would have a number of benefits. First, it would provide a valuable tool for studying the game of blackjack and for developing new strategies for playing the game. Second, it could be used to create a more challenging and engaging version of Easy21 for human players. Third, it could be used to develop automated blackjack-playing systems that could be used by casinos to improve their profits.
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37869020,
#     "bidder_id": 456,
#     "project_id": 37869020,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 41567737
# }
# Generated proposal: Project Proposal: MILP for Solving Real-World Optimization Problems
#
# Problem Statement
#
# Many real-world optimization problems can be expressed as Mixed-Integer Linear Programs (MILPs). However, solving MILPs is computationally challenging, and existing solvers can be prohibitively slow for large problems.
#
# Solution
#
# We propose a new MILP solver that uses a combination of exact and approximate techniques to solve problems efficiently. Our solver is based on a novel decomposition algorithm that allows us to solve large problems in a fraction of the time required by existing solvers.
#
# Benefits
#
# Our solver will enable researchers and practitioners to solve a wider range of optimization problems, leading to new insights and discoveries. In particular, our solver will be useful for applications in areas such as logistics, scheduling, and finance.
#
# Timeline
#
# We plan to develop a prototype of our solver within the next six months. We will then conduct a series of experiments to evaluate the performance of our solver on a variety of real-world problems.
#
# Budget
#
# The total cost of the project is estimated to be \$100,000. This includes the cost of salaries for research staff, software development costs, and the cost of hardware and infrastructure.
#
# Conclusion
#
# We believe that our project has the potential to make a significant impact on the field of optimization. We are confident that our solver will be a valuable tool for researchers and practitioners alike.
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37868849,
#     "bidder_id": 456,
#     "project_id": 37868849,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 73047049
# }
# Generated proposal: Urgent Need: Python Flask Specialist
#
# Problem: Our team is facing a critical shortage of Python Flask specialists. This is causing delays in our projects and is impacting our ability to deliver on time and within budget.
#
# Solution: We need to hire a Python Flask specialist who can help us to address this critical shortage. This person will be responsible for developing and maintaining our Python Flask applications. They will also be responsible for providing support to other team members and helping us to improve our development processes.
#
# Impact: The impact of hiring a Python Flask specialist will be significant. We will be able to reduce delays in our projects, improve our ability to deliver on time and within budget, and provide better support to our customers. This will ultimately lead to increased customer satisfaction and growth for our company.
#
# Value: The value of hiring a Python Flask specialist is clear. This person will help us to address a critical shortage, improve our development processes, and ultimately deliver more value to our customers. We urge you to approve this request as soon as possible.
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37868623,
#     "bidder_id": 456,
#     "project_id": 37868623,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 14558179
# }
# Generated proposal: Data Science Mock Interviews Expert
#
# Data science is a rapidly growing field, and there is a high demand for skilled data scientists. However, many job seekers lack the experience necessary to land a data science job. Data science mock interviews can help job seekers prepare for the interview process and showcase their skills to potential employers.
#
# A data science mock interview expert with 4-5 years of experience can provide valuable insights and guidance to job seekers. They can help job seekers identify their strengths and weaknesses, and develop strategies for answering common interview questions. Additionally, a mock interview expert can provide feedback on job seekers' resumes and LinkedIn profiles.
#
# Data science mock interviews can have a significant impact on job seekers' success. By providing job seekers with the opportunity to practice and receive feedback, mock interviews can help them to feel more confident and prepared for the interview process. This can lead to increased job offers and better job outcomes.
#
# Value:
#
#  Help job seekers prepare for the interview process
#  Showcase job seekers' skills to potential employers
#  Provide valuable insights and guidance
#  Help job seekers feel more confident and prepared for the interview process
#  Lead to increased job offers and better job outcomes
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37868602,
#     "bidder_id": 456,
#     "project_id": 37868602,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 70803505
# }
# Generated proposal: Project Proposal: Python Specialist for Stable Diffusion
#
# Problem: Stable diffusion is a key technique for image processing, computer vision, and other fields. However, existing implementations of stable diffusion are often slow and memory-intensive.
#
# Solution: We propose to develop a Python specialist for stable diffusion that is fast, memory-efficient, and easy to use. Our specialist will be based on PyTorch, and it will be open-source and available on GitHub.
#
# Impact: Our Python specialist for stable diffusion will have a significant impact on the fields of image processing, computer vision, and beyond. It will enable researchers and practitioners to use stable diffusion on larger datasets and more complex problems, leading to new insights and applications.
#
# Value: The Python specialist for stable diffusion will be a valuable tool for researchers and practitioners in the fields of image processing, computer vision, and beyond. It will be fast, memory-efficient, and easy to use, making it the ideal choice for a wide range of applications.
# Proposal saved to proposal.txt
# Created Bid Object: {
#     "id": 37868545,
#     "bidder_id": 456,
#     "project_id": 37868545,
#     "retracted": false,
#     "amount": 100,
#     "period": "1 week",
#     "description": "Example bid description",
#     "project_owner_id": 54989278
# }
#         _id                                             _title  \
# 0  37869301                 Python.flask project development.
# 1  37869245                     Python-Based Screenshot Expert
# 2  37869232        Intelligent Product Finder Telegram Chatbot
# 3  37863101       Python Expert for Training Task Verification
# 4  37869040          Python Developer for Sales Data Analytics
# 5  37869020        Easy21 Game Play via Reinforcement Learning
# 6  37868849                                               MILP
# 7  37868623           Urgently Needed: Python Flask Specialist
# 8  37868602  Datascience mock interviews expert(4-5 years o...
# 9  37868545             Python Specialist for Stable Diffusion
#
#    _budget_minimum  _budget_maximum   _type  _bidperiod  _time_submitted  \
# 0             30.0            250.0   fixed           7       1710241155
# 1             10.0             30.0   fixed           7       1710239944
# 2             30.0            250.0   fixed           7       1710239659
# 3             30.0            250.0   fixed           7       1710237893
# 4            600.0           1500.0   fixed           7       1710236507
# 5             10.0             30.0   fixed           7       1710236064
# 6            150.0            150.0   fixed          10       1710233401
# 7             30.0            250.0   fixed           7       1710229702
# 8            100.0            400.0  hourly           7       1710229479
# 9             10.0             30.0   fixed           7       1710228545
#
#    _bid_stats_bid_count  _bid_stats_bid_avg _currency_code  \
# 0                     5          191.996000            USD
# 1                     8           33.125000            USD
# 2                    19          160.921053            USD
# 3                    17          172.500000            USD
# 4                     7         1097.142857            INR
# 5                     9           80.000000            USD
# 6                     1          150.000000            EUR
# 7                     9          145.444444            AUD
# 8                     3          772.333333            INR
# 9                     8           44.125000            USD
#
#    _currency_exchange_rate                                           proposal  \
# 0                 1.000000  Python Flask Project Development Proposal\n\nP...
# 1                 1.000000  Python-Based Screenshot Expert\n\nProblem\n\nT...
# 2                 1.000000  Intelligent Product Finder Telegram Chatbot\n\...
# 3                 1.000000  Project Proposal: Python Expert for Training T...
# 4                 0.012080  Project Proposal: Python Developer for Sales D...
# 5                 1.000000  Easy21 Game Play via Reinforcement Learning\n\...
# 6                 1.093392  Project Proposal: MILP for Solving Real-World ...
# 7                 0.661610  Urgent Need: Python Flask Specialist\n\nProble...
# 8                 0.012080  Data Science Mock Interviews Expert\n\nData sc...
# 9                 1.000000  Project Proposal: Python Specialist for Stable...
#
#                                     full_description  \
# 0  We are seeking a talented Python Developer wit...
# 1  The project aims to automate the process of ca...
# 2  I require a proficient developer conversant in...
# 3  As a professional or hobbyist deeply immersed ...
# 4  I'm in need of a skilled Python developer expe...
# 5  I'm looking for an expert in Artificial Intell...
# 6  Mixed integer linear programming for VRP in pu...
# 7  I'm in immediate need of an experienced Python...
# 8  I am in need of a knowledgeable and experience...
# 9  Currently, I'm in need of an expert who specia...
#
#                                           bid_object
# 0  {\n    "id": 37869301,\n    "bidder_id": 456,\...
# 1  {\n    "id": 37869245,\n    "bidder_id": 456,\...
# 2  {\n    "id": 37869232,\n    "bidder_id": 456,\...
# 3  {\n    "id": 37863101,\n    "bidder_id": 456,\...
# 4  {\n    "id": 37869040,\n    "bidder_id": 456,\...
# 5  {\n    "id": 37869020,\n    "bidder_id": 456,\...
# 6  {\n    "id": 37868849,\n    "bidder_id": 456,\...
# 7  {\n    "id": 37868623,\n    "bidder_id": 456,\...
# 8  {\n    "id": 37868602,\n    "bidder_id": 456,\...
# 9  {\n    "id": 37868545,\n    "bidder_id": 456,\...
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re

# Define helper functions
def create_bid_object(project, bidder_id, amount, period, description):
    project_id = project['id']
    project_owner_id = project['owner_id']
    retracted = False  # Assuming the bid is not retracted by default

    # Now, create the bid object using the derived values
    bid_object = {
        'id': project_id,  # Use project_id as the bid id
        'bidder_id': bidder_id,
        'project_id': project_id,
        'retracted': retracted,
        'amount': amount,
        'period': period,
        'description': description,
        'project_owner_id': project_owner_id
    }

    return bid_object

def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'  # Replace 'YOUR_API_KEY' with your actual API key
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    full_descriptions = []
    bid_objects = []  # New list to store bid objects
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)
        
        # Create bid object
        bid_object = create_bid_object(
            project,
            bidder_id=456,  # Assuming bidder_id is known
            amount=100,     # Example bid amount
            period='1 week',
            description='Example bid description'
        )
        # Flatten the bid object for readability
        flattened_bid_object = flatten_project_data(bid_object, prefix='bid_object')
        bid_objects.append(flattened_bid_object)  # Append the flattened bid object
        
        # Print the created bid object
        print("Created Bid Object:", flattened_bid_object)
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    # Selecting only specific columns
    selected_columns = [
       '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
        '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'

    ]
    df = df[selected_columns]
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    # Add the flattened bid objects to the DataFrame
    bid_object_columns = list(flattened_bid_object.keys())
    for col in bid_object_columns:
        df[col] = [bid[col] if col in bid else None for bid in bid_objects]
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

if __name__ == "__main__":
    projects = sample_search_projects()
    print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: Project Proposal: Python Guru Needed
#
# Problem:
#
# Our team is developing a new product that uses Python. We need a Python guru to help us design and implement the code.
#
# Solution:
#
# We are looking for a Python expert with experience in software development. The ideal candidate will have a strong understanding of Python syntax, data structures, and algorithms. They will also be able to work independently and as part of a team.
#
# Benefits:
#
# The successful candidate will have the opportunity to work on a cutting-edge project with a talented team of engineers. They will also have the opportunity to learn from and grow with some of the best Python experts in the industry.
#
# Impact:
#
# The successful candidate will make a significant impact on the development of our new product. They will help us to create a high-quality product that meets the needs of our customers.
#
# Timeline:
#
# The project will start immediately and will last for six months.
#
# Budget:
#
# The budget for the project is \$100,000.
#
# Contact:
#
# If you are interested in this position, please contact us at [email protected]
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37869457, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37869457, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 51045059}
# Generated proposal: Azure Backend API Marketplace Development Proposal
#
# The Azure Backend API Marketplace is a cloud-based platform that allows developers to quickly and easily create, deploy, and manage APIs. The marketplace provides a catalog of pre-built APIs that can be used to accelerate development, and it also offers a variety of tools and services to help developers create and manage their own APIs.
#
# The Azure Backend API Marketplace has the potential to significantly impact the way that developers build and deploy APIs. By providing a centralized platform for API development and management, the marketplace can help to reduce the time and cost of creating APIs, and it can also help to improve the quality of APIs.
#
# The marketplace is also expected to have a positive impact on the adoption of cloud-based APIs. By making it easier for developers to create and deploy APIs, the marketplace can help to increase the number of APIs that are available on the cloud, and it can also help to make it easier for businesses to use APIs to improve their products and services.
#
# The Azure Backend API Marketplace is a valuable tool for developers who are looking to create and deploy APIs. The marketplace provides a variety of benefits that can help developers to improve the speed, quality, and cost-effectiveness of their API development projects.
#
# Value:
#
#  Reduces the time and cost of creating APIs
#  Improves the quality of APIs
#  Increases the number of APIs that are available on the cloud
#  Makes it easier for businesses to use APIs
#
# Impact:
#
#  Accelerates innovation
#  Improves customer experience
#  Reduces costs
#  Increases revenue
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37869447, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37869447, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 14102635}
# Generated proposal: Python Flask Project Development Proposal
#
# Project Overview
#
# Python Flask is a popular framework for developing web applications. It is known for its simplicity, ease of use, and flexibility. This proposal outlines a project to develop a Python Flask web application that will provide a platform for users to share and find recipes. The application will be hosted on a cloud-based platform and will be accessible to users from anywhere in the world.
#
# Project Goals
#
# The goals of this project are to:
#
#  Develop a user-friendly web application that allows users to share and find recipes.
#  Host the application on a cloud-based platform to make it accessible to users from anywhere in the world.
#  Use Python Flask to develop the application, which will allow for rapid development and deployment.
#
# Project Benefits
#
# The benefits of this project include:
#
#  A platform for users to share and find recipes.
#  Increased access to recipes for users around the world.
#  Rapid development and deployment of the application using Python Flask.
#
# Project Timeline
#
# The project will be completed in three phases:
#
#  Phase 1: Design and development of the application (2 weeks)
#  Phase 2: Testing and deployment of the application (2 weeks)
#  Phase 3: User feedback and refinement (1 week)
#
# Project Budget
#
# The total cost of the project is estimated to be \$5,000. This includes the cost of software development, cloud hosting, and user testing.
#
# Project Approval
#
# I request approval for this project because it has the potential to provide a valuable resource for users around the world. The application will be easy to use and accessible to users from anywhere in the world. It will also be developed using Python Flask, which will allow for rapid development and deployment.
#
# Signature:
# [Your Name]
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37869301, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37869301, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 72882119}
# Generated proposal: Python-Based Screenshot Expert
#
# Problem: Manually taking screenshots and annotating them is time-consuming and error-prone.
#
# Solution: A Python-based screenshot expert that can automatically take screenshots and annotate them with relevant information. This would save time and improve the accuracy of screenshots, leading to better user experiences and increased productivity.
#
# Value: The Python-based screenshot expert would have the following benefits:
#
#  Save time: By automating the process of taking screenshots and annotating them, the Python-based screenshot expert would save users valuable time.
#  Improve accuracy: The Python-based screenshot expert would be able to take screenshots and annotate them more accurately than a human, reducing the risk of errors.
#  Improve user experiences: By providing users with more accurate and informative screenshots, the Python-based screenshot expert would improve their user experiences.
#  Increase productivity: By saving time and improving accuracy, the Python-based screenshot expert would help users to be more productive.
#
# Impact: The Python-based screenshot expert would have a significant impact on users by saving them time, improving their accuracy, and improving their user experiences. This would lead to increased productivity and better outcomes for businesses.
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37869245, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37869245, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 20013642}
# Generated proposal: Intelligent Product Finder Telegram Chatbot
#
# Problem: Customers find it difficult to find the right products online. They often have to search through multiple websites and compare prices, which can be time-consuming and frustrating.
#
# Solution: An intelligent product finder Telegram chatbot that can help customers find the right products quickly and easily. The chatbot would use natural language processing to understand customer needs and then search through a variety of online retailers to find the best possible matches. The chatbot would also be able to provide information about product prices, reviews, and availability.
#
# Benefits:
#
#  Save customers time and effort by finding the right products quickly and easily
#  Improve customer satisfaction by providing a more personalized and helpful shopping experience
#  Increase sales by driving traffic to online retailers
#
# Impact:
#
# The intelligent product finder Telegram chatbot would have a significant impact on the e-commerce industry by making it easier for customers to find the products they want. This would lead to increased customer satisfaction and sales for online retailers.
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37869232, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37869232, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 74946177}
# Generated proposal: Project Proposal: Python Expert for Training Task Verification
#
# Problem:
#
# Machine learning models are becoming increasingly important for businesses of all sizes. However, it can be difficult to ensure that these models are accurate and reliable. One way to do this is to use training task verification, which involves checking that the model is able to perform the task it was trained for.
#
# Solution:
#
# We propose to develop a Python expert for training task verification. This expert will be able to automatically check that a model is able to perform the task it was trained for, and will provide feedback on how to improve the model if necessary. This will help businesses to ensure that their machine learning models are accurate and reliable, and will ultimately lead to better business outcomes.
#
# Benefits:
#
# The benefits of this project include:
#
#  Improved accuracy and reliability of machine learning models
#  Reduced costs associated with model development and maintenance
#  Increased speed and efficiency of model development
#  Improved customer satisfaction
#
# Timeline:
#
# This project will be completed in three phases:
#
#  Phase 1: Research and development (3 months)
#  Phase 2: Prototype development (6 months)
#  Phase 3: Testing and deployment (9 months)
#
# Budget:
#
# The total budget for this project is \$150,000.
#
# Conclusion:
#
# We believe that this project has the potential to significantly impact the field of machine learning. By developing a Python expert for training task verification, we will help businesses to ensure that their machine learning models are accurate and reliable, and will ultimately lead to better business outcomes.
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37863101, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37863101, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 75034540}
# Generated proposal: Project Proposal: Python Developer for Sales Data Analytics
#
# Problem: Sales teams are drowning in data, but they lack the tools to turn that data into insights. As a result, they're making decisions based on gut instinct rather than data-driven evidence.
#
# Solution: A Python developer can help sales teams build and deploy data analytics solutions that will give them the insights they need to make better decisions. These solutions can help teams identify trends, forecast sales, and target the right customers.
#
# Impact: By implementing a data analytics solution, sales teams can:
#
#  Increase sales by 10%-20%
#  Reduce costs by 5%-10%
#  Improve customer satisfaction by 10%-20%
#
# Benefits:
#
#  A Python developer can help you build a custom data analytics solution that meets your specific needs.
#  A Python developer can help you integrate your data from multiple sources, such as Salesforce, Google Analytics, and HubSpot.
#  A Python developer can help you visualize your data in a way that's easy to understand and actionable.
#
# Call to action: If you're ready to take your sales team to the next level, contact us today to learn more about our Python development services.
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37869040, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37869040, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 62521667}
# Generated proposal: Easy21 Game Play via Reinforcement Learning
#
# Problem: Playing Easy21 optimally is a challenging problem in reinforcement learning, as the game involves a large state space and complex decision-making.
#
# Solution: We propose a novel approach to playing Easy21 using reinforcement learning, which we believe will achieve state-of-the-art results. Our approach is based on a deep neural network that learns to represent the state of the game and a policy network that outputs an action to take.
#
# Benefits: Our approach has the potential to significantly improve the performance of Easy21 players, which could lead to new applications in gambling and other domains. Additionally, our research could contribute to the development of more general-purpose reinforcement learning algorithms.
#
# Impact: The successful development of our approach could have a significant impact on the field of reinforcement learning. Our work could also lead to new applications in gambling and other domains, and could contribute to the development of more general-purpose reinforcement learning algorithms.
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37869020, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37869020, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 41567737}
# Generated proposal: MILP: A Proposal
#
# Problem: Many businesses struggle to optimize their operations due to the complexity of their constraints. This can lead to lost revenue, wasted resources, and decreased customer satisfaction.
#
# Solution: MILP (Mixed-Integer Linear Programming) is a powerful mathematical optimization technique that can be used to solve a wide variety of problems. MILP can help businesses to find the best possible solutions to their problems, even when those problems have many constraints.
#
# Value: MILP can deliver significant value to businesses by helping them to:
#
#  Increase profits
#  Reduce costs
#  Improve efficiency
#  Increase customer satisfaction
#
# Impact: MILP can have a significant impact on businesses by helping them to achieve their goals. By using MILP, businesses can:
#
#  Grow their revenue
#  Become more profitable
#  Gain a competitive advantage
#  Improve their customer experience
#
# Conclusion: MILP is a powerful tool that can help businesses to achieve their goals. If you are looking for a way to improve your business, I encourage you to learn more about MILP.
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37868849, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37868849, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 73047049}
# Generated proposal: Urgent Need: Python Flask Specialist
#
# We are seeking a Python Flask specialist to join our team. The ideal candidate will have experience with Flask, SQL, and NoSQL databases. The position will be responsible for developing and maintaining web applications using Python Flask.
#
# This is a critical role for our team, as we are looking to expand our web application offerings. The successful candidate will be able to work independently and as part of a team. They will also be able to work under pressure and meet deadlines.
#
# This is a full-time position, based in our San Francisco office.
#
# The impact of this role:
#
# The Python Flask specialist will play a key role in developing and maintaining our web applications. They will be responsible for ensuring that our applications are reliable, scalable, and secure. The successful candidate will have a significant impact on the growth of our business.
# Proposal saved to proposal.txt
# Created Bid Object: {'bid_object_id': 37868623, 'bid_object_bidder_id': 456, 'bid_object_project_id': 37868623, 'bid_object_retracted': False, 'bid_object_amount': 100, 'bid_object_period': '1 week', 'bid_object_description': 'Example bid description', 'bid_object_project_owner_id': 14558179}
#         _id                                        _title  _budget_minimum  \
# 0  37869457                            Python Guru Needed             30.0
# 1  37869447     Azure Backend API Marketplace Development           1250.0
# 2  37869301            Python.flask project development.              30.0
# 3  37869245                Python-Based Screenshot Expert             10.0
# 4  37869232   Intelligent Product Finder Telegram Chatbot             30.0
# 5  37863101  Python Expert for Training Task Verification             30.0
# 6  37869040     Python Developer for Sales Data Analytics            600.0
# 7  37869020   Easy21 Game Play via Reinforcement Learning             10.0
# 8  37868849                                          MILP            150.0
# 9  37868623      Urgently Needed: Python Flask Specialist             30.0
#
#    _budget_maximum   _type  _bidperiod  _time_submitted  _bid_stats_bid_count  \
# 0            250.0   fixed           7       1710243799                    20
# 1           2500.0  hourly           7       1710243629                     6
# 2            250.0   fixed           7       1710241155                     6
# 3             30.0   fixed           7       1710239944                     8
# 4            250.0   fixed           7       1710239659                    20
# 5            250.0   fixed           7       1710237893                    21
# 6           1500.0   fixed           7       1710236507                     9
# 7             30.0   fixed           7       1710236064                     9
# 8            150.0   fixed          10       1710233401                     1
# 9            250.0   fixed           7       1710229702                    10
#
#    _bid_stats_bid_avg _currency_code  ...  \
# 0          114.750000            AUD  ...
# 1         1916.666667            INR  ...
# 2          184.996667            USD  ...
# 3           33.125000            USD  ...
# 4          158.875000            USD  ...
# 5          255.119048            USD  ...
# 6         1036.666667            INR  ...
# 7           80.000000            USD  ...
# 8          150.000000            EUR  ...
# 9          150.900000            AUD  ...
#
#                                             proposal  \
# 0  Project Proposal: Python Guru Needed\n\nProble...
# 1  Azure Backend API Marketplace Development Prop...
# 2  Python Flask Project Development Proposal\n\nP...
# 3  Python-Based Screenshot Expert\n\nProblem: Man...
# 4  Intelligent Product Finder Telegram Chatbot\n\...
# 5  Project Proposal: Python Expert for Training T...
# 6  Project Proposal: Python Developer for Sales D...
# 7  Easy21 Game Play via Reinforcement Learning\n\...
# 8  MILP: A Proposal\n\nProblem: Many businesses s...
# 9  Urgent Need: Python Flask Specialist\n\nWe are...
#
#                                     full_description bid_object_id  \
# 0  i have errors at my website ( Python Language ...      37869457
# 1  I'm seeking an expert in Azure and Backend API...      37869447
# 2  We are seeking a talented Python Developer wit...      37869301
# 3  The project aims to automate the process of ca...      37869245
# 4  I require a proficient developer conversant in...      37869232
# 5  As a professional or hobbyist deeply immersed ...      37863101
# 6  I'm in need of a skilled Python developer expe...      37869040
# 7  I'm looking for an expert in Artificial Intell...      37869020
# 8  Mixed integer linear programming for VRP in pu...      37868849
# 9  I'm in immediate need of an experienced Python...      37868623
#
#    bid_object_bidder_id  bid_object_project_id  bid_object_retracted  \
# 0                   456               37869457                 False
# 1                   456               37869447                 False
# 2                   456               37869301                 False
# 3                   456               37869245                 False
# 4                   456               37869232                 False
# 5                   456               37863101                 False
# 6                   456               37869040                 False
# 7                   456               37869020                 False
# 8                   456               37868849                 False
# 9                   456               37868623                 False
#
#    bid_object_amount  bid_object_period   bid_object_description  \
# 0                100             1 week  Example bid description
# 1                100             1 week  Example bid description
# 2                100             1 week  Example bid description
# 3                100             1 week  Example bid description
# 4                100             1 week  Example bid description
# 5                100             1 week  Example bid description
# 6                100             1 week  Example bid description
# 7                100             1 week  Example bid description
# 8                100             1 week  Example bid description
# 9                100             1 week  Example bid description
#
#   bid_object_project_owner_id
# 0                    51045059
# 1                    14102635
# 2                    72882119
# 3                    20013642
# 4                    74946177
# 5                    75034540
# 6                    62521667
# 7                    41567737
# 8                    73047049
# 9                    14558179
#
# [10 rows x 21 columns]
# DataFrame saved to projects_with_proposals.csv

# %%
from freelancersdk.resources.projects import place_project_bid
from freelancersdk.session import Session
from freelancersdk.resources.users import get_self_user_id
from freelancersdk.exceptions import BidNotPlacedException
import os

# https://www.freelancer.com/api/docs/cases/creating_a_bid
def sample_place_project_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')

    session = Session(oauth_token=oauth_token, url=url)

    try:
        my_user_id = get_self_user_id(session)
    except:
        # User ID not retrieved. Handle the error here, e.g., print an error message.
        return None

    bid_data = {
        'project_id': int(37869764),
        'bidder_id': my_user_id,
        'amount': 10,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        return place_project_bid(session, **bid_data)
    except BidNotPlacedException as e:
        print(('Error message: %s' % e.message))
        print(('Error code: %s' % e.error_code))
        return None


b = sample_place_project_bid()
if b:
    print(("Bid placed: %s" % b))

# %%
import os
import pandas as pd
import requests
import re
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id, place_project_bid
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
from freelancersdk.resources.users import get_self_user_id
from freelancersdk.exceptions import BidNotPlacedException

# Define helper functions
def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    full_descriptions = []
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    # Selecting only specific columns
    selected_columns = [
       '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
        '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'

    ]
    df = df[selected_columns]
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

# Function to place a bid on a project
def sample_place_project_bid():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    project_id = os.environ.get('PROJECT_ID')

    session = Session(oauth_token=oauth_token, url=url)

    try:
        my_user_id = get_self_user_id(session)
    except:
        # User ID not retrieved. Handle the error here, e.g., print an error message.
        return None

    bid_data = {
        'project_id': int(37869764),
        'bidder_id': my_user_id,
        'amount': 10,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        return place_project_bid(session, **bid_data)
    except BidNotPlacedException as e:
        print(('Error message: %s' % e.message))
        print(('Error code: %s' % e.error_code))
        return None

# Main function to run the code
def main():
    projects = sample_search_projects()
    print_projects_table_with_proposal(projects)
    b = sample_place_project_bid()
    if b:
        print(("Bid placed: %s" % b))

if __name__ == "__main__":
    main()
# Out:
# Generated proposal: Trading View Indicators Coding in Python
#
# Trading View is a popular platform for technical analysis and trading. Its wide range of indicators and charting tools make it a powerful tool for traders of all levels. However, the platform's native coding language, PineScript, can be difficult to learn. This project proposes to create a library of TradingView indicators written in Python, making it easier for traders to create and use custom indicators.
#
# The library would be open source and available on GitHub. It would include a variety of indicators, from simple moving averages to complex technical indicators. The library would also include documentation and examples to help traders get started.
#
# This project would have a significant impact on the TradingView community. It would make it easier for traders to create and use custom indicators, which would lead to increased innovation and creativity. The library would also make it easier for traders to learn about technical analysis, as they would have access to a wide range of indicators and examples.
#
# In short, this project would make TradingView a more powerful and accessible tool for technical analysis and trading.
# Proposal saved to proposal.txt
# Generated proposal: Proposal for Docker Image Creation for Python REST API - Google Cloud Run
#
# Problem
#
# Developing and deploying a Python REST API can be a time-consuming and complex process. This is especially true if you want to deploy your API on a serverless platform like Google Cloud Run.
#
# Solution
#
# Creating a Docker image for your Python REST API can help you to streamline the development and deployment process. Docker images are self-contained, portable packages that can be easily deployed to any environment.
#
# Benefits
#
# Creating a Docker image for your Python REST API can provide you with a number of benefits, including:
#
#  Reduced development time: Docker images can help you to speed up the development process by providing a standardized environment for your code.
#  Simplified deployment: Docker images can make it easier to deploy your API to a serverless platform like Google Cloud Run.
#  Increased portability: Docker images are portable packages that can be easily deployed to any environment.
#
# Impact
#
# Creating a Docker image for your Python REST API can have a significant impact on your development and deployment processes. By streamlining these processes, you can free up your time to focus on other tasks, such as developing new features and improving your API.
#
# Call to action
#
# If you are interested in learning more about how to create a Docker image for your Python REST API, please contact us today. We would be happy to help you get started.
# Proposal saved to proposal.txt
# Generated proposal: Human Face Detection Python Project
#
# We propose to develop a Python project that can detect human faces in images and videos. This project would have a variety of applications, such as:
#
#  Security: The project could be used to detect unauthorized persons in restricted areas.
#  Surveillance: The project could be used to monitor people in public places for safety and security purposes.
#  Healthcare: The project could be used to track patients' movements and vital signs.
#  Education: The project could be used to create interactive learning materials that track students' attention and engagement.
#
# The project would be developed using Python, a popular programming language that is well-suited for machine learning applications. The project would be open source, so that it could be used by anyone for free.
#
# We believe that this project would have a significant impact on a variety of industries. It would make security systems more effective, improve surveillance capabilities, and help to provide better healthcare and education.
# Proposal saved to proposal.txt
# Generated proposal: PDF Page Analyser Proposal
#
# Problem: PDFs are a common format for storing and sharing documents, but they can be difficult to analyze. Existing tools are either too complex or too limited.
#
# Solution: The PDF Page Analyser is a tool that makes it easy to extract data from PDFs. It can be used to extract text, images, tables, and other content. The tool is also able to identify the structure of a PDF, making it easy to find specific information.
#
# Benefits: The PDF Page Analyser has a number of benefits, including:
#
#  Ease of use: The tool is easy to use, even for users who are not familiar with PDFs.
#  Powerful: The tool can extract a wide variety of data from PDFs.
#  Flexible: The tool can be used to extract data from PDFs in a variety of ways.
#
# Impact: The PDF Page Analyser has the potential to have a significant impact on a variety of industries. It can be used to improve efficiency, reduce costs, and improve decision-making.
#
# Call to action: We are seeking funding to develop the PDF Page Analyser. We believe that this tool has the potential to make a significant impact on a variety of industries. We are confident that the PDF Page Analyser will be a valuable tool for businesses and organizations of all sizes.
# Proposal saved to proposal.txt
# Generated proposal: Data Science Mock Interviews Expert
#
# Data science is a hot field, and with the demand for data scientists growing rapidly, it's more important than ever to be prepared for a data science interview. A data science mock interview with an expert can help you to identify your strengths and weaknesses, and give you the practice you need to ace your next interview.
#
# Benefits of a data science mock interview:
#
#  Identify your strengths and weaknesses
#  Practice answering common interview questions
#  Get feedback on your technical skills and communication skills
#  Gain confidence in your ability to perform well in a data science interview
#
# Impact of a data science mock interview:
#
# A data science mock interview can help you to land your dream job by giving you the practice and confidence you need to perform well in a real interview. With a mock interview, you can be sure that you're prepared for any question that comes your way, and you'll be more likely to make a positive impression on potential employers.
#
# Call to action:
#
# If you're looking to land a data science job, a mock interview with an expert is a valuable investment. Contact us today to schedule your session.
# Proposal saved to proposal.txt
# Generated proposal: Python Script Development for Web Scraping
#
# Web scraping is a valuable tool for businesses of all sizes. It can be used to collect data from websites, extract information, and automate tasks. By developing a Python script for web scraping, businesses can save time and money, improve their efficiency, and gain a competitive advantage.
#
# Here are some of the benefits of using Python for web scraping:
#
#  Simplicity: Python is a powerful and easy-to-learn programming language. This makes it ideal for developers of all skill levels.
#  Flexibility: Python is a versatile language that can be used for a wide variety of tasks. This makes it a good choice for businesses with a variety of needs.
#  Speed: Python is a fast language that can be used to quickly and efficiently scrape data from websites.
#  Reliability: Python is a reliable language that is known for its stability and performance. This makes it a good choice for businesses that need to ensure that their web scraping scripts are running smoothly.
#
# If you are looking for a way to improve your business's efficiency and gain a competitive advantage, then Python web scraping is a great option. By developing a Python script for web scraping, you can collect the data you need to make informed decisions, improve your marketing efforts, and stay ahead of the competition.
#
# Call to action:
#
# To learn more about how Python web scraping can benefit your business, please contact us today.
# Proposal saved to proposal.txt
# Generated proposal: E-commerce Website Development Needed
#
# E-commerce is booming, and businesses of all sizes are looking to get a piece of the action. A well-developed e-commerce website can help you reach new customers, increase sales, and grow your business.
#
# Here are just a few of the benefits of having an e-commerce website:
#
#  Increased sales: An e-commerce website allows you to sell your products or services to customers around the world, 24/7.
#  Reach new customers: A well-optimized e-commerce website can help you reach new customers who are searching for products or services like yours.
#  Improved customer service: An e-commerce website can make it easier for customers to find the information they need, place orders, and track their shipments.
#
# If you're ready to take your business to the next level, an e-commerce website is a must-have. Contact us today to learn more about how we can help you create a successful e-commerce website.
# Proposal saved to proposal.txt
# Generated proposal: Social Media Integration API Development Proposal
#
# Value:
#
# A Social Media Integration API would allow our customers to easily connect their social media accounts with our platform, giving them a single place to manage their content and engage with their audience. This would save them time and effort, and would also improve the overall user experience.
#
# Impact:
#
# The Social Media Integration API would have a significant impact on our customers, by:
#
#  Increasing customer satisfaction and loyalty
#  Reducing the time it takes to manage social media accounts
#  Improving the overall user experience
#  Driving new business opportunities
#
# Project Description:
#
# The Social Media Integration API would be a RESTful API that would allow our customers to connect their social media accounts with our platform. The API would support the following features:
#
#  OAuth 2.0 authentication
#  CRUD operations for social media posts, comments, and likes
#  Webhooks for real-time updates
#
# The API would be developed using agile methodology, and would be released in phases. The first phase would focus on supporting the core features of the API, and the second phase would add support for additional features such as pagination and search.
#
# Budget:
#
# The total cost of the Social Media Integration API project is estimated to be \$100,000. This includes the cost of development, testing, and deployment.
#
# Timeline:
#
# The Social Media Integration API project is scheduled to be completed in six months. The project will be divided into two phases:
#
#  Phase 1: Core features (3 months)
#  Phase 2: Additional features (3 months)
#
# Conclusion:
#
# The Social Media Integration API would be a valuable addition to our platform, and would have a significant impact on our customers. We are confident that this project is a worthwhile investment, and we look forward to its successful completion.
# Proposal saved to proposal.txt
# Generated proposal: Machine Learning Specialist Needed
#
# Problem
#
# Our company is facing a challenge in developing and deploying machine learning models. We need a specialist with expertise in data science, machine learning, and software engineering to help us address this challenge.
#
# Solution
#
# A machine learning specialist would be able to help us develop and deploy machine learning models that can solve a variety of problems, such as:
#
#  Predicting customer churn
#  Optimizing product recommendations
#  Detecting fraud
#
# Impact
#
# A machine learning specialist would have a significant impact on our company by helping us to:
#
#  Increase revenue
#  Reduce costs
#  Improve customer satisfaction
#
# Benefits
#
# The benefits of hiring a machine learning specialist include:
#
#  Increased revenue
#  Reduced costs
#  Improved customer satisfaction
#  Competitive advantage
#
# Call to Action
#
# We are seeking a highly motivated and experienced machine learning specialist to join our team. If you are interested in this position, please send your resume and cover letter to [email protected]
# Proposal saved to proposal.txt
# Generated proposal: Advanced Python Developer for Automation Scripts
#
# Problem
#
# Many businesses are struggling to automate their processes due to a lack of skilled Python developers. This is leading to lost productivity and increased costs.
#
# Solution
#
# We propose to create an Advanced Python Developer training program that will teach students the skills they need to automate their businesses' processes. This program will be delivered online and will be self-paced, so students can learn at their own speed.
#
# Benefits
#
# The benefits of this program include:
#
#  Increased productivity: By automating their processes, businesses can save time and money.
#  Reduced costs: Automation can help businesses reduce costs by eliminating the need for manual tasks.
#  Improved efficiency: Automation can help businesses improve efficiency by streamlining processes and reducing errors.
#
# Impact
#
# This program will have a significant impact on businesses by helping them to automate their processes, save time and money, and improve efficiency.
# Proposal saved to proposal.txt
#         _id                                             _title  \
# 0  37870051           Trading View Indicators Coding in Python
# 1  37870014  Docker Image Creation for Python REST API - Go...
# 2  37869992                Human Face Detection Python Project
# 3  37869949                                  PDF page analyser
# 4  37868602  Datascience mock interviews expert(4-5 years o...
# 5  37869899         Python Script Development for Web Scraping
# 6  37869836              E-commerce Website Development Needed
# 7  37869764           Social Media Integration API Development
# 8  37869755                 Machine Learning Specialist Needed
# 9  37869695   Advanced Python Developer for Automation Scripts
#
#    _budget_minimum  _budget_maximum   _type  _bidperiod  _time_submitted  \
# 0            600.0           1500.0   fixed           7       1710253865
# 1             10.0             30.0   fixed           7       1710253186
# 2            600.0           1500.0   fixed           7       1710252799
# 3            200.0            200.0   fixed          10       1710252201
# 4            100.0            400.0  hourly           7       1710229479
# 5             10.0             30.0   fixed           7       1710251270
# 6            600.0            601.0   fixed           7       1710250209
# 7           1500.0          12500.0   fixed           7       1710249007
# 8             30.0            250.0   fixed           7       1710248939
# 9             30.0            250.0   fixed           7       1710248266
#
#    _bid_stats_bid_count  _bid_stats_bid_avg _currency_code  \
# 0                     1         1050.000000            INR
# 1                     3           28.333333            USD
# 2                    11        14600.000000            INR
# 3                     1          200.000000            AUD
# 4                     4          604.250000            INR
# 5                     7          115.000000            CAD
# 6                    11         3459.818182            INR
# 7                     8         9825.000000            INR
# 8                    29          188.931034            EUR
# 9                    35          172.928571            USD
#
#    _currency_exchange_rate                                           proposal  \
# 0                 0.012075  Trading View Indicators Coding in Python\n\nTr...
# 1                 1.000000  Proposal for Docker Image Creation for Python ...
# 2                 0.012075  Human Face Detection Python Project\n\nWe prop...
# 3                 0.659522  PDF Page Analyser Proposal\n\nProblem: PDFs ar...
# 4                 0.012075  Data Science Mock Interviews Expert\n\nData sc...
# 5                 0.740700  Python Script Development for Web Scraping\n\n...
# 6                 0.012075  E-commerce Website Development Needed\n\nE-com...
# 7                 0.012075  Social Media Integration API Development Propo...
# 8                 1.091209  Machine Learning Specialist Needed\n\nProblem\...
# 9                 1.000000  Advanced Python Developer for Automation Scrip...
#
#                                     full_description
# 0  In this project, I am seeking a proficient Pyt...
# 1  I need assistance with creating a Dockerfile a...
# 2  I am in need of a professional with experience...
# 3  Hi Ishaq, I was wondering if you'd be interest...
# 4  I am in need of a knowledgeable and experience...
# 5  I am looking for a talented Python developer t...
# 6  I need an expert to create an e-commerce websi...
# 7  I am looking for a seasoned developer with a d...
# 8  We need to create a machine learning model ins...
# 9  I'm looking for a highly-skilled Python develo...
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
import requests
import re
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id, place_project_bid
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
from freelancersdk.resources.users import get_self_user_id
from freelancersdk.exceptions import BidNotPlacedException

# Define helper functions
def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def sample_place_project_bid(session):
    try:
        my_user_id = get_self_user_id(session)
    except:
        # User ID not retrieved. Handle the error here, e.g., print an error message.
        return None, "User ID not retrieved"

    bid_data = {
        'project_id': int(37869764),
        'bidder_id': my_user_id,
        'amount': 10,
        'period': 2,
        'milestone_percentage': 100,
        'description': 'This is my bid',
    }

    try:
        bid_result = place_project_bid(session, **bid_data)
        return bid_result, "Bid placed successfully"
    except BidNotPlacedException as e:
        error_message = 'Error message: %s' % e.message
        error_code = 'Error code: %s' % e.error_code
        return None, f"{error_message}, {error_code}"

def print_projects_table_with_proposal_and_bids(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    full_descriptions = []
    bids = []
    bid_statuses = []
    session = Session(oauth_token=os.environ.get('FLN_OAUTH_TOKEN'), url=os.environ.get('FLN_URL'))
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        # Place bid
        bid_result, bid_status = sample_place_project_bid(session)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)
        bids.append(bid_result)
        bid_statuses.append(bid_status)
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    # Selecting only specific columns
    selected_columns = [
       '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
        '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'
    ]
    df = df[selected_columns]
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    df['bid_result'] = bids  # Add bid results to the DataFrame
    df['bid_status'] = bid_statuses  # Add bid statuses to the DataFrame
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals_and_bids.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

# Main function to run the code
def main():
    projects = sample_search_projects()
    print_projects_table_with_proposal_and_bids(projects)

if __name__ == "__main__":
    main()
# Out:
# Generated proposal: Trading View Indicators Coding in Python:
#
# Learn to code TradingView indicators in Python and backtest your strategies with real data. This is a valuable skill for any trader who wants to take their trading to the next level. With this skill, you can create your own indicators and strategies, and backtest them to see how they would have performed in the past. This will help you to make more informed trading decisions and increase your chances of success.
# Proposal saved to proposal.txt
# Generated proposal: Docker Image Creation for Python REST API - Google Cloud Run
#
# Value:
#
# - Reduces time to deploy Python REST APIs to Google Cloud Run by 80%
# - Improves reliability and scalability of Python REST APIs by running them in a containerized environment
# - Reduces costs by eliminating the need to provision and manage servers
#
# Impact:
#
# - Enables developers to quickly and easily deploy Python REST APIs to Google Cloud Run
# - Improves the reliability and scalability of Python REST APIs
# - Reduces costs for running Python REST APIs on Google Cloud Run
# Proposal saved to proposal.txt
# Generated proposal: Human Face Detection Python Project
#
# Problem: Facial recognition technology is becoming increasingly important, but it is often limited by high costs and a lack of accessibility.
#
# Solution: This project will develop a Python-based face detection algorithm that is both accurate and affordable. The algorithm will be open-source, making it available to anyone who wants to use it.
#
# Impact: This project will have a significant impact by making facial recognition technology more accessible to a wider range of applications. For example, it could be used to improve security, facilitate access to services, and create more engaging user experiences.
#
# Value: The project will be valuable to a wide range of stakeholders, including developers, researchers, and businesses. It will also benefit the public by making facial recognition technology more affordable and accessible.
# Proposal saved to proposal.txt
# Generated proposal: PDF Page Analyser Proposal
#
# Problem: PDFs are a common format for storing and sharing documents, but they can be difficult to analyze. The lack of structure and standardization makes it difficult to extract information from PDFs, and the sheer volume of PDFs can make it difficult to find the information you need.
#
# Solution: A PDF page analyzer would address these problems by providing a structured way to represent PDFs and by making it easy to search and extract information from them. The analyzer would be able to:
#
#  Extract text, images, and other data from PDFs
#  Identify the structure of a PDF, including the title, headings, and paragraphs
#  Search PDFs for specific words or phrases
#  Generate reports on the content of PDFs
#
# Benefits: A PDF page analyzer would have a number of benefits, including:
#
#  Increased productivity: By making it easier to find and extract information from PDFs, a PDF page analyzer could save businesses time and money.
#  Improved decision-making: By providing access to more information, a PDF page analyzer could help businesses make better decisions.
#  Improved security: By making it easier to identify and track PDFs, a PDF page analyzer could help businesses protect their sensitive data.
#
# Impact: A PDF page analyzer could have a significant impact on businesses by making it easier to find, extract, and use information from PDFs. This could lead to increased productivity, improved decision-making, and improved security.
# Proposal saved to proposal.txt
# Generated proposal: Data Science Mock Interviews Expert
#
# Data science is a rapidly growing field, and the demand for skilled data scientists is high. However, many job candidates lack the experience necessary to perform well in a data science interview. This can lead to qualified candidates being passed over for jobs that they are capable of doing.
#
# A data science mock interview expert can help bridge this gap by providing candidates with the opportunity to practice answering common interview questions and receive feedback on their performance. This can help candidates to improve their interviewing skills and increase their chances of landing the job.
#
# The value of a data science mock interview expert is clear: it can help candidates to get the jobs they want. The impact of this project is also significant: it can help to increase the number of qualified data scientists in the workforce, which will benefit businesses and organizations of all sizes.
#
# Call to action:
#
# If you are a data science professional with 4-5 years of experience, I encourage you to consider becoming a data science mock interview expert. You can make a real difference in the lives of job candidates and help to shape the future of data science.
# Proposal saved to proposal.txt
# Generated proposal: Python Script Development for Web Scraping
#
# Web scraping is a valuable technique for collecting data from websites. However, it can be time-consuming and difficult to do manually. By developing a Python script, we can automate the process of web scraping, making it more efficient and scalable.
#
# This project will have the following impacts:
#
#  Reduce the time and effort required to collect data from websites.
#  Increase the accuracy and consistency of data collection.
#  Make it possible to collect data from websites that would be difficult or impossible to do manually.
#
# The developed Python script will be a valuable tool for researchers, data scientists, and anyone else who needs to collect data from websites. It will save time and effort, improve the accuracy and consistency of data collection, and make it possible to collect data from websites that would be difficult or impossible to do manually.
#
# Benefits:
#
#  Save time and effort
#  Improve accuracy and consistency
#  Collect data from difficult-to-access websites
# Proposal saved to proposal.txt
# Generated proposal: E-commerce Website Development Proposal
#
# Problem:
#
# In today's digital world, having an online presence is essential for businesses of all sizes. An e-commerce website allows businesses to reach a wider audience, sell their products or services to customers around the world, and increase their sales.
#
# Solution:
#
# Developing a custom e-commerce website is the best way to ensure that your business has a strong online presence and can compete with other businesses in your industry. A well-designed e-commerce website will make it easy for customers to find the products or services they're looking for, make a purchase, and track their orders.
#
# Benefits:
#
# An e-commerce website can provide your business with a number of benefits, including:
#
#  Increased sales
#  Improved customer service
#  Increased brand awareness
#  Enhanced customer loyalty
#  Increased profitability
#
# Impact:
#
# A well-developed e-commerce website can have a significant impact on your business, helping you to reach new customers, increase sales, and improve your bottom line. If you're not yet taking advantage of the benefits of e-commerce, now is the time to start.
#
# Contact us today to learn more about how we can help you create a custom e-commerce website that will help your business grow.
# Proposal saved to proposal.txt
# Generated proposal: Social Media Integration API Development Proposal
#
# Value:
#
#  Increased user engagement: By integrating with social media platforms, businesses can increase user engagement by making it easier for users to share content, connect with other users, and stay up-to-date on the latest news and updates.
#  Improved customer service: Social media integration can also help businesses improve customer service by providing a direct line of communication between customers and businesses. This can help businesses resolve customer issues quickly and efficiently, and can also help build relationships with customers.
#  Enhanced marketing: Social media integration can also be used to enhance marketing efforts by allowing businesses to promote their products and services on social media platforms. This can help businesses reach a wider audience and generate more leads.
#
# Impact:
#
# The development of a social media integration API could have a significant impact on businesses by helping them to increase user engagement, improve customer service, and enhance marketing efforts. This could lead to increased sales and profits for businesses.
#
# Call to action:
#
# We are excited to develop a social media integration API for your business. Contact us today to learn more about how we can help you achieve your business goals.
# Proposal saved to proposal.txt
# Generated proposal: Machine Learning Specialist Needed
#
# Project Description
#
# The company is looking for a Machine Learning Specialist to join our team. The ideal candidate will have a strong background in machine learning, data science, and statistics. The role will involve developing and implementing machine learning models to solve real-world problems. The successful candidate will be able to work independently and as part of a team, and will have excellent communication and presentation skills.
#
# Value and Impact
#
# A Machine Learning Specialist will bring significant value to the company. By developing and implementing machine learning models, the company will be able to improve its efficiency and productivity, and make better decisions. The successful candidate will also be able to mentor and train other members of the team, and help to build a culture of innovation.
#
# Why should you join this project?
#
# This is an exciting opportunity to join a team of talented and passionate individuals who are working on cutting-edge machine learning technologies. The successful candidate will have the opportunity to make a real impact on the company, and to help to shape the future of machine learning.
# Proposal saved to proposal.txt
# Generated proposal: Advanced Python Developer for Automation Scripts
#
# Problem
#
# Many businesses are struggling to automate their processes due to a lack of skilled Python developers. This is leading to lost productivity and increased costs.
#
# Solution
#
# We propose to train a team of Advanced Python Developers who will be able to automate a wide range of business processes. This will save businesses time and money, and improve their efficiency.
#
# Benefits
#
# The benefits of our proposal include:
#
#  Increased productivity
#  Reduced costs
#  Improved efficiency
#  Improved customer satisfaction
#
# Impact
#
# Our proposal will have a significant impact on businesses by helping them to automate their processes and improve their efficiency. This will lead to increased productivity, reduced costs, and improved customer satisfaction.
#
# Call to Action
#
# We urge you to approve our proposal so that we can help you to achieve these benefits.
# Proposal saved to proposal.txt
#         _id                                             _title  \
# 0  37870051           Trading View Indicators Coding in Python
# 1  37870014  Docker Image Creation for Python REST API - Go...
# 2  37869992                Human Face Detection Python Project
# 3  37869949                                  PDF page analyser
# 4  37868602  Datascience mock interviews expert(4-5 years o...
# 5  37869899         Python Script Development for Web Scraping
# 6  37869836              E-commerce Website Development Needed
# 7  37869764           Social Media Integration API Development
# 8  37869755                 Machine Learning Specialist Needed
# 9  37869695   Advanced Python Developer for Automation Scripts
#
#    _budget_minimum  _budget_maximum   _type  _bidperiod  _time_submitted  \
# 0            600.0           1500.0   fixed           7       1710253865
# 1             10.0             30.0   fixed           7       1710253186
# 2            600.0           1500.0   fixed           7       1710252799
# 3            200.0            200.0   fixed          10       1710252201
# 4            100.0            400.0  hourly           7       1710229479
# 5             10.0             30.0   fixed           7       1710251270
# 6            600.0            601.0   fixed           7       1710250209
# 7           1500.0          12500.0   fixed           7       1710249007
# 8             30.0            250.0   fixed           7       1710248939
# 9             30.0            250.0   fixed           7       1710248266
#
#    _bid_stats_bid_count  _bid_stats_bid_avg _currency_code  \
# 0                     1         1050.000000            INR
# 1                     4           28.750000            USD
# 2                    11        14600.000000            INR
# 3                     1          200.000000            AUD
# 4                     4          604.250000            INR
# 5                     7          115.000000            CAD
# 6                    11         3459.818182            INR
# 7                     8         9825.000000            INR
# 8                    29          188.931034            EUR
# 9                    35          172.928571            USD
#
#    _currency_exchange_rate                                           proposal  \
# 0                 0.012075  Trading View Indicators Coding in Python:\n\nL...
# 1                 1.000000  Docker Image Creation for Python REST API - Go...
# 2                 0.012075  Human Face Detection Python Project\n\nProblem...
# 3                 0.659551  PDF Page Analyser Proposal\n\nProblem: PDFs ar...
# 4                 0.012075  Data Science Mock Interviews Expert\n\nData sc...
# 5                 0.740645  Python Script Development for Web Scraping\n\n...
# 6                 0.012075  E-commerce Website Development Proposal\n\nPro...
# 7                 0.012075  Social Media Integration API Development Propo...
# 8                 1.091451  Machine Learning Specialist Needed\n\nProject ...
# 9                 1.000000  Advanced Python Developer for Automation Scrip...
#
#                                     full_description bid_result  \
# 0  In this project, I am seeking a proficient Pyt...       None
# 1  I need assistance with creating a Dockerfile a...       None
# 2  I am in need of a professional with experience...       None
# 3  Hi Ishaq, I was wondering if you'd be interest...       None
# 4  I am in need of a knowledgeable and experience...       None
# 5  I am looking for a talented Python developer t...       None
# 6  I need an expert to create an e-commerce websi...       None
# 7  I am looking for a seasoned developer with a d...       None
# 8  We need to create a machine learning model ins...       None
# 9  I'm looking for a highly-skilled Python develo...       None
#
#               bid_status
# 0  User ID not retrieved
# 1  User ID not retrieved
# 2  User ID not retrieved
# 3  User ID not retrieved
# 4  User ID not retrieved
# 5  User ID not retrieved
# 6  User ID not retrieved
# 7  User ID not retrieved
# 8  User ID not retrieved
# 9  User ID not retrieved
# DataFrame saved to projects_with_proposals_and_bids.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re
from freelancersdk.resources.projects import (
    make_get_request, make_post_request, make_put_request,
)

# Define helper functions
def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def place_project_bid(session, project_id, bidder_id, description, amount, period, milestone_percentage):
    """
    Place a bid on a project
    """
    bid_data = {
        'id': project_id,
        'bidder_id': bidder_id,
        'description': description,
        'amount': amount,
        'period': period,
        'milestone_percentage': milestone_percentage,
    }
    # POST /api/projects/0.1/bids/
    response = make_post_request(session, 'bids', json_data=bid_data)
    json_data = response.json()
    if response.status_code == 200:
        bid_data = json_data['result']
        return Bid(bid_data)
    else:
        raise BidNotPlacedException(message=json_data['message'],
                                    error_code=json_data['error_code'],
                                    request_id=json_data['request_id'])

def print_projects_table_with_proposal_and_bid(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    full_descriptions = []
    bid_data_list = []  # List to store bid data for each project
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)

        # Sample bid data, replace this with actual bid data
        bid_data = {
            'bidder_id': '123456',
            'description': 'Sample bid description',
            'amount': 1000,
            'period': '1 week',
            'milestone_percentage': 50,
        }
        bid_data_list.append(bid_data)
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    # Selecting only specific columns
    selected_columns = [
       '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
        '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'

    ]
    df = df[selected_columns]
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    
    # Add bid data to DataFrame
    df['bid_data'] = bid_data_list
    
    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals_and_bid_data.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
print_projects_table_with_proposal_and_bid(projects)
# Out:
# Generated proposal: 4 in a Row Game in Python Console Application
#
# Problem
#
# There is a need for a simple and engaging game that can be played in the terminal.
#
# Solution
#
# A 4 in a Row game will be developed in Python. The game will be easy to learn and play, and it will provide hours of entertainment.
#
# Benefits
#
# The 4 in a Row game will have the following benefits:
#
#  It will be a fun and challenging game to play.
#  It will be easy to learn and play.
#  It will be free to download and play.
#  It will be available on all platforms that support Python.
#
# Impact
#
# The 4 in a Row game will have a positive impact by providing a fun and engaging way to spend time. It will also help to promote the Python programming language.
#
# Cost
#
# The development of the 4 in a Row game will be funded by a grant from the Python Software Foundation.
#
# Timeline
#
# The 4 in a Row game will be developed over the course of 6 months.
#
# Conclusion
#
# The 4 in a Row game is a valuable project that will provide a fun and engaging way to spend time. It will also help to promote the Python programming language.
# Proposal saved to proposal.txt
# Generated proposal: Trading View Indicators Coding in Python:
#
# Learn to code TradingView indicators in Python and gain a competitive edge in the financial markets. This project will teach you how to create custom indicators that can be used to analyze stocks, identify trading opportunities, and develop trading strategies. The project is perfect for intermediate to advanced Python programmers who are interested in trading and quantitative finance.
#
# Benefits of this project:
#
#  Learn to code TradingView indicators from scratch
#  Gain a competitive edge in the financial markets
#  Develop custom indicators to analyze stocks, identify trading opportunities, and develop trading strategies
#  Learn Python programming for finance
# Proposal saved to proposal.txt
# Generated proposal: Proposal for Docker Image Creation for Python REST API on Google Cloud Run
#
# Value:
#
# - Create a production-ready Docker image for a Python REST API
# - Deploy the image to Google Cloud Run, a serverless platform that allows you to run stateless containers that are invocable via HTTP requests
# - Benefit from Google Cloud Run's scalability, reliability, and cost-effectiveness
#
# Impact:
#
# - Reduce the time and effort required to deploy a Python REST API
# - Improve the scalability, reliability, and cost-effectiveness of a Python REST API
# - Enable developers to focus on building and innovating, rather than managing infrastructure
#
# Benefits:
#
# - Increased scalability: Google Cloud Run can automatically scale your application up or down based on demand, so you don't have to worry about over-provisioning or under-provisioning resources.
# - Increased reliability: Google Cloud Run is a highly reliable platform, with a proven track record of uptime.
# - Reduced costs: Google Cloud Run is a pay-per-use service, so you only pay for the resources you use.
#
# Next steps:
#
# - Gather requirements and identify the target audience for the API
# - Design the API and create the necessary code
# - Build the Docker image and push it to a Docker registry
# - Deploy the image to Google Cloud Run and configure the service
# - Test the API and make any necessary adjustments
#
# Timeline:
#
# This project can be completed in 4-6 weeks, depending on the complexity of the API.
# Proposal saved to proposal.txt
# Generated proposal: Human Face Detection Python Project
#
# Problem: Facial recognition is a key technology with a wide range of applications, from security to social media. However, current facial recognition systems are often biased against people of color and women.
#
# Solution: This project will develop a Python-based facial recognition system that is more accurate and fair than existing systems. The system will be trained on a diverse dataset of faces, and it will be evaluated to ensure that it does not discriminate against any particular group.
#
# Impact: The successful development of this project will have a significant impact on the field of facial recognition. The system will be more accurate and fair than existing systems, making it more useful for a wider range of applications. This will benefit people of color and women, who are currently underrepresented in facial recognition datasets.
#
# Budget: \$10,000
#
# Timeline: 6 months
# Proposal saved to proposal.txt
# Generated proposal: PDF Page Analyser Proposal
#
# Problem
#
# PDF documents are a common way to share information, but they can be difficult to analyze. The lack of structure and formatting makes it difficult to find specific information, and the sheer volume of PDFs can make it difficult to find the ones you're looking for.
#
# Solution
#
# A PDF page analyser would solve these problems by providing a way to easily search and organize PDF documents. The analyser would allow users to:
#
#  Search for specific text or data within a PDF
#  Sort PDFs by date, author, or other criteria
#  Create a table of contents for a PDF
#  Extract text from a PDF
#  Convert a PDF to a different format
#
# Benefits
#
# A PDF page analyser would have a number of benefits, including:
#
#  Increased productivity: Users would be able to find the information they need faster and easier, which would save them time.
#  Improved organization: Users would be able to organize their PDFs more easily, which would make them easier to find and use.
#  Increased accessibility: The ability to extract text from PDFs would make them more accessible to people with disabilities.
#
# Impact
#
# A PDF page analyser would have a significant impact on businesses and individuals alike. By making it easier to find and use PDF documents, the analyser would save time and improve productivity. It would also make PDFs more accessible to people with disabilities, increasing their ability to participate in society.
#
# Call to Action
#
# We are seeking funding to develop a PDF page analyser. We believe that this tool would have a significant impact on businesses and individuals alike, and we are confident that it would be a valuable addition to the market.
# Proposal saved to proposal.txt
# Generated proposal: Data Science Mock Interview Expert
#
# Problem
#
# Data science is a rapidly growing field, and the demand for skilled data scientists is high. However, many job seekers lack the experience they need to land a data science job. Data science mock interviews can help job seekers prepare for the interview process and increase their chances of success.
#
# Solution
#
# A data science mock interview expert with 4-5 years of experience can provide job seekers with the following benefits:
#
#  Targeted feedback on their skills and experience
#  Realistic interview practice
#  Strategies for answering tough interview questions
#  Tips for building rapport with interviewers
#  Confidence and preparation for the interview process
#
# Impact
#
# Data science mock interviews can help job seekers land their dream jobs by providing them with the skills and confidence they need to succeed in the interview process. With the help of a mock interview expert, job seekers can:
#
#  Increase their chances of getting hired by a data science company
#  Earn a higher salary
#  Accelerate their careers in the data science field
#
# Call to Action
#
# If you are a job seeker looking to land a data science job, I encourage you to schedule a mock interview with a data science expert. With the help of a mock interview expert, you can take your data science career to the next level.
# Proposal saved to proposal.txt
# Generated proposal: Python Script Development for Web Scraping
#
# Web scraping is a powerful technique that can be used to extract data from websites. This data can be used for a variety of purposes, such as research, marketing, and competitive intelligence. However, web scraping can be a time-consuming and tedious process. By developing a Python script, we can automate the process of web scraping, making it more efficient and scalable.
#
# The value of this project is that it will allow us to extract data from websites that would otherwise be difficult or impossible to access. This data can be used to gain insights into our competitors, identify new marketing opportunities, and conduct market research. The impact of this project will be significant, as it will allow us to make better decisions based on the data we collect.
#
# Project Timeline:
#
#  Phase 1: Research and development (1 week)
#  Phase 2: Script development (2 weeks)
#  Phase 3: Testing and refinement (1 week)
#
# Total Project Duration: 4 weeks
# Proposal saved to proposal.txt
# Generated proposal: E-commerce Website Development Proposal
#
# Problem:
#
# Your business is not taking full advantage of the online market. You have a great product or service, but you're not reaching the customers who are searching for it online.
#
# Solution:
#
# We will develop a custom e-commerce website for your business that will allow you to sell your products or services online. Our website will be user-friendly and easy to navigate, and it will be optimized for search engines so that your products or services can be easily found by potential customers.
#
# Benefits:
#
# An e-commerce website can help you to:
#
#  Increase sales
#  Reach new customers
#  Improve your brand awareness
#  Provide a convenient way for customers to purchase your products or services
#
# Cost:
#
# The cost of developing an e-commerce website will vary depending on the features and functionality that you require. We will provide you with a detailed quote once we have a better understanding of your needs.
#
# Call to action:
#
# If you're ready to take your business to the next level, contact us today to discuss your e-commerce website development project.
#
# We look forward to hearing from you!
# Proposal saved to proposal.txt
# Generated proposal: Social Media Integration API Development Proposal
#
# Value:
#
#  Increase user engagement and retention by providing a seamless way to share content across social media platforms.
#  Improve customer service by providing a single point of contact for customer support inquiries.
#  Enhance brand awareness by promoting content on social media channels.
#
# Impact:
#
#  The Social Media Integration API will allow our company to:
#      Reach a wider audience by making it easier for users to share our content on social media.
#      Improve customer service by providing a more efficient way for customers to contact us.
#      Increase brand awareness by promoting our content on social media channels.
#
# Benefits:
#
#  The Social Media Integration API will provide a number of benefits for our company, including:
#      Increased user engagement and retention.
#      Improved customer service.
#      Enhanced brand awareness.
#
# Cost:
#
# The estimated cost of developing the Social Media Integration API is \$100,000.
#
# Timeline:
#
# The Social Media Integration API is expected to be completed within 6 months.
#
# Approval:
#
# We request approval to proceed with the development of the Social Media Integration API.
# Proposal saved to proposal.txt
# Generated proposal: Machine Learning Specialist Needed
#
# Problem
#
# Our company is facing a challenge in developing and deploying machine learning models. We need a specialist with expertise in machine learning, data science, and software engineering to help us address this challenge.
#
# Solution
#
# A machine learning specialist would be able to help us develop and deploy machine learning models that can solve a variety of problems, such as:
#
#  Predicting customer churn
#  Identifying fraudulent transactions
#  Personalizing product recommendations
#
# Benefits
#
# A machine learning specialist would bring a number of benefits to our company, including:
#
#  Increased revenue
#  Reduced costs
#  Improved customer satisfaction
#
# Impact
#
# By hiring a machine learning specialist, we would be able to address a critical challenge and achieve a number of important benefits. This would have a significant impact on our company's bottom line and its ability to serve its customers.
#
# Call to Action
#
# We are seeking a highly motivated and experienced machine learning specialist to join our team. If you are interested in this opportunity, please send your resume and cover letter to [email protected]
# Proposal saved to proposal.txt
#         _id                                             _title  \
# 0  37870166  Create 4 in a row game in python console appli...
# 1  37870051           Trading View Indicators Coding in Python
# 2  37870014  Docker Image Creation for Python REST API - Go...
# 3  37869992                Human Face Detection Python Project
# 4  37869949                                  PDF page analyser
# 5  37868602  Datascience mock interviews expert(4-5 years o...
# 6  37869899         Python Script Development for Web Scraping
# 7  37869836              E-commerce Website Development Needed
# 8  37869764           Social Media Integration API Development
# 9  37869755                 Machine Learning Specialist Needed
#
#    _budget_minimum  _budget_maximum   _type  _bidperiod  _time_submitted  \
# 0             30.0            250.0   fixed           7       1710255706
# 1            600.0           1500.0   fixed           7       1710253865
# 2             10.0             30.0   fixed           7       1710253186
# 3            600.0           1500.0   fixed           7       1710252799
# 4            200.0            200.0   fixed          10       1710252201
# 5            100.0            400.0  hourly           7       1710229479
# 6             10.0             30.0   fixed           7       1710251270
# 7            600.0            601.0   fixed           7       1710250209
# 8           1500.0          12500.0   fixed           7       1710249007
# 9             30.0            250.0   fixed           7       1710248939
#
#    _bid_stats_bid_count  _bid_stats_bid_avg _currency_code  \
# 0                    17          153.117647            USD
# 1                     1         1050.000000            INR
# 2                     5           27.000000            USD
# 3                    12        13800.000000            INR
# 4                     1          200.000000            AUD
# 5                     4          604.250000            INR
# 6                     7          115.000000            CAD
# 7                    11         3459.818182            INR
# 8                     8         9825.000000            INR
# 9                    31          182.225806            EUR
#
#    _currency_exchange_rate                                           proposal  \
# 0                 1.000000  4 in a Row Game in Python Console Application\...
# 1                 0.012076  Trading View Indicators Coding in Python:\n\nL...
# 2                 1.000000  Proposal for Docker Image Creation for Python ...
# 3                 0.012076  Human Face Detection Python Project\n\nProblem...
# 4                 0.659708  PDF Page Analyser Proposal\n\nProblem\n\nPDF d...
# 5                 0.012076  Data Science Mock Interview Expert\n\nProblem\...
# 6                 0.740934  Python Script Development for Web Scraping\n\n...
# 7                 0.012076  E-commerce Website Development Proposal\n\nPro...
# 8                 0.012076  Social Media Integration API Development Propo...
# 9                 1.091732  Machine Learning Specialist Needed\n\nProblem\...
#
#                                     full_description  \
# 0  Hello, I have an existing code of client/serve...
# 1  In this project, I am seeking a proficient Pyt...
# 2  I need assistance with creating a Dockerfile a...
# 3  I am in need of a professional with experience...
# 4  Hi Ishaq, I was wondering if you'd be interest...
# 5  I am in need of a knowledgeable and experience...
# 6  I am looking for a talented Python developer t...
# 7  I need an expert to create an e-commerce websi...
# 8  I am looking for a seasoned developer with a d...
# 9  We need to create a machine learning model ins...
#
#                                             bid_data
# 0  {'bidder_id': '123456', 'description': 'Sample...
# 1  {'bidder_id': '123456', 'description': 'Sample...
# 2  {'bidder_id': '123456', 'description': 'Sample...
# 3  {'bidder_id': '123456', 'description': 'Sample...
# 4  {'bidder_id': '123456', 'description': 'Sample...
# 5  {'bidder_id': '123456', 'description': 'Sample...
# 6  {'bidder_id': '123456', 'description': 'Sample...
# 7  {'bidder_id': '123456', 'description': 'Sample...
# 8  {'bidder_id': '123456', 'description': 'Sample...
# 9  {'bidder_id': '123456', 'description': 'Sample...
# DataFrame saved to projects_with_proposals_and_bid_data.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re


# Define helper functions
def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def convert_timestamp(timestamp):
    return pd.to_datetime(timestamp, unit='s')

def get_common_usd_values(mimimum,maximum,exchange_rate,code):
    return mimimum * exchange_rate, maximum * exchange_rate, code
    

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def place_project_bid(session, project_id, bidder_id, description, amount,
                      period, milestone_percentage):
    """
    Place a bid on a project
    """
    bid_data = {
        'project_id': project_id,
        'bidder_id': bidder_id,
        'description': description,
        'amount': amount,
        'period': period,
        'milestone_percentage': milestone_percentage,
    }
    # POST /api/projects/0.1/bids/
    response = make_post_request(session, 'bids', json_data=bid_data)
    json_data = response.json()
    if response.status_code == 200:
        bid_data = json_data['result']
        return Bid(bid_data)
    else:
        raise BidNotPlacedException(message=json_data['message'],
                                    error_code=json_data['error_code'],
                                    request_id=json_data['request_id'])

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    proposals = []
    full_descriptions = []
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    # Selecting only specific columns
    selected_columns = [
       '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
        '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'

    ]
    df = df[selected_columns]
    df['proposal'] = proposals  # Add the generated proposals to the DataFramee
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    df['_time_submitted'] = df['_time_submitted'].apply(convert_timestamp)  # Convert timestamp to datetime format# Convert timestamp columns to human-readable format
    #create the new colunm "get_common_usd_values"print only budget_mininum_usd , budget_maximum_usd
    df['_budget_minimum_usd'] = df['_budget_minimum'] * df['_currency_exchange_rate']
    df['_budget_maximum_usd'] = df['_budget_maximum'] * df['_currency_exchange_rate']
    #create the new colunm "get_common_usd_values"
    #df['get_common_usd_values'] = df.apply(lambda row: get_common_usd_values(row['_budget_minimum'], row['_budget_maximum'], row['_currency_exchange_rate'], row['_currency_code']), axis=1)

    print(df)  # Print the DataFrame
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: Cloud-based Captcha Solver Development (Automatic)
#
# Problem: Captchas are a common security measure used to prevent bots from accessing websites. However, they can be a frustrating experience for users, who often have to solve multiple captchas in a row.
#
# Solution: Our proposed solution is a cloud-based captcha solver that automatically solves captchas for users. This would save users time and frustration, and would also help to improve the security of websites.
#
# Benefits:
#
#  Improved user experience: Users would no longer have to solve captchas, which would save them time and frustration.
#  Increased security: Our captcha solver would use advanced techniques to solve captchas, making it more difficult for bots to bypass.
#  Reduced costs: Our captcha solver would be hosted in the cloud, which would reduce the cost of implementing it for websites.
#
# We believe that our cloud-based captcha solver would be a valuable addition to any website. It would improve the user experience, increase security, and reduce costs.
# Proposal saved to proposal.txt
# Generated proposal: Project Proposal: Python Developer for Sales Data Analytics
#
# Problem: Sales teams are drowning in data, but they lack the tools to make sense of it. As a result, they're making decisions based on intuition rather than data-driven insights.
#
# Solution: A Python developer can help sales teams build and deploy data analytics models that will give them the insights they need to make better decisions. These models can help teams identify trends, predict customer behavior, and optimize their sales strategies.
#
# Impact: By implementing a data analytics solution, sales teams can:
#
#  Increase sales revenue by 10%-20%
#  Reduce costs by 5%-10%
#  Improve customer satisfaction by 10%-20%
#
# Benefits:
#
#  A Python developer can be hired on a contract basis, so there is no need to invest in full-time staff.
#  Python is a versatile language that can be used for a variety of data analytics tasks.
#  Python developers are in high demand, so it is easy to find qualified candidates.
#
# Conclusion: A Python developer for sales data analytics can help your team make better decisions, increase sales revenue, and reduce costs. This is a valuable investment that will pay off in the long run.
# Proposal saved to proposal.txt
# Generated proposal: 4 in a Row Game in Python Console Application
#
# Value:
#
#  A fun and challenging game to play for all ages.
#  A great way to learn the basics of programming in Python.
#  A practical project that can be used to demonstrate your skills to potential employers.
#
# Impact:
#
#  The 4 in a Row game will be a valuable addition to the Python programming community. It will provide a fun and challenging way for people to learn the basics of programming. The project will also be a practical demonstration of skills that can be used to obtain employment in the tech industry.
# Proposal saved to proposal.txt
# Generated proposal: Trading View Indicators Coding in Python
#
# Trading View is a popular platform for technical analysis and stock trading. Its charting tools and indicators can be used to identify trading opportunities and make informed decisions. However, the default indicators that come with Trading View are limited. By coding your own indicators in Python, you can create custom indicators that are tailored to your specific trading style and strategies.
#
# This project will teach you how to code Trading View indicators in Python. You will learn how to:
#
#  Use the TradingView API to access historical data and create charts
#  Develop custom indicators using Python's data science libraries
#  Backtest your indicators to test their performance
#
# This project is ideal for traders who want to take their technical analysis to the next level. By learning how to code your own indicators, you will be able to create a more comprehensive and customized trading strategy.
#
# Value:
#
# This project will provide you with the skills and knowledge you need to create custom Trading View indicators that can be used to identify trading opportunities and make informed trading decisions. This can lead to increased profitability and better trading performance.
#
# Impact:
#
# The impact of this project could be significant. By learning how to code your own Trading View indicators, you could potentially improve your trading performance and achieve your financial goals. You could also share your custom indicators with other traders, which could help to improve the overall trading community.
# Proposal saved to proposal.txt
# Generated proposal: Proposal for Docker Image Creation for Python REST API - Google Cloud Run
#
# Value:
#
# - Create a portable, production-ready image for running Python REST APIs on Google Cloud Run
# - Reduce development and deployment time
# - Improve reliability and scalability
#
# Impact:
#
# - Enable developers to quickly and easily deploy Python REST APIs to Google Cloud Run
# - Reduce the cost of running Python REST APIs on Google Cloud Run
# - Improve the reliability and scalability of Python REST APIs on Google Cloud Run
#
# Description:
#
# This proposal describes the creation of a Docker image for running Python REST APIs on Google Cloud Run. The image will be based on the official Python image and will include the necessary dependencies for running a Python REST API. The image will be built using a Dockerfile and will be pushed to a Docker registry. The proposal also includes a tutorial on how to use the image to deploy a Python REST API to Google Cloud Run.
#
# Benefits:
#
# - The Docker image will be portable and can be used to deploy Python REST APIs on any platform that supports Docker.
# - The Docker image will be production-ready and will include all of the necessary dependencies for running a Python REST API.
# - The Docker image will be easy to use and can be deployed with a single command.
#
# Timeline:
#
# The project will be completed in two weeks. The first week will be spent creating the Dockerfile and building the image. The second week will be spent writing the tutorial on how to use the image.
#
# Budget:
#
# The project will require a budget of \$1,000. The budget will be used to purchase the necessary software and hardware for development and testing.
#
# Approvals:
#
# This proposal requires the approval of the following stakeholders:
#
# - [Name] - Director of Engineering
# - [Name] - Head of Product Management
# - [Name] - VP of Marketing
#
# Next Steps:
#
# The next steps for this project are to create the Dockerfile and build the image. Once the image is built, the tutorial on how to use the image will be written.
# Proposal saved to proposal.txt
# Generated proposal: Human Face Detection Python Project Proposal
#
# Problem: Face detection is a challenging problem in computer vision, with a wide range of applications in security, surveillance, and biometrics. Existing face detection algorithms are often computationally expensive, making them impractical for use on resource-constrained devices.
#
# Solution: This project proposes a novel approach to face detection that is both accurate and efficient. The proposed algorithm is based on a deep learning model that is trained on a large dataset of face images. The model is able to detect faces in real time, even in challenging conditions such as low resolution and occlusion.
#
# Benefits: The proposed face detection algorithm has a number of benefits over existing approaches, including:
#
#  Accuracy: The proposed algorithm achieves state-of-the-art accuracy on standard face detection benchmarks.
#  Efficiency: The proposed algorithm is significantly more efficient than existing approaches, making it practical for use on resource-constrained devices.
#  Robustness: The proposed algorithm is robust to a wide range of challenges, such as low resolution and occlusion.
#
# Impact: The proposed face detection algorithm has the potential to have a significant impact on a wide range of applications, including:
#
#  Security: The proposed algorithm could be used to improve security systems by detecting unauthorized individuals.
#  Surveillance: The proposed algorithm could be used to monitor public spaces and detect suspicious activity.
#  Biometrics: The proposed algorithm could be used to identify individuals based on their facial features.
#
# Conclusion: The proposed face detection algorithm is a promising new approach that is both accurate and efficient. The algorithm has the potential to have a significant impact on a wide range of applications.
# Proposal saved to proposal.txt
# Generated proposal: PDF Page Analyser Proposal
#
# Problem: PDFs are a common format for storing and sharing documents, but they can be difficult to analyze. Existing tools are either too complex or too limited in their functionality.
#
# Solution: A PDF page analyser would provide a simple and easy-to-use way to extract data from PDFs. It would be able to extract text, images, tables, and other elements, and would also provide information about the document's structure and formatting.
#
# Benefits: A PDF page analyser would have a number of benefits, including:
#
#  Improved productivity: Users would be able to extract data from PDFs more quickly and easily, saving time and effort.
#  Improved decision-making: Users would be able to make better decisions based on the data they extract from PDFs.
#  Increased security: Users would be able to identify and protect sensitive data in PDFs.
#
# Impact: A PDF page analyser would have a significant impact on a variety of industries, including:
#
#  Business: Businesses would be able to improve their efficiency and productivity by extracting data from PDFs more quickly and easily.
#  Government: Governments would be able to make better decisions by identifying and protecting sensitive data in PDFs.
#  Education: Educators would be able to use PDF page analysers to help students learn and understand new concepts.
#
# Conclusion: A PDF page analyser would be a valuable tool for a variety of users. It would improve productivity, decision-making, and security, and would have a significant impact on a variety of industries.
# Proposal saved to proposal.txt
# Generated proposal: Data Science Mock Interview Expert
#
# Data science is a rapidly growing field, and the demand for skilled data scientists is high. However, many job seekers lack the experience necessary to land a data science job. This proposal outlines a project to create a pool of experienced data science mock interviewers who can help job seekers prepare for their interviews.
#
# The project will have the following benefits:
#
#  It will help job seekers improve their skills and knowledge. By practicing with experienced interviewers, job seekers will gain the confidence and skills they need to succeed in their interviews.
#  It will help employers find qualified candidates. By providing mock interviews, the project will help employers identify the best candidates for their open positions.
#  It will promote the growth of the data science field. By making it easier for people to get into data science, the project will help to grow the field and make it more accessible to everyone.
#
# The project will be funded by a grant from the National Science Foundation. The project will be led by a team of experienced data scientists and educators. The project will be completed in 12 months.
#
# Project Impact
#
# The project will have a significant impact on the data science field. It will help job seekers improve their skills and knowledge, help employers find qualified candidates, and promote the growth of the field. The project will also help to make data science more accessible to everyone.
# Proposal saved to proposal.txt
# Generated proposal: Python Script Development for Web Scraping
#
# Problem
#
# The ability to collect and analyze data from the web is essential for businesses of all sizes. However, manually extracting data from websites can be a time-consuming and tedious process.
#
# Solution
#
# A Python script can be developed to automate the process of web scraping, making it possible to collect large amounts of data quickly and easily. This data can then be used to improve business decision-making and drive growth.
#
# Benefits
#
# The benefits of using a Python script for web scraping include:
#
#  Reduced time and cost
#  Improved accuracy
#  Increased efficiency
#  Enhanced insights
#
# Impact
#
# By automating the process of web scraping, businesses can:
#
#  Gain a competitive advantage
#  Make better decisions
#  Increase their bottom line
#
# Conclusion
#
# Developing a Python script for web scraping is a valuable investment for businesses of all sizes. By automating the process of data collection, businesses can save time, money, and improve their bottom line.
# Proposal saved to proposal.txt
# Generated proposal: E-commerce Website Development Needed
#
# Overview
#
# In today's digital age, e-commerce is essential for businesses of all sizes. A well-developed e-commerce website can help you reach new customers, increase sales, and improve your bottom line.
#
# Benefits of an E-commerce Website
#
# An e-commerce website can provide your business with a number of benefits, including:
#
#  Increased sales: An e-commerce website allows you to sell your products or services to customers 24/7, from anywhere in the world.
#  Improved customer service: An e-commerce website can provide customers with a convenient way to shop, learn about your products or services, and contact customer service.
#  Brand awareness: An e-commerce website can help you build brand awareness and reach new customers.
#  Cost-effectiveness: An e-commerce website can be a cost-effective way to reach new customers and grow your business.
#
# Impact of an E-commerce Website
#
# An e-commerce website can have a significant impact on your business, helping you to reach new customers, increase sales, and improve your bottom line. If you're not yet taking advantage of e-commerce, now is the time to start.
#
# Call to Action
#
# If you're interested in learning more about how an e-commerce website can benefit your business, contact us today. We'll be happy to discuss your needs and create a custom e-commerce website that will help you achieve your goals.
# Proposal saved to proposal.txt
#         _id                                             _title  \
# 0  37870316  Cloud-based Captcha Solver Development (Automa...
# 1  37869040          Python Developer for Sales Data Analytics
# 2  37870166  Create 4 in a row game in python console appli...
# 3  37870051           Trading View Indicators Coding in Python
# 4  37870014  Docker Image Creation for Python REST API - Go...
# 5  37869992                Human Face Detection Python Project
# 6  37869949                                  PDF page analyser
# 7  37868602  Datascience mock interviews expert(4-5 years o...
# 8  37869899         Python Script Development for Web Scraping
# 9  37869836              E-commerce Website Development Needed
#
#    _budget_minimum  _budget_maximum   _type  _bidperiod     _time_submitted  \
# 0             50.0             80.0   fixed           7 2024-03-12 15:44:13
# 1            600.0           1500.0   fixed           7 2024-03-12 09:41:47
# 2             30.0            250.0   fixed           7 2024-03-12 15:01:46
# 3            600.0           1500.0   fixed           7 2024-03-12 14:31:05
# 4             10.0             30.0   fixed           7 2024-03-12 14:19:46
# 5            600.0           1500.0   fixed           7 2024-03-12 14:13:19
# 6            200.0            200.0   fixed          10 2024-03-12 14:03:21
# 7            100.0            400.0  hourly           7 2024-03-12 07:44:39
# 8             10.0             30.0   fixed           7 2024-03-12 13:47:50
# 9            600.0            601.0   fixed           7 2024-03-12 13:30:09
#
#    _bid_stats_bid_count  _bid_stats_bid_avg _currency_code  \
# 0                     0                 NaN            USD
# 1                    11         1084.545455            INR
# 2                    23          155.565217            USD
# 3                     1         1050.000000            INR
# 4                     7           25.714286            USD
# 5                    13        12819.230769            INR
# 6                     1          200.000000            AUD
# 7                     4          604.250000            INR
# 8                     7          115.000000            CAD
# 9                    11         3459.818182            INR
#
#    _currency_exchange_rate                                           proposal  \
# 0                 1.000000  Cloud-based Captcha Solver Development (Automa...
# 1                 0.012077  Project Proposal: Python Developer for Sales D...
# 2                 1.000000  4 in a Row Game in Python Console Application\...
# 3                 0.012077  Trading View Indicators Coding in Python\n\nTr...
# 4                 1.000000  Proposal for Docker Image Creation for Python ...
# 5                 0.012077  Human Face Detection Python Project Proposal\n...
# 6                 0.659595  PDF Page Analyser Proposal\n\nProblem: PDFs ar...
# 7                 0.012077  Data Science Mock Interview Expert\n\nData sci...
# 8                 0.741034  Python Script Development for Web Scraping\n\n...
# 9                 0.012077  E-commerce Website Development Needed\n\nOverv...
#
#                                     full_description  _budget_minimum_usd  \
# 0  As the team lead for this project, I am lookin...             50.00000
# 1  I'm in need of a skilled Python developer expe...              7.24620
# 2  Hello, I have an existing code of client/serve...             30.00000
# 3  In this project, I am seeking a proficient Pyt...              7.24620
# 4  I need assistance with creating a Dockerfile a...             10.00000
# 5  I am in need of a professional with experience...              7.24620
# 6  Hi Ishaq, I was wondering if you'd be interest...            131.91900
# 7  I am in need of a knowledgeable and experience...              1.20770
# 8  I am looking for a talented Python developer t...              7.41034
# 9  I need an expert to create an e-commerce websi...              7.24620
#
#    _budget_maximum_usd
# 0            80.000000
# 1            18.115500
# 2           250.000000
# 3            18.115500
# 4            30.000000
# 5            18.115500
# 6           131.919000
# 7             4.830800
# 8            22.231020
# 9             7.258277
# DataFrame saved to projects_with_proposals.csv

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects, get_project_by_id
from freelancersdk.resources.projects.exceptions import ProjectsNotFoundException
import requests
import re
from freelancersdk.resources.projects import (
    make_get_request, make_post_request, make_put_request,
)

# Define helper functions
def create_get_projects_project_details_object(full_description=False):
    return {'full_description': full_description}

def create_get_projects_user_details_object(basic=False):
    return {'basic': basic}

def convert_timestamp(timestamp):
    return pd.to_datetime(timestamp, unit='s')

def get_common_usd_values(mimimum,maximum,exchange_rate,code):
    return mimimum * exchange_rate, maximum * exchange_rate, code
    

def sample_get_project_by_id(project_id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token)
    try:
        response = search_projects(
            session,
            query='python',  # Empty query to retrieve all projects
            limit=10  # You can adjust the limit as needed
        )
        # Extract the list of projects
        projects = response.get('projects', [])
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return projects

def flatten_project_data(project, prefix=''):
    flattened_data = {}
    for key, value in project.items():
        if isinstance(value, dict):
            flattened_data.update(flatten_project_data(value, prefix=f"{prefix}_{key}"))
        elif value is not None:
            flattened_data[f"{prefix}_{key}"] = value
    return flattened_data

def generate_proposal(project_title, project_description):
    # set api key and api endpoint
    load_dotenv()
    api_key = 'AIzaSyDFyUhDz-TL8DqpWtHit9Ad2cKL-KzxG5Y'
    endpoint = "https://generativelanguage.googleapis.com/v1beta2"
    
    # generate the prompt to get my proposal 
    prompt = f"Generate an engaging and persuasive proposal for a project titled {project_title} with a description of {project_description}. that showcases its value and impact. The proposal should be concise, no longer than 1000 characters."

    # prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }
    # make the request to generative language api
    response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
    
    # get the generated proposal from the response
    try:
        proposal = response.json()['candidates'][0]['output']
    except KeyError:
        # Handle the error if the response does not contain the expected data
        print('Error: The API response does not contain the expected data.')
        return None

    # Remove Markdown syntax from the proposal
    proposal = re.sub(r'[*_]', '', proposal)

    print(f"Generated proposal: {proposal}")
    
    # save the generated proposal to a file
    with open("proposal.txt", "w") as f:
        f.write(proposal)
        print("Proposal saved to proposal.txt")
    # return the generated proposal
    return proposal

def place_project_bid(session, project_id, bidder_id, description, amount,
                      period, milestone_percentage):
    """
    Place a bid on a project
    """
    bid_data = {
        'project_id': project_id,
        'bidder_id': bidder_id,
        'description': description,
        'amount': amount,
        'period': period,
        'milestone_percentage': milestone_percentage,
    }
    # POST /api/projects/0.1/bids/
    response = make_post_request(session, 'bids', json_data=bid_data)
    json_data = response.json()
    if response.status_code == 200:
        bid_data = json_data['result']
        return "Bid Placed Successfully"  # Return a success message
    else:
        raise Exception(f"Bid Placement Error: {json_data['message']}")

def print_projects_table_with_proposal(projects):
    if not projects:
        print("No projects found.")
        return
    
    proposals = []
    full_descriptions = []
    bid_results = []  # List to store the results of placing bids
    
    for project in projects:
        project_id = project['id']
        project_title = project['title']
        
        # Check if 'full_description' key exists, if not, set project_description to an empty string
        project_description = project.get('full_description', '')

        # Get the full description using the project ID
        full_description = sample_get_project_by_id(project_id)['description']

        # Generate proposal
        proposal = generate_proposal(project_title, project_description)
        
        proposals.append(proposal)
        full_descriptions.append(full_description)
        
        # Place bid
        try:
            bid_result = place_project_bid(
                session,
                project_id,
                bidder_id,  # Assuming bidder_id is defined somewhere
                description,  # Assuming description is defined somewhere
                amount,  # Assuming amount is defined somewhere
                period,  # Assuming period is defined somewhere
                milestone_percentage  # Assuming milestone_percentage is defined somewhere
            )
            bid_results.append("Bid Placed Successfully")
        except Exception as e:
            bid_results.append(f"Bid Placement Error: {str(e)}")
    
    flattened_projects = [flatten_project_data(project) for project in projects]
    df = pd.DataFrame(flattened_projects)
    
    # Selecting only specific columns
    selected_columns = [
       '_id',  '_title',  '_budget_minimum', '_budget_maximum','_type','_bidperiod','_time_submitted',
        '_bid_stats_bid_count', '_bid_stats_bid_avg', '_currency_code','_currency_exchange_rate'
    ]
    df = df[selected_columns]
    
    df['proposal'] = proposals  # Add the generated proposals to the DataFrame
    df['full_description'] = full_descriptions  # Add the full descriptions to the DataFrame
    df['bid_result'] = bid_results  # Add the bid results to the DataFrame
    
    df['_time_submitted'] = df['_time_submitted'].apply(convert_timestamp)  # Convert timestamp to datetime format
    
    # Create the new columns for USD values
    df['_budget_minimum_usd'] = df['_budget_minimum'] * df['_currency_exchange_rate']
    df['_budget_maximum_usd'] = df['_budget_maximum'] * df['_currency_exchange_rate']
    
    print(df)  # Print the DataFrame
    
    # Save DataFrame to CSV file
    csv_filename = "projects_with_proposals.csv"
    df.to_csv(csv_filename, index=False)
    print(f"DataFrame saved to {csv_filename}")

projects = sample_search_projects()
print_projects_table_with_proposal(projects)
# Out:
# Generated proposal: 4 in a Row Game in Python Console Application
#
# Value:
#
# - A fun and challenging game for all ages
# - A great way to learn the basics of programming in Python
# - A valuable addition to any portfolio of programming projects
#
# Impact:
#
# - The 4 in a Row game will be a fun and engaging way for people to learn the basics of programming in Python. It will also be a valuable addition to any portfolio of programming projects. The game will be easy to learn and play, but will still provide a challenge for even the most experienced programmers. The game will be released under an open-source license, so that others can learn from and contribute to it.
#
# Project Description:
#
# The 4 in a Row game will be a console application written in Python. The game will be played on a 7x6 board, with players taking turns placing their pieces in empty squares. The first player to get four of their pieces in a row, either horizontally, vertically, or diagonally, wins the game. The game will be turn-based, with each player having one move per turn. The game will be over when one player has won or when the board is full.
#
# The 4 in a Row game will be a fun and challenging game for all ages. It will be a great way to learn the basics of programming in Python, and it will be a valuable addition to any portfolio of programming projects.
# Proposal saved to proposal.txt
# Generated proposal: Trading View Indicators Coding in Python:
#
# Learn to code TradingView indicators in Python and create your own custom indicators to analyze financial markets. This project will teach you how to use Python's powerful data analysis and visualization libraries to create indicators that can help you identify trading opportunities. The skills you learn in this project will be valuable for any trader who wants to take their trading to the next level.
#
# Benefits of this project:
#
#  Learn to code TradingView indicators in Python
#  Create your own custom indicators to analyze financial markets
#  Identify trading opportunities
#  Improve your trading performance
# Proposal saved to proposal.txt
# Generated proposal: Docker Image Creation for Python REST API - Google Cloud Run
#
# Value:
#
# - Reduces time to deploy Python REST APIs to Google Cloud Run by 90%
# - Improves reliability and scalability of Python REST APIs by running them in a containerized environment
# - Reduces costs by leveraging Google Cloud Run's pay-per-use pricing model
#
# Impact:
#
# - Enables developers to quickly and easily deploy Python REST APIs to Google Cloud Run
# - Improves the reliability and scalability of Python REST APIs
# - Reduces the cost of running Python REST APIs on Google Cloud Run
# Proposal saved to proposal.txt
# Generated proposal: Human Face Detection Python Project
#
# Problem
#
# Facial recognition is a powerful technology with a wide range of applications, from security to marketing. However, current facial recognition systems are often limited by their high cost and/or reliance on specialized hardware.
#
# Solution
#
# This project proposes to develop a low-cost, open-source Python project for human face detection. The project will be based on deep learning techniques, and will be designed to run on a variety of hardware platforms.
#
# Benefits
#
# The proposed project would have a number of benefits, including:
#
#  Reduced cost: The project would make facial recognition technology more accessible to a wider range of organizations.
#  Increased flexibility: The project would allow facial recognition to be used on a wider range of hardware platforms.
#  Improved accuracy: The project would use state-of-the-art deep learning techniques to achieve high levels of accuracy.
#
# Impact
#
# The proposed project would have a significant impact on a variety of industries, including security, marketing, and healthcare. By making facial recognition technology more accessible and affordable, the project would help to improve security, personalize marketing campaigns, and provide early detection of medical conditions.
# Proposal saved to proposal.txt
# Generated proposal: PDF Page Analyser Proposal
#
# Problem: PDF files are a common way to share information, but they can be difficult to analyze. The lack of structure and formatting makes it difficult to find specific information or identify trends.
#
# Solution: A PDF page analyser would help to solve this problem by providing a structured way to view and analyze PDF files. The analyser would extract text, images, and other data from PDF files and make it easy to search and filter the data. This would make it much easier to find specific information or identify trends in PDF files.
#
# Value: The PDF page analyser would have a number of benefits, including:
#
#  Improved productivity: The analyser would make it faster and easier to find information in PDF files. This would save time and improve productivity.
#  Improved decision-making: The analyser would make it easier to identify trends and patterns in PDF files. This information could be used to make better decisions.
#  Increased security: The analyser could be used to identify sensitive information in PDF files. This information could then be protected more effectively.
#
# Impact: The PDF page analyser would have a significant impact on a variety of businesses and organizations. It would make it easier for people to find information, identify trends, and make better decisions. This would lead to improved productivity, decision-making, and security.
# Proposal saved to proposal.txt
# Generated proposal: Data Science Mock Interview Expert
#
# Data science is a rapidly growing field, and there is a high demand for skilled professionals. However, getting a job in data science can be challenging, as many employers require candidates to have a lot of experience. This can make it difficult for people who are new to the field or who are looking to change careers.
#
# A data science mock interview expert can help bridge this gap by providing candidates with the opportunity to practice their interview skills in a realistic setting. This can help candidates to feel more confident and prepared when they go on actual interviews, and it can increase their chances of getting a job in data science.
#
# A data science mock interview expert can also provide valuable feedback on candidates' skills and knowledge. This feedback can help candidates to identify areas where they need to improve, and it can help them to develop a plan to become more competitive in the job market.
#
# In addition to helping candidates get jobs, data science mock interview experts can also help to improve the quality of data science professionals in the workforce. By providing candidates with the opportunity to practice their skills and receive feedback, data science mock interview experts can help to ensure that data science professionals are well-prepared to meet the demands of the job market.
#
# Value:
#
#  Helps candidates get jobs in data science
#  Improves the quality of data science professionals in the workforce
#  Provides candidates with the opportunity to practice their skills and receive feedback
#
# Impact:
#
#  More people are able to get jobs in data science
#  Data science professionals are more well-prepared to meet the demands of the job market
#  The data science field is strengthened as a whole
# Proposal saved to proposal.txt
# Generated proposal: Python Script Development for Web Scraping
#
# Web scraping is the process of extracting data from websites. It can be used for a variety of purposes, such as gathering market research data, monitoring competitor pricing, or automating tasks. Python is a powerful programming language that is well-suited for web scraping. It is easy to learn, has a large community of support, and is available on multiple platforms.
#
# This proposal outlines the development of a Python script for web scraping. The script will be able to extract data from a variety of websites, including HTML, XML, and JSON. It will be able to handle dynamic websites that change their content frequently. The script will be modular and extensible, making it easy to add new features or adapt it to new websites.
#
# The benefits of this project include:
#
#  Reduced time and effort required to gather data from websites
#  Improved accuracy of data collection
#  Increased flexibility and scalability of data collection
#
# This project has the potential to have a significant impact on a variety of businesses and organizations. It can help businesses to make better decisions, improve their operations, and gain a competitive advantage.
# Proposal saved to proposal.txt
# Generated proposal: E-commerce Website Development Proposal
#
# Problem
#
# Your current e-commerce website is not meeting the needs of your customers. It is difficult to navigate, slow to load, and does not offer a seamless shopping experience. As a result, you are losing sales and customers to your competitors.
#
# Solution
#
# We propose developing a new e-commerce website that will address the problems with your current site. The new site will be:
#
#  Easy to navigate
#  Fast loading
#  Responsive to mobile devices
#  Secure
#  Full of features that will enhance the shopping experience for your customers
#
# Benefits
#
# A new e-commerce website will have a number of benefits for your business, including:
#
#  Increased sales
#  Improved customer satisfaction
#  Increased brand awareness
#  Reduced costs
#
# Impact
#
# A new e-commerce website can have a significant impact on your business. By improving the customer experience, you will increase sales and grow your business. You will also improve your brand awareness and reduce your costs.
#
# Call to Action
#
# We urge you to consider our proposal for a new e-commerce website. We are confident that it will meet your needs and help you grow your business.
#
# Contact us today to learn more about our services and how we can help you achieve your business goals.
# Proposal saved to proposal.txt
# Generated proposal: Social Media Integration API Development Proposal
#
# Problem:
#
# Today's businesses need to be able to connect with their customers on social media, but doing so can be time-consuming and difficult. A Social Media Integration API can help businesses to connect with their customers on social media more easily and efficiently.
#
# Solution:
#
# Our proposed Social Media Integration API will allow businesses to connect with their customers on social media in a few simple steps. The API will provide businesses with a single point of access to all of their social media accounts, making it easy to post updates, manage comments, and track engagement.
#
# Benefits:
#
# A Social Media Integration API can provide businesses with a number of benefits, including:
#
#  Increased engagement with customers
#  Improved customer service
#  Increased brand awareness
#  Reduced marketing costs
#
# Impact:
#
# A Social Media Integration API can have a significant impact on a business's bottom line. By making it easier for businesses to connect with their customers on social media, an API can help businesses to increase engagement, improve customer service, and increase brand awareness. This can lead to increased sales and profits.
#
# Conclusion:
#
# We believe that a Social Media Integration API would be a valuable asset for any business that wants to connect with its customers on social media. The API would make it easy for businesses to manage their social media accounts, track engagement, and measure results. We are confident that a Social Media Integration API would help businesses to grow their business and reach their goals.
# Proposal saved to proposal.txt
# Generated proposal: Machine Learning Specialist Needed
#
# Problem
#
# Our company is facing a challenge in developing and deploying machine learning models. We need a specialist with expertise in data science, machine learning, and software engineering to help us solve this problem.
#
# Solution
#
# We propose hiring a machine learning specialist who will be responsible for developing and deploying machine learning models. This person will work closely with our team of data scientists and engineers to ensure that our models are accurate, scalable, and reliable.
#
# Benefits
#
# Hiring a machine learning specialist will have a number of benefits for our company, including:
#
#  Improved accuracy of our machine learning models
#  Increased scalability of our machine learning models
#  Reduced time to deploy new machine learning models
#  Increased productivity of our data scientists and engineers
#
# Impact
#
# The hiring of a machine learning specialist will have a significant impact on our company. It will help us to develop and deploy more accurate, scalable, and reliable machine learning models. This will allow us to improve our products and services, and ultimately, to better serve our customers.
#
# Call to Action
#
# We urge you to approve the hiring of a machine learning specialist. This is a critical role that will have a significant impact on our company.
# Proposal saved to proposal.txt
#         _id                                             _title  \
# 0  37870166  Create 4 in a row game in python console appli...
# 1  37870051           Trading View Indicators Coding in Python
# 2  37870014  Docker Image Creation for Python REST API - Go...
# 3  37869992                Human Face Detection Python Project
# 4  37869949                                  PDF page analyser
# 5  37868602  Datascience mock interviews expert(4-5 years o...
# 6  37869899         Python Script Development for Web Scraping
# 7  37869836              E-commerce Website Development Needed
# 8  37869764           Social Media Integration API Development
# 9  37869755                 Machine Learning Specialist Needed
#
#    _budget_minimum  _budget_maximum   _type  _bidperiod     _time_submitted  \
# 0             30.0            250.0   fixed           7 2024-03-12 15:01:46
# 1            600.0           1500.0   fixed           7 2024-03-12 14:31:05
# 2             10.0             30.0   fixed           7 2024-03-12 14:19:46
# 3            600.0           1500.0   fixed           7 2024-03-12 14:13:19
# 4            200.0            200.0   fixed          10 2024-03-12 14:03:21
# 5            100.0            400.0  hourly           7 2024-03-12 07:44:39
# 6             10.0             30.0   fixed           7 2024-03-12 13:47:50
# 7            600.0            601.0   fixed           7 2024-03-12 13:30:09
# 8           1500.0          12500.0   fixed           7 2024-03-12 13:10:07
# 9             30.0            250.0   fixed           7 2024-03-12 13:08:59
#
#    _bid_stats_bid_count  _bid_stats_bid_avg _currency_code  \
# 0                    23          155.565217            USD
# 1                     1         1050.000000            INR
# 2                     7           25.714286            USD
# 3                    13        12819.230769            INR
# 4                     1          200.000000            AUD
# 5                     4          604.250000            INR
# 6                     7          115.000000            CAD
# 7                    11         3459.818182            INR
# 8                     8         9825.000000            INR
# 9                    32          178.093750            EUR
#
#    _currency_exchange_rate                                           proposal  \
# 0                 1.000000  4 in a Row Game in Python Console Application\...
# 1                 0.012077  Trading View Indicators Coding in Python:\n\nL...
# 2                 1.000000  Docker Image Creation for Python REST API - Go...
# 3                 0.012077  Human Face Detection Python Project\n\nProblem...
# 4                 0.659595  PDF Page Analyser Proposal\n\nProblem: PDF fil...
# 5                 0.012077  Data Science Mock Interview Expert\n\nData sci...
# 6                 0.741034  Python Script Development for Web Scraping\n\n...
# 7                 0.012077  E-commerce Website Development Proposal\n\nPro...
# 8                 0.012077  Social Media Integration API Development Propo...
# 9                 1.091184  Machine Learning Specialist Needed\n\nProblem\...
#
#                                     full_description  \
# 0  Hello, I have an existing code of client/serve...
# 1  In this project, I am seeking a proficient Pyt...
# 2  I need assistance with creating a Dockerfile a...
# 3  I am in need of a professional with experience...
# 4  Hi Ishaq, I was wondering if you'd be interest...
# 5  I am in need of a knowledgeable and experience...
# 6  I am looking for a talented Python developer t...
# 7  I need an expert to create an e-commerce websi...
# 8  I am looking for a seasoned developer with a d...
# 9  We need to create a machine learning model ins...
#
#                                           bid_result  _budget_minimum_usd  \
# 0  Bid Placement Error: name 'session' is not def...             30.00000
# 1  Bid Placement Error: name 'session' is not def...              7.24620
# 2  Bid Placement Error: name 'session' is not def...             10.00000
# 3  Bid Placement Error: name 'session' is not def...              7.24620
# 4  Bid Placement Error: name 'session' is not def...            131.91900
# 5  Bid Placement Error: name 'session' is not def...              1.20770
# 6  Bid Placement Error: name 'session' is not def...              7.41034
# 7  Bid Placement Error: name 'session' is not def...              7.24620
# 8  Bid Placement Error: name 'session' is not def...             18.11550
# 9  Bid Placement Error: name 'session' is not def...             32.73552
#
#    _budget_maximum_usd
# 0           250.000000
# 1            18.115500
# 2            30.000000
# 3            18.115500
# 4           131.919000
# 5             4.830800
# 6            22.231020
# 7             7.258277
# 8           150.962500
# 9           272.796000
# DataFrame saved to projects_with_proposals.csv

# %%
console.log("hello")
# Out:
# Failed to start the Kernel.
#
# /home/ash93/.npm-global/lib/node_modules/itypescript/node_modules/node-gyp-build/node-gyp-build.js:60
#
#   throw new Error('No native build was found for ' + target + '\n    loaded from: ' + dir + '\n')
#
#   ^
#
#
#
# Error: No native build was found for platform=linux arch=x64 runtime=electron abi=72 uv=1 libc=glibc node=12.22.9
#
#     loaded from: /home/ash93/.npm-global/lib/node_modules/itypescript/node_modules/zeromq
#
#
#
#     at Function.load.resolve.load.path (/home/ash93/.npm-global/lib/node_modules/itypescript/node_modules/node-gyp-build/node-gyp-build.js:60:9)
#
#     at load (/home/ash93/.npm-global/lib/node_modules/itypescript/node_modules/node-gyp-build/node-gyp-build.js:22:30)
#
#     at Object.<anonymous> (/home/ash93/.npm-global/lib/node_modules/itypescript/node_modules/zeromq/binding.js:1:43)
#
#     at Module._compile (internal/modules/cjs/loader.js:999:30)
#
#     at Object.Module._extensions..js (internal/modules/cjs/loader.js:1027:10)
#
#     at Module.load (internal/modules/cjs/loader.js:863:32)
#
#     at Function.Module._load (internal/modules/cjs/loader.js:708:14)
#
#     at Module.require (internal/modules/cjs/loader.js:887:19)
#
#     at require (internal/modules/cjs/helpers.js:74:18)
#
#     at Object.<anonymous> (/home/ash93/.npm-global/lib/node_modules/itypescript/node_modules/zeromq/lib/index.js:6:11).
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
